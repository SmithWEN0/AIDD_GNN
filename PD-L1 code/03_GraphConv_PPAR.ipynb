# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
from rdkit.Chem import AllChem
import re
import torch
from torch_geometric.data import Data, Batch

from Bio.PDB import PDBList, PDBParser, PPBuilder
from Bio import PDB

import networkx as nx
from torch_geometric.utils import from_networkx
import matplotlib.pyplot as plt

from torch_geometric.loader import DataLoader

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, GATConv, GraphConv, GraphSAGE

import random

# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

from sklearn.preprocessing import StandardScaler

from ydata_profiling import ProfileReport
import os
from scipy.stats import pearsonr

# %%
# 固定随机种子等操作
seed = 12345
g = torch.Generator()
g.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = False
torch.use_deterministic_algorithms(True)
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'
os.environ['PYTHONHASHSEED'] = str(seed)  # 为了禁止hash随机化，使得实验可复现。

# %% [markdown]
# # 1. datasets

# %% [markdown]
# ## 1.1 read datasets

# %%
raw_data_molecule = pd.read_csv('./data/BindingDB clean.csv')
raw_data_molecule = raw_data_molecule.sample(frac=1, random_state=seed)
raw_data_molecule.reset_index(drop=True, inplace=True)
raw_data_molecule
# Out:
#             ID                                             Smiles  IC50 (nM)  \
# 0     50297101  Cc1oc(nc1CCOc1cccc(C[C@H]2CN(C[C@H]2C(O)=O)c2n...    1120.00
# 1     50510299           CCCCCCCCCCCC\C=C(/CCCC(O)=O)[N+]([O-])=O   15000.00
# 2     50935590  CC(C)=CCC\C(C)=C\Cc1c(O)cc(\C=C\c2ccc(C=O)cc2)...    2820.00
# 3     50939160  COc1ccc2CN(CCc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1c...   10000.00
# 4     50938853  Cc1cc(SCc2ccc(OCc3ccc(cc3)C(F)(F)F)cc2)c2OCCCc...     427.56
# ...        ...                                                ...        ...
# 997   50239381  CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(c1)-c1sc(...      28.00
# 998   50386699  Cc1nc(sc1COc1cc(Cl)c2c(CC(O)=O)csc2c1)-c1ccc(c...    1040.00
# 999      52091  COc1ccc2n(ccc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1cc...    3162.00
# 1000  50297055  CCOC(=O)N1C[C@H](CC(O)=O)[C@@H](C1)c1ccc(OCCc2...   10000.00
# 1001  51014438  FC(F)(F)c1ccc(nc1)S(=O)(=O)CCNC(=O)c1ccc(Cl)c(...   10000.00
#
#                                        canonical_smiles  Molecular Weight  \
# 0     Cc1oc(-c2ccccc2)nc1CCOc1cccc(C[C@H]2CN(c3nccc(...           552.553
# 1              CCCCCCCCCCCC/C=C(\CCCC(=O)O)[N+](=O)[O-]           327.465
# 2     CC(C)=CCC/C(C)=C/Cc1c(O)cc(/C=C/c2ccc(C=O)cc2)...           376.496
# 3     COc1ccc2c(c1)CCN(S(=O)(=O)c1cccc(C(=O)Nc3ccc(C...           500.960
# 4     Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...           518.553
# ...                                                 ...               ...
# 997   CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(-c2sc(=O)...           495.572
# 998   Cc1nc(-c2ccc(C(F)(F)F)cc2)sc1COc1cc(Cl)c2c(CC(...           497.947
# 999   COc1ccc2c(ccn2S(=O)(=O)c2cccc(C(=O)Nc3ccc(Cl)c...           484.917
# 1000  CCOC(=O)N1C[C@H](CC(=O)O)[C@H](c2ccc(OCCc3nc(-...           478.545
# 1001  O=C(NCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(Cl)c(...           471.682
#
#          LogP  num_H_acceptors  num_H_Donors
# 0     5.46002                7             1
# 1     5.71290                3             1
# 2     6.31590                3             2
# 3     4.04610                5             2
# 4     6.67352                5             1
# ...       ...              ...           ...
# 997   6.54080                6             2
# 998   7.21152                5             1
# 999   4.49080                6             2
# 1000  4.91812                6             1
# 1001  3.72000                4             1
#
# [1002 rows x 8 columns]

# %%
print(raw_data_molecule.columns)
# Out:
# Index(['ID', 'Smiles', 'IC50 (nM)', 'canonical_smiles', 'Molecular Weight',
#        'LogP', 'num_H_acceptors', 'num_H_Donors'],
#       dtype='object')

# %% [markdown]
# ## 1.4 missing data and duplicated data

# %%
raw_data_molecule_copy = raw_data_molecule.dropna(subset=['IC50 (nM)'])
raw_data_molecule_copy = raw_data_molecule_copy.drop_duplicates(subset='Smiles')
raw_data_molecule_copy = raw_data_molecule_copy.reset_index(drop=True)
raw_data_molecule_copy
# Out:
#             ID                                             Smiles  IC50 (nM)  \
# 0     50297101  Cc1oc(nc1CCOc1cccc(C[C@H]2CN(C[C@H]2C(O)=O)c2n...    1120.00
# 1     50510299           CCCCCCCCCCCC\C=C(/CCCC(O)=O)[N+]([O-])=O   15000.00
# 2     50935590  CC(C)=CCC\C(C)=C\Cc1c(O)cc(\C=C\c2ccc(C=O)cc2)...    2820.00
# 3     50939160  COc1ccc2CN(CCc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1c...   10000.00
# 4     50938853  Cc1cc(SCc2ccc(OCc3ccc(cc3)C(F)(F)F)cc2)c2OCCCc...     427.56
# ...        ...                                                ...        ...
# 997   50239381  CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(c1)-c1sc(...      28.00
# 998   50386699  Cc1nc(sc1COc1cc(Cl)c2c(CC(O)=O)csc2c1)-c1ccc(c...    1040.00
# 999      52091  COc1ccc2n(ccc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1cc...    3162.00
# 1000  50297055  CCOC(=O)N1C[C@H](CC(O)=O)[C@@H](C1)c1ccc(OCCc2...   10000.00
# 1001  51014438  FC(F)(F)c1ccc(nc1)S(=O)(=O)CCNC(=O)c1ccc(Cl)c(...   10000.00
#
#                                        canonical_smiles  Molecular Weight  \
# 0     Cc1oc(-c2ccccc2)nc1CCOc1cccc(C[C@H]2CN(c3nccc(...           552.553
# 1              CCCCCCCCCCCC/C=C(\CCCC(=O)O)[N+](=O)[O-]           327.465
# 2     CC(C)=CCC/C(C)=C/Cc1c(O)cc(/C=C/c2ccc(C=O)cc2)...           376.496
# 3     COc1ccc2c(c1)CCN(S(=O)(=O)c1cccc(C(=O)Nc3ccc(C...           500.960
# 4     Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...           518.553
# ...                                                 ...               ...
# 997   CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(-c2sc(=O)...           495.572
# 998   Cc1nc(-c2ccc(C(F)(F)F)cc2)sc1COc1cc(Cl)c2c(CC(...           497.947
# 999   COc1ccc2c(ccn2S(=O)(=O)c2cccc(C(=O)Nc3ccc(Cl)c...           484.917
# 1000  CCOC(=O)N1C[C@H](CC(=O)O)[C@H](c2ccc(OCCc3nc(-...           478.545
# 1001  O=C(NCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(Cl)c(...           471.682
#
#          LogP  num_H_acceptors  num_H_Donors
# 0     5.46002                7             1
# 1     5.71290                3             1
# 2     6.31590                3             2
# 3     4.04610                5             2
# 4     6.67352                5             1
# ...       ...              ...           ...
# 997   6.54080                6             2
# 998   7.21152                5             1
# 999   4.49080                6             2
# 1000  4.91812                6             1
# 1001  3.72000                4             1
#
# [1002 rows x 8 columns]

# %%
change_type = raw_data_molecule_copy['IC50 (nM)'].astype('float32')
raw_data_molecule_copy['IC50 (nM)'] = change_type

# %%
raw_data_molecule_copy['pIC50'] = raw_data_molecule_copy['IC50 (nM)'].apply(lambda x: -np.log10(x * 10 ** (-9)))

# %%
raw_data_molecule_copy = raw_data_molecule_copy[raw_data_molecule_copy['pIC50'] >= 4.0]

# %%
raw_data_molecule = raw_data_molecule_copy.reset_index(drop=True)
print(raw_data_molecule.isna().sum())
print(raw_data_molecule.nunique())
raw_data_molecule
# Out:
# ID                  0
# Smiles              0
# IC50 (nM)           0
# canonical_smiles    0
# Molecular Weight    0
# LogP                0
# num_H_acceptors     0
# num_H_Donors        0
# pIC50               0
# dtype: int64
# ID                  1000
# Smiles              1000
# IC50 (nM)            573
# canonical_smiles    1000
# Molecular Weight     741
# LogP                 781
# num_H_acceptors        9
# num_H_Donors           5
# pIC50                573
# dtype: int64
#            ID                                             Smiles  \
# 0    50297101  Cc1oc(nc1CCOc1cccc(C[C@H]2CN(C[C@H]2C(O)=O)c2n...
# 1    50510299           CCCCCCCCCCCC\C=C(/CCCC(O)=O)[N+]([O-])=O
# 2    50935590  CC(C)=CCC\C(C)=C\Cc1c(O)cc(\C=C\c2ccc(C=O)cc2)...
# 3    50939160  COc1ccc2CN(CCc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1c...
# 4    50938853  Cc1cc(SCc2ccc(OCc3ccc(cc3)C(F)(F)F)cc2)c2OCCCc...
# ..        ...                                                ...
# 995  50239381  CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(c1)-c1sc(...
# 996  50386699  Cc1nc(sc1COc1cc(Cl)c2c(CC(O)=O)csc2c1)-c1ccc(c...
# 997     52091  COc1ccc2n(ccc2c1)S(=O)(=O)c1cccc(c1)C(=O)Nc1cc...
# 998  50297055  CCOC(=O)N1C[C@H](CC(O)=O)[C@@H](C1)c1ccc(OCCc2...
# 999  51014438  FC(F)(F)c1ccc(nc1)S(=O)(=O)CCNC(=O)c1ccc(Cl)c(...
#
#         IC50 (nM)                                   canonical_smiles  \
# 0     1120.000000  Cc1oc(-c2ccccc2)nc1CCOc1cccc(C[C@H]2CN(c3nccc(...
# 1    15000.000000           CCCCCCCCCCCC/C=C(\CCCC(=O)O)[N+](=O)[O-]
# 2     2820.000000  CC(C)=CCC/C(C)=C/Cc1c(O)cc(/C=C/c2ccc(C=O)cc2)...
# 3    10000.000000  COc1ccc2c(c1)CCN(S(=O)(=O)c1cccc(C(=O)Nc3ccc(C...
# 4      427.559998  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
# ..            ...                                                ...
# 995     28.000000  CCCc1cc(Oc2ccc(F)cc2)ccc1OCCCOc1cccc(-c2sc(=O)...
# 996   1040.000000  Cc1nc(-c2ccc(C(F)(F)F)cc2)sc1COc1cc(Cl)c2c(CC(...
# 997   3162.000000  COc1ccc2c(ccn2S(=O)(=O)c2cccc(C(=O)Nc3ccc(Cl)c...
# 998  10000.000000  CCOC(=O)N1C[C@H](CC(=O)O)[C@H](c2ccc(OCCc3nc(-...
# 999  10000.000000  O=C(NCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(Cl)c(...
#
#      Molecular Weight     LogP  num_H_acceptors  num_H_Donors     pIC50
# 0             552.553  5.46002                7             1  5.950782
# 1             327.465  5.71290                3             1  4.823909
# 2             376.496  6.31590                3             2  5.549751
# 3             500.960  4.04610                5             2  5.000000
# 4             518.553  6.67352                5             1  6.369003
# ..                ...      ...              ...           ...       ...
# 995           495.572  6.54080                6             2  7.552842
# 996           497.947  7.21152                5             1  5.982967
# 997           484.917  4.49080                6             2  5.500038
# 998           478.545  4.91812                6             1  5.000000
# 999           471.682  3.72000                4             1  5.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# # 2. construct graphs for small molecules

# %%
# Define possible values for one-hot encoding
possible_atomic_numbers = list(range(1, 119))
possible_degrees = list(range(0, 10))
possible_hybridizations = [
    Chem.rdchem.HybridizationType.SP,
    Chem.rdchem.HybridizationType.SP2,
    Chem.rdchem.HybridizationType.SP3,
    Chem.rdchem.HybridizationType.SP3D,
    Chem.rdchem.HybridizationType.SP3D2
]
possible_chirality = [
    Chem.rdchem.ChiralType.CHI_UNSPECIFIED,
    Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CW,
    Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CCW,
    Chem.rdchem.ChiralType.CHI_OTHER
]
possible_bond_types = [Chem.rdchem.BondType.SINGLE, Chem.rdchem.BondType.DOUBLE,
                       Chem.rdchem.BondType.TRIPLE, Chem.rdchem.BondType.AROMATIC]

possible_bond_stereo = [Chem.rdchem.BondStereo.STEREONONE, Chem.rdchem.BondStereo.STEREOZ,
                        Chem.rdchem.BondStereo.STEREOE, Chem.rdchem.BondStereo.STEREOCIS,
                        Chem.rdchem.BondStereo.STEREOTRANS]

# One-hot encoding functions
def one_hot_encode(value, possible_values):
    encoding = [0] * len(possible_values)
    if value in possible_values:
        encoding[possible_values.index(value)] = 1
    return encoding

# Functions for molecular data processing
def get_atomic_info(atom):
    atomic_number_encoding = one_hot_encode(atom.GetAtomicNum(), possible_atomic_numbers)
    degree_encoding = one_hot_encode(atom.GetTotalDegree(), possible_degrees)
    hybridization_encoding = one_hot_encode(atom.GetHybridization(), possible_hybridizations)
    aromatic_encoding = [1 if atom.GetIsAromatic() else 0]
    implicit_valence_encoding = one_hot_encode(atom.GetImplicitValence(), possible_degrees)
    formal_charge_encoding = [atom.GetFormalCharge()]
    chirality_encoding = one_hot_encode(atom.GetChiralTag(), possible_chirality)

    return atomic_number_encoding + degree_encoding + hybridization_encoding + \
           aromatic_encoding + implicit_valence_encoding + formal_charge_encoding + chirality_encoding

def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    atom_features = [get_atomic_info(atom) for atom in mol.GetAtoms()]
    x = torch.tensor(atom_features, dtype=torch.float)

    edges = []
    edge_features = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        edges.append((i, j))
        edges.append((j, i))

        bond_type_encoding = one_hot_encode(bond.GetBondType(), possible_bond_types)
        bond_stereo_encoding = one_hot_encode(bond.GetStereo(), possible_bond_stereo)
        conjugation_encoding = [1 if bond.GetIsConjugated() else 0]
        edge_feature = bond_type_encoding + bond_stereo_encoding + conjugation_encoding

        edge_features.append(edge_feature)
        edge_features.append(edge_feature)

    edge_index = torch.tensor(edges, dtype=torch.int64).t().contiguous()
    edge_attr = torch.tensor(edge_features, dtype=torch.float)

    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr)

# %%
graph_list = [smiles_to_graph(smile) for smile in raw_data_molecule['Smiles']]
pIC50_list = raw_data_molecule['pIC50'].to_list()

scaler = StandardScaler()
pIC50_list = scaler.fit_transform(np.array(pIC50_list).reshape(-1, 1)).flatten()

for graph, pIC50 in zip(graph_list, pIC50_list):
    graph.y = torch.tensor([pIC50], dtype=torch.float).view(-1, 1)


drug_graphs = graph_list
drug_graphs[0]
# Out:
# Data(x=[40, 149], edge_index=[2, 88], edge_attr=[88, 10], y=[1, 1])

# %% [markdown]
# # 3. construct graphs for protein

# %%
# Define a mapping from amino acid names to one-hot encoded vectors
amino_acids = ['ALA', 'ARG', 'ASN', 'ASP', 'CYS', 'GLU', 'GLN', 'GLY', 'HIS', 'ILE', 
               'LEU', 'LYS', 'MET', 'PHE', 'PRO', 'SER', 'THR', 'TRP', 'TYR', 'VAL']
amino_acid_dict = {aa: idx for idx, aa in enumerate(amino_acids)}

# %%
def one_hot_encode_amino_acid(residue_name):
    one_hot = [0] * len(amino_acids)
    if residue_name in amino_acid_dict:
        one_hot[amino_acid_dict[residue_name]] = 1
    return one_hot


def pdb_to_graph(pdb_id):
    pdb_list = PDBList()
    pdb_file_path = pdb_list.retrieve_pdb_file(pdb_id, file_format='pdb', pdir='.')

    parser = PDBParser(QUIET=True)
    structure = parser.get_structure(pdb_id, pdb_file_path)

    # Create a graph
    G = nx.Graph()

    # Traverse through the hierarchy
    for model in structure:
        for chain in model:
            for residue in chain:
                res_id = residue.get_id()
                residue_name = residue.get_resname()
                node_feature = one_hot_encode_amino_acid(residue_name)

                # Additional features: secondary structure and B-factor
                b_factor = residue["CA"].get_bfactor() if 'CA' in residue else 0.0
                
                # Combine all features
                node_feature.append(b_factor)

                G.add_node(res_id, residue_name=residue_name, feature=node_feature)

    # Add edges based on distance threshold
    threshold = 5.0  # Angstroms
    for residue1 in structure.get_residues():
        for residue2 in structure.get_residues():
            if residue1 != residue2:
                try:
                    distance = residue1['CA'] - residue2['CA']  # Using alpha carbon (CA) distance
                    if distance < threshold:
                        G.add_edge(residue1.get_id(), residue2.get_id(), distance=distance)
                except KeyError:
                    continue

    # Convert to PyTorch Geometric Data format
    data = from_networkx(G)

    # Convert node features to tensor and assign to data.x
    node_features = [G.nodes[n]['feature'] for n in G.nodes]
    data.x = torch.tensor(node_features, dtype=torch.float)

    # Optionally add edge attributes if necessary
    edge_attr = [G[u][v]['distance'] for u, v in G.edges]
    data.edge_attr = torch.tensor(edge_attr, dtype=torch.float).view(-1, 1)


    return data

# %%
protein_pdb = '2ZNP'
protein_graph = pdb_to_graph(protein_pdb)
protein_graph
# Out:
# Structure exists: '.\pdb2znp.ent'
# Data(edge_index=[2, 714], residue_name=[275], feature=[275, 21], distance=[714], num_nodes=275, x=[275, 21], edge_attr=[357, 1])

# %% [markdown]
# # 4. datasets preparation
#
# shuffling the dataset before it is split can improve the performance. When downloading the dataset from CheMBL, the compound may be sorted and ranked.

# %%
batch_size = 64
torch.manual_seed(seed)
drug_graph_train_loader = DataLoader(drug_graphs[0: int(len(drug_graphs) * 0.8)], batch_size=batch_size, shuffle=True)
drug_graph_test_loader = DataLoader(drug_graphs[int(len(drug_graphs) * 0.2): ], batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 5. model construction

# %%
class GCN_Graph(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN_Graph, self).__init__()
        torch.manual_seed(seed)
        self.conv1 = GraphConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.lin = torch.nn.Linear(hidden_channels, out_channels)

    
    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = F.leaky_relu(x)

        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = F.leaky_relu(x)

        x = global_mean_pool(x, batch)  # Global pooling

        x = F.dropout(x, p=0.5, training=self.training)
        
        x = self.lin(x)

        return x


class AffinityPredictor(torch.nn.Module):
    def __init__(self, protein_gnn, molecule_gnn, hidden_channels):
        super(AffinityPredictor, self).__init__()
        torch.manual_seed(seed)
        self.protein_gnn = protein_gnn
        self.molecule_gnn = molecule_gnn
        self.lin = torch.nn.Linear(hidden_channels * 2, hidden_channels * 2)
        self.batch = torch.nn.BatchNorm1d(hidden_channels * 2)
        self.fc = torch.nn.Linear(hidden_channels * 2, 1)
    
    def forward(self, protein_data, molecule_data):
        # Protein embedding
        protein_embedding = self.protein_gnn(protein_data.x, protein_data.edge_index, protein_data.batch)
        protein_embedding = protein_embedding.unsqueeze(0).expand(molecule_data.batch.max().item() + 1, -1, -1)  # Expand for batch size
        protein_embedding = protein_embedding.reshape(-1, protein_embedding.size(-1))  # Reshape to match molecule_embedding
        # Molecule embedding
        molecule_embedding = self.molecule_gnn(molecule_data.x, molecule_data.edge_index, molecule_data.batch)
        
        # Concatenate embeddings
        x = torch.cat([protein_embedding, molecule_embedding], dim=1)
        x = self.lin(x)
        x = self.batch(x)
        x = F.leaky_relu(x)
        
        x = F.dropout(x, p=0.5, training=self.training)
        
        return self.fc(x)

# %% [markdown]
# # 6. initializing the model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
protein_gnn = GCN_Graph(in_channels=protein_graph.num_node_features, hidden_channels=128, out_channels=128).to(device)
molecule_gnn = GCN_Graph(in_channels=drug_graphs[0].num_node_features, hidden_channels=128, out_channels=128).to(device)
model = AffinityPredictor(protein_gnn, molecule_gnn, hidden_channels=128).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

criterion = torch.nn.L1Loss(reduction='mean').to(device)
# Out:
# Using device: cuda

# %% [markdown]
# # 7. train and test
# rule of thumb: either MAE < 0.6 or R2 > 0.6 is considered as good model
# https://www.nature.com/articles/s41598-020-80113-7

# %%
def train(model, protein_graph, drug_graph_train_loader, optimizer, criterion, epoch):
    model.train()

    for molecule_data in drug_graph_train_loader:
        
        optimizer.zero_grad()
        molecule_data = molecule_data.to(device)
        protein_graph = protein_graph.to(device)
        
        protein_graph_batch = protein_graph.clone()
        protein_graph_batch.batch = torch.zeros(protein_graph.x.size(0), dtype=torch.long).to(device)
        
        output = model(protein_graph, molecule_data)
        loss = criterion(output, molecule_data.y)
        loss.backward()
        optimizer.step()
    

def test(protein_graph, loader):
    model.eval()

    loss_list = []
    r2_list = []

    with torch.no_grad():
        for data in loader:
            
            protein_graph = protein_graph.to(device)
            data = data.to(device)
            out = model(protein_graph, data)
   
            out = torch.tensor(scaler.inverse_transform(out.detach().cpu().numpy().reshape(-1, 1)).flatten())
            actual = torch.tensor(scaler.inverse_transform(data.y.detach().cpu().numpy().reshape(-1, 1)).flatten())

            mae_loss = criterion(out, actual)

            r2 = r2_score(actual, out)
            r2_list.append(r2)

            mae_loss = mae_loss.detach().cpu().numpy()
            loss_list.append(mae_loss)
            
    return loss_list, r2_list
        
overall_train_r2 = []
overall_test_r2 = []
overall_train_loss = []
overall_test_loss = []

best_loss = float('inf')
patience = 100
patience_counter = 0
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
# Training loop
for epoch in range(1, 2001):
    train(model,protein_graph, drug_graph_train_loader, optimizer, criterion, epoch)

    if epoch % 1 == 0:
        train_loss, r2_train_list = test(protein_graph, drug_graph_train_loader)
        test_loss, r2_test_list = test(protein_graph, drug_graph_test_loader)
        print(f'Epoch {epoch}, MAE train loss: {np.average(train_loss):.4f}, MAE test loss: {np.average(test_loss):.4f}, train r2: {np.average(r2_train_list):.4f}, test r2: {np.average(r2_test_list):.4f}')

        overall_train_loss.append(np.average(train_loss))
        overall_test_loss.append(np.average(test_loss))

        overall_train_r2.append(np.average(r2_train_list))
        overall_test_r2.append(np.average(r2_test_list))


        if np.average(test_loss) < best_loss:
            best_loss = np.average(test_loss)
            patience_counter = 0
            # torch.save(model.state_dict(), 'best_model_no_fingerprint_GraphConv.pth')
        else:
            patience_counter += 1
        
        if patience_counter >= patience:
            print("Early stopping")
            break
    scheduler.step()
# Out:
# Epoch 1, MAE train loss: 0.8288, MAE test loss: 0.8311, train r2: -0.0160, test r2: -0.0043
# Epoch 2, MAE train loss: 0.7987, MAE test loss: 0.8008, train r2: 0.0774, test r2: 0.0744
# Epoch 3, MAE train loss: 0.7316, MAE test loss: 0.7343, train r2: 0.1899, test r2: 0.2089
# Epoch 4, MAE train loss: 0.6580, MAE test loss: 0.6631, train r2: 0.3265, test r2: 0.3391
# Epoch 5, MAE train loss: 0.6315, MAE test loss: 0.6375, train r2: 0.3304, test r2: 0.3526
# Epoch 6, MAE train loss: 0.6410, MAE test loss: 0.6412, train r2: 0.3387, test r2: 0.3528
# Epoch 7, MAE train loss: 0.6188, MAE test loss: 0.6304, train r2: 0.3719, test r2: 0.3861
# Epoch 8, MAE train loss: 0.6224, MAE test loss: 0.6289, train r2: 0.3152, test r2: 0.3138
# Epoch 9, MAE train loss: 0.6582, MAE test loss: 0.6601, train r2: 0.2773, test r2: 0.2779
# Epoch 10, MAE train loss: 0.6017, MAE test loss: 0.6062, train r2: 0.3834, test r2: 0.3930
# Epoch 11, MAE train loss: 0.6017, MAE test loss: 0.6141, train r2: 0.3980, test r2: 0.3892
# Epoch 12, MAE train loss: 0.6292, MAE test loss: 0.6301, train r2: 0.3036, test r2: 0.3097
# Epoch 13, MAE train loss: 0.5899, MAE test loss: 0.5968, train r2: 0.3871, test r2: 0.3995
# Epoch 14, MAE train loss: 0.6312, MAE test loss: 0.6386, train r2: 0.3557, test r2: 0.3544
# Epoch 15, MAE train loss: 0.5978, MAE test loss: 0.6043, train r2: 0.4189, test r2: 0.4195
# Epoch 16, MAE train loss: 0.5615, MAE test loss: 0.5800, train r2: 0.4354, test r2: 0.4198
# Epoch 17, MAE train loss: 0.5720, MAE test loss: 0.5833, train r2: 0.4461, test r2: 0.4432
# Epoch 18, MAE train loss: 0.5576, MAE test loss: 0.5737, train r2: 0.4499, test r2: 0.4394
# Epoch 19, MAE train loss: 0.5557, MAE test loss: 0.5752, train r2: 0.4300, test r2: 0.4090
# Epoch 20, MAE train loss: 0.5787, MAE test loss: 0.5878, train r2: 0.4432, test r2: 0.4455
# Epoch 21, MAE train loss: 0.6944, MAE test loss: 0.7027, train r2: 0.2559, test r2: 0.2635
# Epoch 22, MAE train loss: 0.5424, MAE test loss: 0.5626, train r2: 0.4594, test r2: 0.4373
# Epoch 23, MAE train loss: 0.6096, MAE test loss: 0.6195, train r2: 0.3389, test r2: 0.3244
# Epoch 24, MAE train loss: 0.7497, MAE test loss: 0.7594, train r2: 0.1680, test r2: 0.1594
# Epoch 25, MAE train loss: 1.0005, MAE test loss: 1.0045, train r2: -0.4558, test r2: -0.4865
# Epoch 26, MAE train loss: 0.5948, MAE test loss: 0.6083, train r2: 0.4225, test r2: 0.4135
# Epoch 27, MAE train loss: 0.5806, MAE test loss: 0.5932, train r2: 0.3917, test r2: 0.3808
# Epoch 28, MAE train loss: 0.6790, MAE test loss: 0.6914, train r2: 0.3175, test r2: 0.2928
# Epoch 29, MAE train loss: 0.5359, MAE test loss: 0.5535, train r2: 0.4712, test r2: 0.4509
# Epoch 30, MAE train loss: 0.5539, MAE test loss: 0.5709, train r2: 0.4595, test r2: 0.4681
# Epoch 31, MAE train loss: 0.5366, MAE test loss: 0.5535, train r2: 0.4971, test r2: 0.4786
# Epoch 32, MAE train loss: 0.5415, MAE test loss: 0.5616, train r2: 0.4815, test r2: 0.4654
# Epoch 33, MAE train loss: 0.5224, MAE test loss: 0.5404, train r2: 0.4807, test r2: 0.4597
# Epoch 34, MAE train loss: 0.5384, MAE test loss: 0.5551, train r2: 0.4765, test r2: 0.4366
# Epoch 35, MAE train loss: 0.5101, MAE test loss: 0.5310, train r2: 0.5157, test r2: 0.5076
# Epoch 36, MAE train loss: 0.7182, MAE test loss: 0.7335, train r2: 0.2454, test r2: 0.2091
# Epoch 37, MAE train loss: 0.5242, MAE test loss: 0.5464, train r2: 0.5154, test r2: 0.4989
# Epoch 38, MAE train loss: 0.5119, MAE test loss: 0.5307, train r2: 0.5182, test r2: 0.5002
# Epoch 39, MAE train loss: 0.6171, MAE test loss: 0.6317, train r2: 0.3749, test r2: 0.3796
# Epoch 40, MAE train loss: 0.7560, MAE test loss: 0.7712, train r2: 0.0643, test r2: 0.0438
# Epoch 41, MAE train loss: 0.7041, MAE test loss: 0.7185, train r2: 0.2585, test r2: 0.2501
# Epoch 42, MAE train loss: 0.5112, MAE test loss: 0.5402, train r2: 0.5136, test r2: 0.4936
# Epoch 43, MAE train loss: 0.5040, MAE test loss: 0.5222, train r2: 0.5115, test r2: 0.4924
# Epoch 44, MAE train loss: 0.5132, MAE test loss: 0.5354, train r2: 0.5230, test r2: 0.5072
# Epoch 45, MAE train loss: 0.5073, MAE test loss: 0.5268, train r2: 0.4978, test r2: 0.4823
# Epoch 46, MAE train loss: 0.5028, MAE test loss: 0.5292, train r2: 0.5333, test r2: 0.5101
# Epoch 47, MAE train loss: 0.5124, MAE test loss: 0.5335, train r2: 0.5292, test r2: 0.5079
# Epoch 48, MAE train loss: 0.4982, MAE test loss: 0.5198, train r2: 0.5391, test r2: 0.5159
# Epoch 49, MAE train loss: 0.5339, MAE test loss: 0.5513, train r2: 0.4633, test r2: 0.4421
# Epoch 50, MAE train loss: 0.5394, MAE test loss: 0.5515, train r2: 0.4690, test r2: 0.4477
# Epoch 51, MAE train loss: 0.6021, MAE test loss: 0.6226, train r2: 0.4368, test r2: 0.4008
# Epoch 52, MAE train loss: 0.4805, MAE test loss: 0.5138, train r2: 0.5597, test r2: 0.5179
# Epoch 53, MAE train loss: 0.5195, MAE test loss: 0.5426, train r2: 0.5280, test r2: 0.4970
# Epoch 54, MAE train loss: 0.6778, MAE test loss: 0.7045, train r2: 0.2296, test r2: 0.1575
# Epoch 55, MAE train loss: 0.5132, MAE test loss: 0.5429, train r2: 0.5342, test r2: 0.5039
# Epoch 56, MAE train loss: 0.6358, MAE test loss: 0.6551, train r2: 0.3753, test r2: 0.3348
# Epoch 57, MAE train loss: 0.6929, MAE test loss: 0.7067, train r2: 0.2253, test r2: 0.1688
# Epoch 58, MAE train loss: 0.5998, MAE test loss: 0.6271, train r2: 0.4202, test r2: 0.3721
# Epoch 59, MAE train loss: 0.5327, MAE test loss: 0.5473, train r2: 0.4639, test r2: 0.4289
# Epoch 60, MAE train loss: 0.5404, MAE test loss: 0.5618, train r2: 0.4694, test r2: 0.4320
# Epoch 61, MAE train loss: 0.6176, MAE test loss: 0.6378, train r2: 0.3866, test r2: 0.3653
# Epoch 62, MAE train loss: 0.5038, MAE test loss: 0.5363, train r2: 0.5429, test r2: 0.5028
# Epoch 63, MAE train loss: 0.5249, MAE test loss: 0.5477, train r2: 0.5214, test r2: 0.5104
# Epoch 64, MAE train loss: 0.4708, MAE test loss: 0.5044, train r2: 0.5683, test r2: 0.5332
# Epoch 65, MAE train loss: 0.4680, MAE test loss: 0.4971, train r2: 0.5671, test r2: 0.5151
# Epoch 66, MAE train loss: 0.5108, MAE test loss: 0.5386, train r2: 0.5170, test r2: 0.4870
# Epoch 67, MAE train loss: 0.8074, MAE test loss: 0.8219, train r2: 0.0964, test r2: 0.0445
# Epoch 68, MAE train loss: 0.7654, MAE test loss: 0.7804, train r2: 0.0660, test r2: 0.0158
# Epoch 69, MAE train loss: 0.5208, MAE test loss: 0.5537, train r2: 0.5351, test r2: 0.4957
# Epoch 70, MAE train loss: 0.4922, MAE test loss: 0.5182, train r2: 0.5458, test r2: 0.5117
# Epoch 71, MAE train loss: 0.6523, MAE test loss: 0.6667, train r2: 0.2843, test r2: 0.2421
# Epoch 72, MAE train loss: 0.5572, MAE test loss: 0.5793, train r2: 0.4760, test r2: 0.4314
# Epoch 73, MAE train loss: 0.4643, MAE test loss: 0.4980, train r2: 0.5780, test r2: 0.5462
# Epoch 74, MAE train loss: 0.8706, MAE test loss: 0.8783, train r2: -0.0761, test r2: -0.0786
# Epoch 75, MAE train loss: 0.8192, MAE test loss: 0.8382, train r2: -0.0943, test r2: -0.1355
# Epoch 76, MAE train loss: 0.5346, MAE test loss: 0.5681, train r2: 0.5207, test r2: 0.4629
# Epoch 77, MAE train loss: 0.5800, MAE test loss: 0.5969, train r2: 0.4035, test r2: 0.3539
# Epoch 78, MAE train loss: 0.5022, MAE test loss: 0.5306, train r2: 0.5510, test r2: 0.5099
# Epoch 79, MAE train loss: 0.5167, MAE test loss: 0.5498, train r2: 0.5312, test r2: 0.4870
# Epoch 80, MAE train loss: 0.5234, MAE test loss: 0.5536, train r2: 0.5089, test r2: 0.4635
# Epoch 81, MAE train loss: 0.5448, MAE test loss: 0.5758, train r2: 0.5038, test r2: 0.4570
# Epoch 82, MAE train loss: 0.4559, MAE test loss: 0.4898, train r2: 0.5937, test r2: 0.5582
# Epoch 83, MAE train loss: 0.5512, MAE test loss: 0.5698, train r2: 0.4372, test r2: 0.3926
# Epoch 84, MAE train loss: 0.5078, MAE test loss: 0.5368, train r2: 0.5350, test r2: 0.5111
# Epoch 85, MAE train loss: 0.5237, MAE test loss: 0.5556, train r2: 0.5239, test r2: 0.4747
# Epoch 86, MAE train loss: 0.4487, MAE test loss: 0.4832, train r2: 0.6051, test r2: 0.5664
# Epoch 87, MAE train loss: 0.4579, MAE test loss: 0.4879, train r2: 0.5685, test r2: 0.5298
# Epoch 88, MAE train loss: 0.4800, MAE test loss: 0.5092, train r2: 0.5792, test r2: 0.5285
# Epoch 89, MAE train loss: 0.4633, MAE test loss: 0.4973, train r2: 0.5926, test r2: 0.5494
# Epoch 90, MAE train loss: 0.4640, MAE test loss: 0.4994, train r2: 0.5959, test r2: 0.5518
# Epoch 91, MAE train loss: 0.4869, MAE test loss: 0.5234, train r2: 0.5769, test r2: 0.5288
# Epoch 92, MAE train loss: 0.5064, MAE test loss: 0.5308, train r2: 0.5139, test r2: 0.4779
# Epoch 93, MAE train loss: 0.4639, MAE test loss: 0.4931, train r2: 0.5923, test r2: 0.5509
# Epoch 94, MAE train loss: 0.5047, MAE test loss: 0.5324, train r2: 0.4997, test r2: 0.4645
# Epoch 95, MAE train loss: 0.4774, MAE test loss: 0.5164, train r2: 0.5934, test r2: 0.5361
# Epoch 96, MAE train loss: 0.4668, MAE test loss: 0.5013, train r2: 0.5800, test r2: 0.5285
# Epoch 97, MAE train loss: 0.4824, MAE test loss: 0.5125, train r2: 0.5528, test r2: 0.4946
# Epoch 98, MAE train loss: 0.4428, MAE test loss: 0.4727, train r2: 0.6087, test r2: 0.5732
# Epoch 99, MAE train loss: 0.4742, MAE test loss: 0.5077, train r2: 0.5893, test r2: 0.5452
# Epoch 100, MAE train loss: 0.4861, MAE test loss: 0.5104, train r2: 0.5583, test r2: 0.5194
# Epoch 101, MAE train loss: 0.4598, MAE test loss: 0.4935, train r2: 0.6068, test r2: 0.5613
# Epoch 102, MAE train loss: 0.4385, MAE test loss: 0.4731, train r2: 0.6141, test r2: 0.5618
# Epoch 103, MAE train loss: 0.4671, MAE test loss: 0.5045, train r2: 0.5873, test r2: 0.5452
# Epoch 104, MAE train loss: 0.6106, MAE test loss: 0.6279, train r2: 0.3225, test r2: 0.2897
# Epoch 105, MAE train loss: 0.5288, MAE test loss: 0.5582, train r2: 0.4935, test r2: 0.4719
# Epoch 106, MAE train loss: 0.4273, MAE test loss: 0.4702, train r2: 0.6249, test r2: 0.5785
# Epoch 107, MAE train loss: 0.4446, MAE test loss: 0.4817, train r2: 0.6014, test r2: 0.5425
# Epoch 108, MAE train loss: 0.4298, MAE test loss: 0.4664, train r2: 0.6342, test r2: 0.5874
# Epoch 109, MAE train loss: 0.4252, MAE test loss: 0.4564, train r2: 0.6348, test r2: 0.5904
# Epoch 110, MAE train loss: 0.4657, MAE test loss: 0.5035, train r2: 0.6012, test r2: 0.5428
# Epoch 111, MAE train loss: 0.4967, MAE test loss: 0.5334, train r2: 0.5628, test r2: 0.5015
# Epoch 112, MAE train loss: 0.5468, MAE test loss: 0.5770, train r2: 0.4533, test r2: 0.3933
# Epoch 113, MAE train loss: 0.4970, MAE test loss: 0.5269, train r2: 0.5596, test r2: 0.5170
# Epoch 114, MAE train loss: 0.4506, MAE test loss: 0.4859, train r2: 0.5971, test r2: 0.5381
# Epoch 115, MAE train loss: 0.5473, MAE test loss: 0.5719, train r2: 0.4818, test r2: 0.4460
# Epoch 116, MAE train loss: 0.4414, MAE test loss: 0.4821, train r2: 0.5856, test r2: 0.5429
# Epoch 117, MAE train loss: 0.4142, MAE test loss: 0.4503, train r2: 0.6349, test r2: 0.5997
# Epoch 118, MAE train loss: 0.4093, MAE test loss: 0.4453, train r2: 0.6464, test r2: 0.5919
# Epoch 119, MAE train loss: 0.4318, MAE test loss: 0.4718, train r2: 0.6268, test r2: 0.5721
# Epoch 120, MAE train loss: 0.4330, MAE test loss: 0.4675, train r2: 0.6168, test r2: 0.5796
# Epoch 121, MAE train loss: 0.4432, MAE test loss: 0.4801, train r2: 0.6065, test r2: 0.5644
# Epoch 122, MAE train loss: 0.5153, MAE test loss: 0.5528, train r2: 0.5163, test r2: 0.4404
# Epoch 123, MAE train loss: 0.4607, MAE test loss: 0.4940, train r2: 0.6093, test r2: 0.5599
# Epoch 124, MAE train loss: 0.4381, MAE test loss: 0.4739, train r2: 0.6052, test r2: 0.5567
# Epoch 125, MAE train loss: 0.4226, MAE test loss: 0.4563, train r2: 0.6386, test r2: 0.5889
# Epoch 126, MAE train loss: 0.4043, MAE test loss: 0.4417, train r2: 0.6524, test r2: 0.6006
# Epoch 127, MAE train loss: 0.5385, MAE test loss: 0.5701, train r2: 0.4859, test r2: 0.4446
# Epoch 128, MAE train loss: 0.4319, MAE test loss: 0.4695, train r2: 0.6229, test r2: 0.5576
# Epoch 129, MAE train loss: 0.4797, MAE test loss: 0.5085, train r2: 0.5895, test r2: 0.5377
# Epoch 130, MAE train loss: 0.4066, MAE test loss: 0.4431, train r2: 0.6535, test r2: 0.6039
# Epoch 131, MAE train loss: 0.4178, MAE test loss: 0.4651, train r2: 0.6190, test r2: 0.5646
# Epoch 132, MAE train loss: 0.4720, MAE test loss: 0.5088, train r2: 0.5644, test r2: 0.5013
# Epoch 133, MAE train loss: 0.4037, MAE test loss: 0.4464, train r2: 0.6582, test r2: 0.5990
# Epoch 134, MAE train loss: 0.4072, MAE test loss: 0.4514, train r2: 0.6411, test r2: 0.5768
# Epoch 135, MAE train loss: 0.4893, MAE test loss: 0.5159, train r2: 0.5782, test r2: 0.5532
# Epoch 136, MAE train loss: 0.4698, MAE test loss: 0.5046, train r2: 0.5605, test r2: 0.5041
# Epoch 137, MAE train loss: 0.4068, MAE test loss: 0.4476, train r2: 0.6515, test r2: 0.6023
# Epoch 138, MAE train loss: 0.4198, MAE test loss: 0.4512, train r2: 0.6397, test r2: 0.6086
# Epoch 139, MAE train loss: 0.4708, MAE test loss: 0.5022, train r2: 0.5701, test r2: 0.5194
# Epoch 140, MAE train loss: 0.4221, MAE test loss: 0.4645, train r2: 0.6276, test r2: 0.5653
# Epoch 141, MAE train loss: 0.4234, MAE test loss: 0.4655, train r2: 0.6304, test r2: 0.5715
# Epoch 142, MAE train loss: 0.4443, MAE test loss: 0.4704, train r2: 0.6145, test r2: 0.5775
# Epoch 143, MAE train loss: 0.4784, MAE test loss: 0.5082, train r2: 0.5822, test r2: 0.5467
# Epoch 144, MAE train loss: 0.3988, MAE test loss: 0.4454, train r2: 0.6569, test r2: 0.5924
# Epoch 145, MAE train loss: 0.4297, MAE test loss: 0.4686, train r2: 0.6176, test r2: 0.5879
# Epoch 146, MAE train loss: 0.4125, MAE test loss: 0.4554, train r2: 0.6379, test r2: 0.5771
# Epoch 147, MAE train loss: 0.5024, MAE test loss: 0.5370, train r2: 0.5428, test r2: 0.5111
# Epoch 148, MAE train loss: 0.3979, MAE test loss: 0.4396, train r2: 0.6582, test r2: 0.6074
# Epoch 149, MAE train loss: 0.4473, MAE test loss: 0.4816, train r2: 0.6266, test r2: 0.5749
# Epoch 150, MAE train loss: 0.4135, MAE test loss: 0.4557, train r2: 0.6305, test r2: 0.5667
# Epoch 151, MAE train loss: 0.3985, MAE test loss: 0.4426, train r2: 0.6583, test r2: 0.6015
# Epoch 152, MAE train loss: 0.4807, MAE test loss: 0.5221, train r2: 0.5610, test r2: 0.4808
# Epoch 153, MAE train loss: 0.4111, MAE test loss: 0.4517, train r2: 0.6361, test r2: 0.6023
# Epoch 154, MAE train loss: 0.5229, MAE test loss: 0.5570, train r2: 0.5296, test r2: 0.4887
# Epoch 155, MAE train loss: 0.5830, MAE test loss: 0.6135, train r2: 0.4011, test r2: 0.3395
# Epoch 156, MAE train loss: 0.5211, MAE test loss: 0.5531, train r2: 0.5526, test r2: 0.4896
# Epoch 157, MAE train loss: 0.4612, MAE test loss: 0.4987, train r2: 0.5832, test r2: 0.5335
# Epoch 158, MAE train loss: 0.5358, MAE test loss: 0.5682, train r2: 0.5102, test r2: 0.4592
# Epoch 159, MAE train loss: 0.4020, MAE test loss: 0.4460, train r2: 0.6515, test r2: 0.5896
# Epoch 160, MAE train loss: 0.4351, MAE test loss: 0.4779, train r2: 0.6238, test r2: 0.5598
# Epoch 161, MAE train loss: 0.4134, MAE test loss: 0.4509, train r2: 0.6581, test r2: 0.5926
# Epoch 162, MAE train loss: 0.4001, MAE test loss: 0.4455, train r2: 0.6682, test r2: 0.6072
# Epoch 163, MAE train loss: 0.4584, MAE test loss: 0.4955, train r2: 0.6216, test r2: 0.5703
# Epoch 164, MAE train loss: 0.5606, MAE test loss: 0.5996, train r2: 0.4501, test r2: 0.3686
# Epoch 165, MAE train loss: 0.4073, MAE test loss: 0.4512, train r2: 0.6610, test r2: 0.6048
# Epoch 166, MAE train loss: 0.4737, MAE test loss: 0.5078, train r2: 0.5554, test r2: 0.4971
# Epoch 167, MAE train loss: 0.4451, MAE test loss: 0.4859, train r2: 0.6144, test r2: 0.5694
# Epoch 168, MAE train loss: 0.4167, MAE test loss: 0.4623, train r2: 0.6446, test r2: 0.5813
# Epoch 169, MAE train loss: 0.4141, MAE test loss: 0.4597, train r2: 0.6408, test r2: 0.5978
# Epoch 170, MAE train loss: 0.4068, MAE test loss: 0.4512, train r2: 0.6713, test r2: 0.6092
# Epoch 171, MAE train loss: 0.3894, MAE test loss: 0.4307, train r2: 0.6700, test r2: 0.6132
# Epoch 172, MAE train loss: 0.6744, MAE test loss: 0.7008, train r2: 0.3270, test r2: 0.2745
# Epoch 173, MAE train loss: 0.4204, MAE test loss: 0.4646, train r2: 0.6316, test r2: 0.5562
# Epoch 174, MAE train loss: 0.4368, MAE test loss: 0.4776, train r2: 0.6240, test r2: 0.5546
# Epoch 175, MAE train loss: 0.3989, MAE test loss: 0.4413, train r2: 0.6655, test r2: 0.6071
# Epoch 176, MAE train loss: 0.3985, MAE test loss: 0.4457, train r2: 0.6477, test r2: 0.5949
# Epoch 177, MAE train loss: 0.4148, MAE test loss: 0.4646, train r2: 0.6409, test r2: 0.5590
# Epoch 178, MAE train loss: 0.3938, MAE test loss: 0.4437, train r2: 0.6906, test r2: 0.6174
# Epoch 179, MAE train loss: 0.4031, MAE test loss: 0.4510, train r2: 0.6654, test r2: 0.6099
# Epoch 180, MAE train loss: 0.3983, MAE test loss: 0.4478, train r2: 0.6522, test r2: 0.5794
# Epoch 181, MAE train loss: 0.4471, MAE test loss: 0.4912, train r2: 0.6162, test r2: 0.5539
# Epoch 182, MAE train loss: 0.4627, MAE test loss: 0.5032, train r2: 0.5772, test r2: 0.5095
# Epoch 183, MAE train loss: 0.4155, MAE test loss: 0.4587, train r2: 0.6732, test r2: 0.6012
# Epoch 184, MAE train loss: 0.3899, MAE test loss: 0.4371, train r2: 0.6758, test r2: 0.6105
# Epoch 185, MAE train loss: 0.4644, MAE test loss: 0.5058, train r2: 0.5834, test r2: 0.5099
# Epoch 186, MAE train loss: 0.3999, MAE test loss: 0.4398, train r2: 0.6476, test r2: 0.5941
# Epoch 187, MAE train loss: 0.4437, MAE test loss: 0.4831, train r2: 0.6015, test r2: 0.5511
# Epoch 188, MAE train loss: 0.4173, MAE test loss: 0.4540, train r2: 0.6283, test r2: 0.5788
# Epoch 189, MAE train loss: 0.3898, MAE test loss: 0.4409, train r2: 0.6814, test r2: 0.6141
# Epoch 190, MAE train loss: 0.5656, MAE test loss: 0.6013, train r2: 0.4520, test r2: 0.4139
# Epoch 191, MAE train loss: 0.5831, MAE test loss: 0.6126, train r2: 0.4053, test r2: 0.3275
# Epoch 192, MAE train loss: 0.4732, MAE test loss: 0.5111, train r2: 0.5944, test r2: 0.5318
# Epoch 193, MAE train loss: 0.6044, MAE test loss: 0.6498, train r2: 0.3445, test r2: 0.2559
# Epoch 194, MAE train loss: 0.5766, MAE test loss: 0.6160, train r2: 0.4528, test r2: 0.3912
# Epoch 195, MAE train loss: 0.3903, MAE test loss: 0.4345, train r2: 0.6782, test r2: 0.6097
# Epoch 196, MAE train loss: 0.4356, MAE test loss: 0.4853, train r2: 0.6350, test r2: 0.5644
# Epoch 197, MAE train loss: 0.4306, MAE test loss: 0.4725, train r2: 0.6386, test r2: 0.5775
# Epoch 198, MAE train loss: 0.3878, MAE test loss: 0.4385, train r2: 0.6892, test r2: 0.6172
# Epoch 199, MAE train loss: 0.3799, MAE test loss: 0.4298, train r2: 0.6767, test r2: 0.6150
# Epoch 200, MAE train loss: 0.3948, MAE test loss: 0.4455, train r2: 0.6605, test r2: 0.5965
# Epoch 201, MAE train loss: 0.3733, MAE test loss: 0.4201, train r2: 0.6767, test r2: 0.6242
# Epoch 202, MAE train loss: 0.3742, MAE test loss: 0.4221, train r2: 0.6905, test r2: 0.6281
# Epoch 203, MAE train loss: 0.3784, MAE test loss: 0.4244, train r2: 0.6952, test r2: 0.6369
# Epoch 204, MAE train loss: 0.3672, MAE test loss: 0.4155, train r2: 0.7041, test r2: 0.6314
# Epoch 205, MAE train loss: 0.3658, MAE test loss: 0.4113, train r2: 0.6871, test r2: 0.6339
# Epoch 206, MAE train loss: 0.3675, MAE test loss: 0.4199, train r2: 0.7020, test r2: 0.6376
# Epoch 207, MAE train loss: 0.3982, MAE test loss: 0.4439, train r2: 0.6655, test r2: 0.5957
# Epoch 208, MAE train loss: 0.3744, MAE test loss: 0.4250, train r2: 0.6965, test r2: 0.6273
# Epoch 209, MAE train loss: 0.4244, MAE test loss: 0.4650, train r2: 0.6410, test r2: 0.5955
# Epoch 210, MAE train loss: 0.3722, MAE test loss: 0.4256, train r2: 0.6922, test r2: 0.6262
# Epoch 211, MAE train loss: 0.3724, MAE test loss: 0.4188, train r2: 0.6790, test r2: 0.6316
# Epoch 212, MAE train loss: 0.3619, MAE test loss: 0.4129, train r2: 0.6942, test r2: 0.6370
# Epoch 213, MAE train loss: 0.3687, MAE test loss: 0.4154, train r2: 0.6917, test r2: 0.6310
# Epoch 214, MAE train loss: 0.3827, MAE test loss: 0.4284, train r2: 0.6945, test r2: 0.6330
# Epoch 215, MAE train loss: 0.3984, MAE test loss: 0.4444, train r2: 0.6647, test r2: 0.5927
# Epoch 216, MAE train loss: 0.4142, MAE test loss: 0.4576, train r2: 0.6476, test r2: 0.5819
# Epoch 217, MAE train loss: 0.4164, MAE test loss: 0.4564, train r2: 0.6765, test r2: 0.6170
# Epoch 218, MAE train loss: 0.3882, MAE test loss: 0.4374, train r2: 0.6781, test r2: 0.6054
# Epoch 219, MAE train loss: 0.3937, MAE test loss: 0.4420, train r2: 0.6800, test r2: 0.6189
# Epoch 220, MAE train loss: 0.3674, MAE test loss: 0.4217, train r2: 0.6965, test r2: 0.6312
# Epoch 221, MAE train loss: 0.3799, MAE test loss: 0.4339, train r2: 0.6785, test r2: 0.6305
# Epoch 222, MAE train loss: 0.3593, MAE test loss: 0.4162, train r2: 0.7058, test r2: 0.6341
# Epoch 223, MAE train loss: 0.3702, MAE test loss: 0.4143, train r2: 0.6960, test r2: 0.6379
# Epoch 224, MAE train loss: 0.3673, MAE test loss: 0.4174, train r2: 0.6969, test r2: 0.6404
# Epoch 225, MAE train loss: 0.3608, MAE test loss: 0.4115, train r2: 0.7021, test r2: 0.6398
# Epoch 226, MAE train loss: 0.4188, MAE test loss: 0.4685, train r2: 0.6326, test r2: 0.5622
# Epoch 227, MAE train loss: 0.3752, MAE test loss: 0.4294, train r2: 0.6957, test r2: 0.6405
# Epoch 228, MAE train loss: 0.4102, MAE test loss: 0.4552, train r2: 0.6719, test r2: 0.6090
# Epoch 229, MAE train loss: 0.3821, MAE test loss: 0.4294, train r2: 0.6945, test r2: 0.6279
# Epoch 230, MAE train loss: 0.3575, MAE test loss: 0.4113, train r2: 0.7011, test r2: 0.6282
# Epoch 231, MAE train loss: 0.3918, MAE test loss: 0.4352, train r2: 0.6777, test r2: 0.6278
# Epoch 232, MAE train loss: 0.4368, MAE test loss: 0.4855, train r2: 0.6158, test r2: 0.5358
# Epoch 233, MAE train loss: 0.3768, MAE test loss: 0.4226, train r2: 0.6914, test r2: 0.6442
# Epoch 234, MAE train loss: 0.3930, MAE test loss: 0.4412, train r2: 0.6720, test r2: 0.6219
# Epoch 235, MAE train loss: 0.5265, MAE test loss: 0.5707, train r2: 0.4880, test r2: 0.3976
# Epoch 236, MAE train loss: 0.3565, MAE test loss: 0.4090, train r2: 0.7129, test r2: 0.6378
# Epoch 237, MAE train loss: 0.3614, MAE test loss: 0.4132, train r2: 0.7112, test r2: 0.6414
# Epoch 238, MAE train loss: 0.3768, MAE test loss: 0.4263, train r2: 0.6952, test r2: 0.6287
# Epoch 239, MAE train loss: 0.3629, MAE test loss: 0.4174, train r2: 0.6929, test r2: 0.6304
# Epoch 240, MAE train loss: 0.4210, MAE test loss: 0.4683, train r2: 0.6635, test r2: 0.6029
# Epoch 241, MAE train loss: 0.3710, MAE test loss: 0.4278, train r2: 0.6950, test r2: 0.6160
# Epoch 242, MAE train loss: 0.3591, MAE test loss: 0.4138, train r2: 0.7071, test r2: 0.6406
# Epoch 243, MAE train loss: 0.3763, MAE test loss: 0.4245, train r2: 0.6966, test r2: 0.6368
# Epoch 244, MAE train loss: 0.4238, MAE test loss: 0.4702, train r2: 0.6243, test r2: 0.5556
# Epoch 245, MAE train loss: 0.3860, MAE test loss: 0.4314, train r2: 0.6961, test r2: 0.6274
# Epoch 246, MAE train loss: 0.3780, MAE test loss: 0.4296, train r2: 0.7052, test r2: 0.6370
# Epoch 247, MAE train loss: 0.3916, MAE test loss: 0.4412, train r2: 0.6771, test r2: 0.5976
# Epoch 248, MAE train loss: 0.3522, MAE test loss: 0.4068, train r2: 0.7219, test r2: 0.6418
# Epoch 249, MAE train loss: 0.3624, MAE test loss: 0.4104, train r2: 0.6953, test r2: 0.6428
# Epoch 250, MAE train loss: 0.3660, MAE test loss: 0.4169, train r2: 0.7098, test r2: 0.6397
# Epoch 251, MAE train loss: 0.3581, MAE test loss: 0.4075, train r2: 0.7005, test r2: 0.6417
# Epoch 252, MAE train loss: 0.3711, MAE test loss: 0.4258, train r2: 0.7027, test r2: 0.6269
# Epoch 253, MAE train loss: 0.3667, MAE test loss: 0.4168, train r2: 0.7138, test r2: 0.6573
# Epoch 254, MAE train loss: 0.3517, MAE test loss: 0.4056, train r2: 0.7241, test r2: 0.6490
# Epoch 255, MAE train loss: 0.3500, MAE test loss: 0.4076, train r2: 0.7266, test r2: 0.6491
# Epoch 256, MAE train loss: 0.3615, MAE test loss: 0.4126, train r2: 0.7192, test r2: 0.6447
# Epoch 257, MAE train loss: 0.3871, MAE test loss: 0.4373, train r2: 0.6791, test r2: 0.6212
# Epoch 258, MAE train loss: 0.3674, MAE test loss: 0.4202, train r2: 0.7143, test r2: 0.6439
# Epoch 259, MAE train loss: 0.3827, MAE test loss: 0.4352, train r2: 0.6835, test r2: 0.6115
# Epoch 260, MAE train loss: 0.3644, MAE test loss: 0.4163, train r2: 0.7143, test r2: 0.6441
# Epoch 261, MAE train loss: 0.3819, MAE test loss: 0.4310, train r2: 0.6864, test r2: 0.6166
# Epoch 262, MAE train loss: 0.3507, MAE test loss: 0.4047, train r2: 0.7224, test r2: 0.6479
# Epoch 263, MAE train loss: 0.3572, MAE test loss: 0.4106, train r2: 0.7050, test r2: 0.6343
# Epoch 264, MAE train loss: 0.3522, MAE test loss: 0.4058, train r2: 0.7237, test r2: 0.6495
# Epoch 265, MAE train loss: 0.3687, MAE test loss: 0.4187, train r2: 0.7025, test r2: 0.6430
# Epoch 266, MAE train loss: 0.3801, MAE test loss: 0.4251, train r2: 0.6933, test r2: 0.6325
# Epoch 267, MAE train loss: 0.3548, MAE test loss: 0.4048, train r2: 0.7194, test r2: 0.6571
# Epoch 268, MAE train loss: 0.3557, MAE test loss: 0.4073, train r2: 0.7163, test r2: 0.6479
# Epoch 269, MAE train loss: 0.3657, MAE test loss: 0.4164, train r2: 0.7039, test r2: 0.6288
# Epoch 270, MAE train loss: 0.3587, MAE test loss: 0.4089, train r2: 0.6955, test r2: 0.6461
# Epoch 271, MAE train loss: 0.3612, MAE test loss: 0.4088, train r2: 0.7149, test r2: 0.6536
# Epoch 272, MAE train loss: 0.3740, MAE test loss: 0.4275, train r2: 0.6783, test r2: 0.6164
# Epoch 273, MAE train loss: 0.3504, MAE test loss: 0.4018, train r2: 0.7151, test r2: 0.6525
# Epoch 274, MAE train loss: 0.3577, MAE test loss: 0.4108, train r2: 0.6981, test r2: 0.6524
# Epoch 275, MAE train loss: 0.4012, MAE test loss: 0.4488, train r2: 0.6584, test r2: 0.5890
# Epoch 276, MAE train loss: 0.3553, MAE test loss: 0.4076, train r2: 0.7129, test r2: 0.6463
# Epoch 277, MAE train loss: 0.3548, MAE test loss: 0.4100, train r2: 0.7092, test r2: 0.6380
# Epoch 278, MAE train loss: 0.3564, MAE test loss: 0.4074, train r2: 0.7049, test r2: 0.6454
# Epoch 279, MAE train loss: 0.3402, MAE test loss: 0.3968, train r2: 0.7135, test r2: 0.6496
# Epoch 280, MAE train loss: 0.3667, MAE test loss: 0.4233, train r2: 0.6994, test r2: 0.6430
# Epoch 281, MAE train loss: 0.3732, MAE test loss: 0.4195, train r2: 0.6873, test r2: 0.6316
# Epoch 282, MAE train loss: 0.3713, MAE test loss: 0.4226, train r2: 0.7158, test r2: 0.6516
# Epoch 283, MAE train loss: 0.3465, MAE test loss: 0.3969, train r2: 0.7271, test r2: 0.6576
# Epoch 284, MAE train loss: 0.3599, MAE test loss: 0.4111, train r2: 0.7008, test r2: 0.6449
# Epoch 285, MAE train loss: 0.3870, MAE test loss: 0.4364, train r2: 0.6933, test r2: 0.6288
# Epoch 286, MAE train loss: 0.3714, MAE test loss: 0.4198, train r2: 0.7090, test r2: 0.6382
# Epoch 287, MAE train loss: 0.3445, MAE test loss: 0.3993, train r2: 0.7241, test r2: 0.6523
# Epoch 288, MAE train loss: 0.3507, MAE test loss: 0.4048, train r2: 0.7202, test r2: 0.6568
# Epoch 289, MAE train loss: 0.3653, MAE test loss: 0.4199, train r2: 0.7085, test r2: 0.6334
# Epoch 290, MAE train loss: 0.4339, MAE test loss: 0.4746, train r2: 0.6154, test r2: 0.5561
# Epoch 291, MAE train loss: 0.3618, MAE test loss: 0.4145, train r2: 0.7299, test r2: 0.6627
# Epoch 292, MAE train loss: 0.3564, MAE test loss: 0.4047, train r2: 0.7153, test r2: 0.6629
# Epoch 293, MAE train loss: 0.3537, MAE test loss: 0.4004, train r2: 0.7031, test r2: 0.6584
# Epoch 294, MAE train loss: 0.3485, MAE test loss: 0.3958, train r2: 0.7261, test r2: 0.6574
# Epoch 295, MAE train loss: 0.3766, MAE test loss: 0.4271, train r2: 0.7007, test r2: 0.6455
# Epoch 296, MAE train loss: 0.3443, MAE test loss: 0.4009, train r2: 0.7218, test r2: 0.6464
# Epoch 297, MAE train loss: 0.3587, MAE test loss: 0.4109, train r2: 0.7155, test r2: 0.6506
# Epoch 298, MAE train loss: 0.3573, MAE test loss: 0.4094, train r2: 0.7264, test r2: 0.6587
# Epoch 299, MAE train loss: 0.3538, MAE test loss: 0.4099, train r2: 0.7137, test r2: 0.6400
# Epoch 300, MAE train loss: 0.3619, MAE test loss: 0.4109, train r2: 0.7028, test r2: 0.6427
# Epoch 301, MAE train loss: 0.3366, MAE test loss: 0.3941, train r2: 0.7333, test r2: 0.6612
# Epoch 302, MAE train loss: 0.3370, MAE test loss: 0.3930, train r2: 0.7331, test r2: 0.6605
# Epoch 303, MAE train loss: 0.3303, MAE test loss: 0.3918, train r2: 0.7426, test r2: 0.6599
# Epoch 304, MAE train loss: 0.3454, MAE test loss: 0.3955, train r2: 0.7252, test r2: 0.6600
# Epoch 305, MAE train loss: 0.3391, MAE test loss: 0.3937, train r2: 0.7357, test r2: 0.6624
# Epoch 306, MAE train loss: 0.3405, MAE test loss: 0.3961, train r2: 0.7270, test r2: 0.6631
# Epoch 307, MAE train loss: 0.3480, MAE test loss: 0.4013, train r2: 0.7328, test r2: 0.6631
# Epoch 308, MAE train loss: 0.3345, MAE test loss: 0.3936, train r2: 0.7367, test r2: 0.6614
# Epoch 309, MAE train loss: 0.3374, MAE test loss: 0.3947, train r2: 0.7356, test r2: 0.6645
# Epoch 310, MAE train loss: 0.3623, MAE test loss: 0.4163, train r2: 0.6949, test r2: 0.6314
# Epoch 311, MAE train loss: 0.3556, MAE test loss: 0.4109, train r2: 0.7004, test r2: 0.6369
# Epoch 312, MAE train loss: 0.3685, MAE test loss: 0.4209, train r2: 0.7113, test r2: 0.6464
# Epoch 313, MAE train loss: 0.3351, MAE test loss: 0.3953, train r2: 0.7416, test r2: 0.6610
# Epoch 314, MAE train loss: 0.3615, MAE test loss: 0.4166, train r2: 0.7074, test r2: 0.6449
# Epoch 315, MAE train loss: 0.3332, MAE test loss: 0.3943, train r2: 0.7357, test r2: 0.6583
# Epoch 316, MAE train loss: 0.3424, MAE test loss: 0.3973, train r2: 0.7280, test r2: 0.6643
# Epoch 317, MAE train loss: 0.3493, MAE test loss: 0.4102, train r2: 0.7118, test r2: 0.6392
# Epoch 318, MAE train loss: 0.3383, MAE test loss: 0.3990, train r2: 0.7314, test r2: 0.6559
# Epoch 319, MAE train loss: 0.3438, MAE test loss: 0.4016, train r2: 0.7277, test r2: 0.6639
# Epoch 320, MAE train loss: 0.3497, MAE test loss: 0.4077, train r2: 0.7336, test r2: 0.6590
# Epoch 321, MAE train loss: 0.3593, MAE test loss: 0.4110, train r2: 0.7093, test r2: 0.6618
# Epoch 322, MAE train loss: 0.3377, MAE test loss: 0.3957, train r2: 0.7333, test r2: 0.6581
# Epoch 323, MAE train loss: 0.3389, MAE test loss: 0.3946, train r2: 0.7428, test r2: 0.6690
# Epoch 324, MAE train loss: 0.3402, MAE test loss: 0.3976, train r2: 0.7414, test r2: 0.6670
# Epoch 325, MAE train loss: 0.3392, MAE test loss: 0.3942, train r2: 0.7307, test r2: 0.6658
# Epoch 326, MAE train loss: 0.3498, MAE test loss: 0.4030, train r2: 0.7329, test r2: 0.6614
# Epoch 327, MAE train loss: 0.3347, MAE test loss: 0.3939, train r2: 0.7324, test r2: 0.6642
# Epoch 328, MAE train loss: 0.3457, MAE test loss: 0.4016, train r2: 0.7285, test r2: 0.6491
# Epoch 329, MAE train loss: 0.3572, MAE test loss: 0.4156, train r2: 0.7130, test r2: 0.6310
# Epoch 330, MAE train loss: 0.3301, MAE test loss: 0.3943, train r2: 0.7386, test r2: 0.6632
# Epoch 331, MAE train loss: 0.4279, MAE test loss: 0.4684, train r2: 0.6404, test r2: 0.6053
# Epoch 332, MAE train loss: 0.3399, MAE test loss: 0.3982, train r2: 0.7297, test r2: 0.6527
# Epoch 333, MAE train loss: 0.3396, MAE test loss: 0.4003, train r2: 0.7279, test r2: 0.6489
# Epoch 334, MAE train loss: 0.3353, MAE test loss: 0.3950, train r2: 0.7255, test r2: 0.6561
# Epoch 335, MAE train loss: 0.3370, MAE test loss: 0.3957, train r2: 0.7353, test r2: 0.6601
# Epoch 336, MAE train loss: 0.3710, MAE test loss: 0.4287, train r2: 0.7188, test r2: 0.6459
# Epoch 337, MAE train loss: 0.3368, MAE test loss: 0.3959, train r2: 0.7315, test r2: 0.6592
# Epoch 338, MAE train loss: 0.3504, MAE test loss: 0.4029, train r2: 0.7247, test r2: 0.6595
# Epoch 339, MAE train loss: 0.3403, MAE test loss: 0.3977, train r2: 0.7281, test r2: 0.6546
# Epoch 340, MAE train loss: 0.3473, MAE test loss: 0.4052, train r2: 0.7229, test r2: 0.6471
# Epoch 341, MAE train loss: 0.3317, MAE test loss: 0.3898, train r2: 0.7466, test r2: 0.6703
# Epoch 342, MAE train loss: 0.3638, MAE test loss: 0.4197, train r2: 0.7182, test r2: 0.6450
# Epoch 343, MAE train loss: 0.3763, MAE test loss: 0.4310, train r2: 0.7053, test r2: 0.6443
# Epoch 344, MAE train loss: 0.3406, MAE test loss: 0.3942, train r2: 0.7335, test r2: 0.6635
# Epoch 345, MAE train loss: 0.3423, MAE test loss: 0.3969, train r2: 0.7286, test r2: 0.6592
# Epoch 346, MAE train loss: 0.3367, MAE test loss: 0.3962, train r2: 0.7253, test r2: 0.6673
# Epoch 347, MAE train loss: 0.3390, MAE test loss: 0.3923, train r2: 0.7394, test r2: 0.6686
# Epoch 348, MAE train loss: 0.3322, MAE test loss: 0.3930, train r2: 0.7401, test r2: 0.6667
# Epoch 349, MAE train loss: 0.3599, MAE test loss: 0.4132, train r2: 0.7279, test r2: 0.6636
# Epoch 350, MAE train loss: 0.3342, MAE test loss: 0.3902, train r2: 0.7414, test r2: 0.6668
# Epoch 351, MAE train loss: 0.3373, MAE test loss: 0.3929, train r2: 0.7383, test r2: 0.6670
# Epoch 352, MAE train loss: 0.3328, MAE test loss: 0.3911, train r2: 0.7390, test r2: 0.6694
# Epoch 353, MAE train loss: 0.3487, MAE test loss: 0.3975, train r2: 0.7349, test r2: 0.6726
# Epoch 354, MAE train loss: 0.3348, MAE test loss: 0.3927, train r2: 0.7298, test r2: 0.6602
# Epoch 355, MAE train loss: 0.3670, MAE test loss: 0.4198, train r2: 0.6952, test r2: 0.6242
# Epoch 356, MAE train loss: 0.3363, MAE test loss: 0.3968, train r2: 0.7447, test r2: 0.6718
# Epoch 357, MAE train loss: 0.3305, MAE test loss: 0.3869, train r2: 0.7330, test r2: 0.6689
# Epoch 358, MAE train loss: 0.3630, MAE test loss: 0.4198, train r2: 0.7213, test r2: 0.6532
# Epoch 359, MAE train loss: 0.3300, MAE test loss: 0.3890, train r2: 0.7448, test r2: 0.6702
# Epoch 360, MAE train loss: 0.3552, MAE test loss: 0.4065, train r2: 0.7204, test r2: 0.6447
# Epoch 361, MAE train loss: 0.3323, MAE test loss: 0.3924, train r2: 0.7339, test r2: 0.6701
# Epoch 362, MAE train loss: 0.3350, MAE test loss: 0.3919, train r2: 0.7445, test r2: 0.6756
# Epoch 363, MAE train loss: 0.3367, MAE test loss: 0.3946, train r2: 0.7432, test r2: 0.6736
# Epoch 364, MAE train loss: 0.3253, MAE test loss: 0.3874, train r2: 0.7531, test r2: 0.6753
# Epoch 365, MAE train loss: 0.3219, MAE test loss: 0.3843, train r2: 0.7503, test r2: 0.6677
# Epoch 366, MAE train loss: 0.3353, MAE test loss: 0.3933, train r2: 0.7541, test r2: 0.6749
# Epoch 367, MAE train loss: 0.3336, MAE test loss: 0.3934, train r2: 0.7530, test r2: 0.6702
# Epoch 368, MAE train loss: 0.3306, MAE test loss: 0.3886, train r2: 0.7520, test r2: 0.6728
# Epoch 369, MAE train loss: 0.3379, MAE test loss: 0.3963, train r2: 0.7352, test r2: 0.6677
# Epoch 370, MAE train loss: 0.3337, MAE test loss: 0.3964, train r2: 0.7455, test r2: 0.6710
# Epoch 371, MAE train loss: 0.3334, MAE test loss: 0.3930, train r2: 0.7407, test r2: 0.6653
# Epoch 372, MAE train loss: 0.3326, MAE test loss: 0.3920, train r2: 0.7479, test r2: 0.6694
# Epoch 373, MAE train loss: 0.3315, MAE test loss: 0.3903, train r2: 0.7334, test r2: 0.6656
# Epoch 374, MAE train loss: 0.3279, MAE test loss: 0.3895, train r2: 0.7451, test r2: 0.6654
# Epoch 375, MAE train loss: 0.3551, MAE test loss: 0.4113, train r2: 0.7149, test r2: 0.6396
# Epoch 376, MAE train loss: 0.3264, MAE test loss: 0.3892, train r2: 0.7457, test r2: 0.6655
# Epoch 377, MAE train loss: 0.3721, MAE test loss: 0.4253, train r2: 0.7064, test r2: 0.6480
# Epoch 378, MAE train loss: 0.3281, MAE test loss: 0.3899, train r2: 0.7471, test r2: 0.6701
# Epoch 379, MAE train loss: 0.3291, MAE test loss: 0.3925, train r2: 0.7480, test r2: 0.6646
# Epoch 380, MAE train loss: 0.3270, MAE test loss: 0.3889, train r2: 0.7294, test r2: 0.6682
# Epoch 381, MAE train loss: 0.3291, MAE test loss: 0.3879, train r2: 0.7478, test r2: 0.6716
# Epoch 382, MAE train loss: 0.3470, MAE test loss: 0.4064, train r2: 0.7298, test r2: 0.6419
# Epoch 383, MAE train loss: 0.3407, MAE test loss: 0.3940, train r2: 0.7258, test r2: 0.6652
# Epoch 384, MAE train loss: 0.3276, MAE test loss: 0.3880, train r2: 0.7533, test r2: 0.6720
# Epoch 385, MAE train loss: 0.3339, MAE test loss: 0.3920, train r2: 0.7424, test r2: 0.6662
# Epoch 386, MAE train loss: 0.3289, MAE test loss: 0.3897, train r2: 0.7434, test r2: 0.6689
# Epoch 387, MAE train loss: 0.3361, MAE test loss: 0.3975, train r2: 0.7496, test r2: 0.6692
# Epoch 388, MAE train loss: 0.3368, MAE test loss: 0.3981, train r2: 0.7420, test r2: 0.6677
# Epoch 389, MAE train loss: 0.3240, MAE test loss: 0.3889, train r2: 0.7533, test r2: 0.6721
# Epoch 390, MAE train loss: 0.3368, MAE test loss: 0.3914, train r2: 0.7313, test r2: 0.6701
# Epoch 391, MAE train loss: 0.3410, MAE test loss: 0.4011, train r2: 0.7345, test r2: 0.6531
# Epoch 392, MAE train loss: 0.3413, MAE test loss: 0.3987, train r2: 0.7391, test r2: 0.6667
# Epoch 393, MAE train loss: 0.3330, MAE test loss: 0.3910, train r2: 0.7429, test r2: 0.6679
# Epoch 394, MAE train loss: 0.3501, MAE test loss: 0.4082, train r2: 0.7315, test r2: 0.6599
# Epoch 395, MAE train loss: 0.3272, MAE test loss: 0.3898, train r2: 0.7431, test r2: 0.6728
# Epoch 396, MAE train loss: 0.3426, MAE test loss: 0.4039, train r2: 0.7271, test r2: 0.6530
# Epoch 397, MAE train loss: 0.3328, MAE test loss: 0.3910, train r2: 0.7492, test r2: 0.6737
# Epoch 398, MAE train loss: 0.3304, MAE test loss: 0.3882, train r2: 0.7518, test r2: 0.6760
# Epoch 399, MAE train loss: 0.3428, MAE test loss: 0.3981, train r2: 0.7357, test r2: 0.6650
# Epoch 400, MAE train loss: 0.3338, MAE test loss: 0.3940, train r2: 0.7399, test r2: 0.6566
# Epoch 401, MAE train loss: 0.3262, MAE test loss: 0.3882, train r2: 0.7480, test r2: 0.6744
# Epoch 402, MAE train loss: 0.3274, MAE test loss: 0.3884, train r2: 0.7449, test r2: 0.6733
# Epoch 403, MAE train loss: 0.3288, MAE test loss: 0.3859, train r2: 0.7457, test r2: 0.6734
# Epoch 404, MAE train loss: 0.3270, MAE test loss: 0.3900, train r2: 0.7516, test r2: 0.6726
# Epoch 405, MAE train loss: 0.3234, MAE test loss: 0.3848, train r2: 0.7468, test r2: 0.6736
# Epoch 406, MAE train loss: 0.3212, MAE test loss: 0.3824, train r2: 0.7527, test r2: 0.6767
# Epoch 407, MAE train loss: 0.3280, MAE test loss: 0.3865, train r2: 0.7306, test r2: 0.6721
# Epoch 408, MAE train loss: 0.3235, MAE test loss: 0.3872, train r2: 0.7502, test r2: 0.6698
# Epoch 409, MAE train loss: 0.3276, MAE test loss: 0.3868, train r2: 0.7501, test r2: 0.6766
# Epoch 410, MAE train loss: 0.3209, MAE test loss: 0.3843, train r2: 0.7510, test r2: 0.6752
# Epoch 411, MAE train loss: 0.3197, MAE test loss: 0.3833, train r2: 0.7502, test r2: 0.6731
# Epoch 412, MAE train loss: 0.3225, MAE test loss: 0.3844, train r2: 0.7520, test r2: 0.6743
# Epoch 413, MAE train loss: 0.3209, MAE test loss: 0.3831, train r2: 0.7549, test r2: 0.6767
# Epoch 414, MAE train loss: 0.3241, MAE test loss: 0.3875, train r2: 0.7526, test r2: 0.6723
# Epoch 415, MAE train loss: 0.3237, MAE test loss: 0.3856, train r2: 0.7447, test r2: 0.6743
# Epoch 416, MAE train loss: 0.3276, MAE test loss: 0.3877, train r2: 0.7543, test r2: 0.6753
# Epoch 417, MAE train loss: 0.3217, MAE test loss: 0.3847, train r2: 0.7583, test r2: 0.6758
# Epoch 418, MAE train loss: 0.3339, MAE test loss: 0.3894, train r2: 0.7433, test r2: 0.6681
# Epoch 419, MAE train loss: 0.3288, MAE test loss: 0.3884, train r2: 0.7460, test r2: 0.6762
# Epoch 420, MAE train loss: 0.3362, MAE test loss: 0.3936, train r2: 0.7416, test r2: 0.6725
# Epoch 421, MAE train loss: 0.3240, MAE test loss: 0.3856, train r2: 0.7455, test r2: 0.6742
# Epoch 422, MAE train loss: 0.3184, MAE test loss: 0.3838, train r2: 0.7438, test r2: 0.6673
# Epoch 423, MAE train loss: 0.3299, MAE test loss: 0.3852, train r2: 0.7438, test r2: 0.6780
# Epoch 424, MAE train loss: 0.3253, MAE test loss: 0.3874, train r2: 0.7453, test r2: 0.6728
# Epoch 425, MAE train loss: 0.3299, MAE test loss: 0.3898, train r2: 0.7484, test r2: 0.6764
# Epoch 426, MAE train loss: 0.3234, MAE test loss: 0.3861, train r2: 0.7567, test r2: 0.6755
# Epoch 427, MAE train loss: 0.3216, MAE test loss: 0.3821, train r2: 0.7526, test r2: 0.6744
# Epoch 428, MAE train loss: 0.3187, MAE test loss: 0.3823, train r2: 0.7518, test r2: 0.6724
# Epoch 429, MAE train loss: 0.3316, MAE test loss: 0.3928, train r2: 0.7488, test r2: 0.6727
# Epoch 430, MAE train loss: 0.3162, MAE test loss: 0.3818, train r2: 0.7573, test r2: 0.6745
# Epoch 431, MAE train loss: 0.3207, MAE test loss: 0.3838, train r2: 0.7570, test r2: 0.6758
# Epoch 432, MAE train loss: 0.3258, MAE test loss: 0.3871, train r2: 0.7546, test r2: 0.6747
# Epoch 433, MAE train loss: 0.3209, MAE test loss: 0.3822, train r2: 0.7478, test r2: 0.6726
# Epoch 434, MAE train loss: 0.3179, MAE test loss: 0.3821, train r2: 0.7562, test r2: 0.6751
# Epoch 435, MAE train loss: 0.3218, MAE test loss: 0.3858, train r2: 0.7526, test r2: 0.6742
# Epoch 436, MAE train loss: 0.3320, MAE test loss: 0.3919, train r2: 0.7502, test r2: 0.6720
# Epoch 437, MAE train loss: 0.3236, MAE test loss: 0.3865, train r2: 0.7497, test r2: 0.6770
# Epoch 438, MAE train loss: 0.3233, MAE test loss: 0.3852, train r2: 0.7563, test r2: 0.6778
# Epoch 439, MAE train loss: 0.3281, MAE test loss: 0.3864, train r2: 0.7470, test r2: 0.6731
# Epoch 440, MAE train loss: 0.3267, MAE test loss: 0.3868, train r2: 0.7403, test r2: 0.6696
# Epoch 441, MAE train loss: 0.3280, MAE test loss: 0.3869, train r2: 0.7517, test r2: 0.6782
# Epoch 442, MAE train loss: 0.3482, MAE test loss: 0.4052, train r2: 0.7292, test r2: 0.6659
# Epoch 443, MAE train loss: 0.3304, MAE test loss: 0.3845, train r2: 0.7455, test r2: 0.6797
# Epoch 444, MAE train loss: 0.3307, MAE test loss: 0.3894, train r2: 0.7362, test r2: 0.6667
# Epoch 445, MAE train loss: 0.3181, MAE test loss: 0.3813, train r2: 0.7516, test r2: 0.6791
# Epoch 446, MAE train loss: 0.3230, MAE test loss: 0.3838, train r2: 0.7461, test r2: 0.6769
# Epoch 447, MAE train loss: 0.3225, MAE test loss: 0.3857, train r2: 0.7577, test r2: 0.6743
# Epoch 448, MAE train loss: 0.3283, MAE test loss: 0.3863, train r2: 0.7445, test r2: 0.6756
# Epoch 449, MAE train loss: 0.3289, MAE test loss: 0.3890, train r2: 0.7591, test r2: 0.6810
# Epoch 450, MAE train loss: 0.3228, MAE test loss: 0.3796, train r2: 0.7447, test r2: 0.6811
# Epoch 451, MAE train loss: 0.3144, MAE test loss: 0.3786, train r2: 0.7535, test r2: 0.6769
# Epoch 452, MAE train loss: 0.3274, MAE test loss: 0.3877, train r2: 0.7514, test r2: 0.6738
# Epoch 453, MAE train loss: 0.3344, MAE test loss: 0.3948, train r2: 0.7469, test r2: 0.6731
# Epoch 454, MAE train loss: 0.3245, MAE test loss: 0.3834, train r2: 0.7385, test r2: 0.6781
# Epoch 455, MAE train loss: 0.3193, MAE test loss: 0.3816, train r2: 0.7519, test r2: 0.6775
# Epoch 456, MAE train loss: 0.3219, MAE test loss: 0.3845, train r2: 0.7608, test r2: 0.6786
# Epoch 457, MAE train loss: 0.3322, MAE test loss: 0.3907, train r2: 0.7459, test r2: 0.6767
# Epoch 458, MAE train loss: 0.3234, MAE test loss: 0.3861, train r2: 0.7491, test r2: 0.6798
# Epoch 459, MAE train loss: 0.3238, MAE test loss: 0.3839, train r2: 0.7494, test r2: 0.6761
# Epoch 460, MAE train loss: 0.3221, MAE test loss: 0.3802, train r2: 0.7528, test r2: 0.6804
# Epoch 461, MAE train loss: 0.3243, MAE test loss: 0.3828, train r2: 0.7351, test r2: 0.6711
# Epoch 462, MAE train loss: 0.3245, MAE test loss: 0.3820, train r2: 0.7548, test r2: 0.6809
# Epoch 463, MAE train loss: 0.3219, MAE test loss: 0.3842, train r2: 0.7535, test r2: 0.6802
# Epoch 464, MAE train loss: 0.3236, MAE test loss: 0.3825, train r2: 0.7555, test r2: 0.6795
# Epoch 465, MAE train loss: 0.3211, MAE test loss: 0.3819, train r2: 0.7482, test r2: 0.6796
# Epoch 466, MAE train loss: 0.3237, MAE test loss: 0.3898, train r2: 0.7623, test r2: 0.6789
# Epoch 467, MAE train loss: 0.3150, MAE test loss: 0.3801, train r2: 0.7614, test r2: 0.6800
# Epoch 468, MAE train loss: 0.3159, MAE test loss: 0.3816, train r2: 0.7572, test r2: 0.6790
# Epoch 469, MAE train loss: 0.3233, MAE test loss: 0.3865, train r2: 0.7546, test r2: 0.6803
# Epoch 470, MAE train loss: 0.3296, MAE test loss: 0.3872, train r2: 0.7498, test r2: 0.6814
# Epoch 471, MAE train loss: 0.3212, MAE test loss: 0.3806, train r2: 0.7495, test r2: 0.6788
# Epoch 472, MAE train loss: 0.3263, MAE test loss: 0.3849, train r2: 0.7461, test r2: 0.6787
# Epoch 473, MAE train loss: 0.3191, MAE test loss: 0.3833, train r2: 0.7598, test r2: 0.6784
# Epoch 474, MAE train loss: 0.3201, MAE test loss: 0.3812, train r2: 0.7603, test r2: 0.6780
# Epoch 475, MAE train loss: 0.3198, MAE test loss: 0.3801, train r2: 0.7545, test r2: 0.6809
# Epoch 476, MAE train loss: 0.3236, MAE test loss: 0.3800, train r2: 0.7460, test r2: 0.6817
# Epoch 477, MAE train loss: 0.3156, MAE test loss: 0.3799, train r2: 0.7596, test r2: 0.6826
# Epoch 478, MAE train loss: 0.3224, MAE test loss: 0.3876, train r2: 0.7423, test r2: 0.6694
# Epoch 479, MAE train loss: 0.3218, MAE test loss: 0.3830, train r2: 0.7525, test r2: 0.6767
# Epoch 480, MAE train loss: 0.3309, MAE test loss: 0.3884, train r2: 0.7588, test r2: 0.6837
# Epoch 481, MAE train loss: 0.3203, MAE test loss: 0.3825, train r2: 0.7579, test r2: 0.6834
# Epoch 482, MAE train loss: 0.3554, MAE test loss: 0.4109, train r2: 0.7208, test r2: 0.6594
# Epoch 483, MAE train loss: 0.3149, MAE test loss: 0.3832, train r2: 0.7547, test r2: 0.6753
# Epoch 484, MAE train loss: 0.3223, MAE test loss: 0.3812, train r2: 0.7487, test r2: 0.6771
# Epoch 485, MAE train loss: 0.3266, MAE test loss: 0.3832, train r2: 0.7355, test r2: 0.6774
# Epoch 486, MAE train loss: 0.3328, MAE test loss: 0.3854, train r2: 0.7497, test r2: 0.6821
# Epoch 487, MAE train loss: 0.3299, MAE test loss: 0.3863, train r2: 0.7430, test r2: 0.6835
# Epoch 488, MAE train loss: 0.3164, MAE test loss: 0.3802, train r2: 0.7572, test r2: 0.6835
# Epoch 489, MAE train loss: 0.3179, MAE test loss: 0.3809, train r2: 0.7563, test r2: 0.6846
# Epoch 490, MAE train loss: 0.3158, MAE test loss: 0.3802, train r2: 0.7572, test r2: 0.6847
# Epoch 491, MAE train loss: 0.3264, MAE test loss: 0.3868, train r2: 0.7497, test r2: 0.6830
# Epoch 492, MAE train loss: 0.3227, MAE test loss: 0.3820, train r2: 0.7491, test r2: 0.6834
# Epoch 493, MAE train loss: 0.3151, MAE test loss: 0.3802, train r2: 0.7513, test r2: 0.6848
# Epoch 494, MAE train loss: 0.3248, MAE test loss: 0.3846, train r2: 0.7499, test r2: 0.6837
# Epoch 495, MAE train loss: 0.3190, MAE test loss: 0.3818, train r2: 0.7628, test r2: 0.6842
# Epoch 496, MAE train loss: 0.3293, MAE test loss: 0.3876, train r2: 0.7559, test r2: 0.6777
# Epoch 497, MAE train loss: 0.3277, MAE test loss: 0.3870, train r2: 0.7450, test r2: 0.6860
# Epoch 498, MAE train loss: 0.3186, MAE test loss: 0.3811, train r2: 0.7583, test r2: 0.6845
# Epoch 499, MAE train loss: 0.3147, MAE test loss: 0.3781, train r2: 0.7539, test r2: 0.6788
# Epoch 500, MAE train loss: 0.3179, MAE test loss: 0.3812, train r2: 0.7529, test r2: 0.6762
# Epoch 501, MAE train loss: 0.3130, MAE test loss: 0.3788, train r2: 0.7600, test r2: 0.6832
# Epoch 502, MAE train loss: 0.3132, MAE test loss: 0.3777, train r2: 0.7530, test r2: 0.6828
# Epoch 503, MAE train loss: 0.3155, MAE test loss: 0.3808, train r2: 0.7589, test r2: 0.6829
# Epoch 504, MAE train loss: 0.3159, MAE test loss: 0.3813, train r2: 0.7589, test r2: 0.6824
# Epoch 505, MAE train loss: 0.3248, MAE test loss: 0.3796, train r2: 0.7403, test r2: 0.6849
# Epoch 506, MAE train loss: 0.3155, MAE test loss: 0.3792, train r2: 0.7529, test r2: 0.6830
# Epoch 507, MAE train loss: 0.3217, MAE test loss: 0.3803, train r2: 0.7495, test r2: 0.6756
# Epoch 508, MAE train loss: 0.3169, MAE test loss: 0.3801, train r2: 0.7609, test r2: 0.6795
# Epoch 509, MAE train loss: 0.3182, MAE test loss: 0.3789, train r2: 0.7584, test r2: 0.6821
# Epoch 510, MAE train loss: 0.3168, MAE test loss: 0.3779, train r2: 0.7553, test r2: 0.6817
# Epoch 511, MAE train loss: 0.3129, MAE test loss: 0.3773, train r2: 0.7549, test r2: 0.6826
# Epoch 512, MAE train loss: 0.3185, MAE test loss: 0.3802, train r2: 0.7634, test r2: 0.6824
# Epoch 513, MAE train loss: 0.3165, MAE test loss: 0.3810, train r2: 0.7493, test r2: 0.6781
# Epoch 514, MAE train loss: 0.3186, MAE test loss: 0.3833, train r2: 0.7616, test r2: 0.6810
# Epoch 515, MAE train loss: 0.3212, MAE test loss: 0.3818, train r2: 0.7622, test r2: 0.6814
# Epoch 516, MAE train loss: 0.3187, MAE test loss: 0.3807, train r2: 0.7553, test r2: 0.6810
# Epoch 517, MAE train loss: 0.3145, MAE test loss: 0.3783, train r2: 0.7581, test r2: 0.6806
# Epoch 518, MAE train loss: 0.3143, MAE test loss: 0.3810, train r2: 0.7621, test r2: 0.6834
# Epoch 519, MAE train loss: 0.3153, MAE test loss: 0.3788, train r2: 0.7508, test r2: 0.6827
# Epoch 520, MAE train loss: 0.3199, MAE test loss: 0.3785, train r2: 0.7559, test r2: 0.6848
# Epoch 521, MAE train loss: 0.3165, MAE test loss: 0.3800, train r2: 0.7625, test r2: 0.6823
# Epoch 522, MAE train loss: 0.3147, MAE test loss: 0.3794, train r2: 0.7685, test r2: 0.6862
# ...
# Epoch 569, MAE train loss: 0.3149, MAE test loss: 0.3780, train r2: 0.7566, test r2: 0.6854
# Epoch 570, MAE train loss: 0.3185, MAE test loss: 0.3776, train r2: 0.7638, test r2: 0.6857
# Epoch 571, MAE train loss: 0.3233, MAE test loss: 0.3826, train r2: 0.7324, test r2: 0.6784
# Epoch 572, MAE train loss: 0.3126, MAE test loss: 0.3778, train r2: 0.7604, test r2: 0.6809
# Epoch 573, MAE train loss: 0.3166, MAE test loss: 0.3790, train r2: 0.7617, test r2: 0.6839
# Epoch 574, MAE train loss: 0.3154, MAE test loss: 0.3772, train r2: 0.7589, test r2: 0.6839
# Epoch 575, MAE train loss: 0.3134, MAE test loss: 0.3778, train r2: 0.7615, test r2: 0.6825
# Epoch 576, MAE train loss: 0.3078, MAE test loss: 0.3754, train r2: 0.7534, test r2: 0.6838
# Epoch 577, MAE train loss: 0.3109, MAE test loss: 0.3776, train r2: 0.7616, test r2: 0.6835
# Epoch 578, MAE train loss: 0.3118, MAE test loss: 0.3746, train r2: 0.7572, test r2: 0.6826
# Epoch 579, MAE train loss: 0.3127, MAE test loss: 0.3780, train r2: 0.7621, test r2: 0.6856
# Epoch 580, MAE train loss: 0.3171, MAE test loss: 0.3795, train r2: 0.7575, test r2: 0.6859
# Epoch 581, MAE train loss: 0.3134, MAE test loss: 0.3782, train r2: 0.7623, test r2: 0.6853
# Epoch 582, MAE train loss: 0.3131, MAE test loss: 0.3765, train r2: 0.7546, test r2: 0.6831
# Epoch 583, MAE train loss: 0.3134, MAE test loss: 0.3754, train r2: 0.7489, test r2: 0.6816
# Epoch 584, MAE train loss: 0.3100, MAE test loss: 0.3757, train r2: 0.7570, test r2: 0.6829
# Epoch 585, MAE train loss: 0.3129, MAE test loss: 0.3776, train r2: 0.7511, test r2: 0.6842
# Epoch 586, MAE train loss: 0.3126, MAE test loss: 0.3778, train r2: 0.7669, test r2: 0.6836
# Epoch 587, MAE train loss: 0.3149, MAE test loss: 0.3786, train r2: 0.7467, test r2: 0.6818
# Epoch 588, MAE train loss: 0.3096, MAE test loss: 0.3757, train r2: 0.7600, test r2: 0.6836
# Epoch 589, MAE train loss: 0.3180, MAE test loss: 0.3821, train r2: 0.7658, test r2: 0.6824
# Epoch 590, MAE train loss: 0.3214, MAE test loss: 0.3837, train r2: 0.7595, test r2: 0.6831
# Epoch 591, MAE train loss: 0.3146, MAE test loss: 0.3785, train r2: 0.7558, test r2: 0.6847
# Epoch 592, MAE train loss: 0.3137, MAE test loss: 0.3805, train r2: 0.7623, test r2: 0.6773
# Epoch 593, MAE train loss: 0.3106, MAE test loss: 0.3776, train r2: 0.7598, test r2: 0.6829
# Epoch 594, MAE train loss: 0.3083, MAE test loss: 0.3746, train r2: 0.7635, test r2: 0.6805
# Epoch 595, MAE train loss: 0.3119, MAE test loss: 0.3753, train r2: 0.7599, test r2: 0.6836
# Epoch 596, MAE train loss: 0.3141, MAE test loss: 0.3753, train r2: 0.7498, test r2: 0.6835
# Epoch 597, MAE train loss: 0.3162, MAE test loss: 0.3793, train r2: 0.7607, test r2: 0.6831
# Epoch 598, MAE train loss: 0.3186, MAE test loss: 0.3806, train r2: 0.7533, test r2: 0.6829
# Epoch 599, MAE train loss: 0.3224, MAE test loss: 0.3823, train r2: 0.7531, test r2: 0.6844
# Epoch 600, MAE train loss: 0.3126, MAE test loss: 0.3784, train r2: 0.7601, test r2: 0.6857
# Epoch 601, MAE train loss: 0.3120, MAE test loss: 0.3785, train r2: 0.7659, test r2: 0.6859
# Epoch 602, MAE train loss: 0.3140, MAE test loss: 0.3783, train r2: 0.7654, test r2: 0.6812
# Epoch 603, MAE train loss: 0.3132, MAE test loss: 0.3764, train r2: 0.7603, test r2: 0.6845
# Epoch 604, MAE train loss: 0.3102, MAE test loss: 0.3763, train r2: 0.7657, test r2: 0.6848
# Epoch 605, MAE train loss: 0.3124, MAE test loss: 0.3780, train r2: 0.7631, test r2: 0.6848
# Epoch 606, MAE train loss: 0.3120, MAE test loss: 0.3771, train r2: 0.7554, test r2: 0.6846
# Epoch 607, MAE train loss: 0.3117, MAE test loss: 0.3765, train r2: 0.7633, test r2: 0.6848
# Epoch 608, MAE train loss: 0.3136, MAE test loss: 0.3757, train r2: 0.7642, test r2: 0.6856
# Epoch 609, MAE train loss: 0.3088, MAE test loss: 0.3767, train r2: 0.7637, test r2: 0.6853
# Epoch 610, MAE train loss: 0.3138, MAE test loss: 0.3777, train r2: 0.7596, test r2: 0.6846
# Epoch 611, MAE train loss: 0.3155, MAE test loss: 0.3765, train r2: 0.7530, test r2: 0.6849
# Epoch 612, MAE train loss: 0.3153, MAE test loss: 0.3790, train r2: 0.7620, test r2: 0.6845
# Epoch 613, MAE train loss: 0.3268, MAE test loss: 0.3843, train r2: 0.7554, test r2: 0.6840
# Epoch 614, MAE train loss: 0.3190, MAE test loss: 0.3816, train r2: 0.7558, test r2: 0.6846
# Epoch 615, MAE train loss: 0.3132, MAE test loss: 0.3797, train r2: 0.7686, test r2: 0.6849
# Epoch 616, MAE train loss: 0.3047, MAE test loss: 0.3744, train r2: 0.7568, test r2: 0.6844
# Epoch 617, MAE train loss: 0.3159, MAE test loss: 0.3767, train r2: 0.7583, test r2: 0.6829
# Epoch 618, MAE train loss: 0.3109, MAE test loss: 0.3778, train r2: 0.7655, test r2: 0.6835
# Epoch 619, MAE train loss: 0.3159, MAE test loss: 0.3790, train r2: 0.7544, test r2: 0.6846
# Epoch 620, MAE train loss: 0.3164, MAE test loss: 0.3787, train r2: 0.7601, test r2: 0.6861
# Epoch 621, MAE train loss: 0.3183, MAE test loss: 0.3772, train r2: 0.7424, test r2: 0.6853
# Epoch 622, MAE train loss: 0.3168, MAE test loss: 0.3829, train r2: 0.7658, test r2: 0.6840
# Epoch 623, MAE train loss: 0.3179, MAE test loss: 0.3828, train r2: 0.7645, test r2: 0.6846
# Epoch 624, MAE train loss: 0.3158, MAE test loss: 0.3775, train r2: 0.7583, test r2: 0.6864
# Epoch 625, MAE train loss: 0.3082, MAE test loss: 0.3751, train r2: 0.7558, test r2: 0.6837
# Epoch 626, MAE train loss: 0.3089, MAE test loss: 0.3744, train r2: 0.7590, test r2: 0.6843
# Epoch 627, MAE train loss: 0.3150, MAE test loss: 0.3739, train r2: 0.7433, test r2: 0.6835
# Epoch 628, MAE train loss: 0.3128, MAE test loss: 0.3763, train r2: 0.7527, test r2: 0.6851
# Epoch 629, MAE train loss: 0.3147, MAE test loss: 0.3750, train r2: 0.7610, test r2: 0.6827
# Epoch 630, MAE train loss: 0.3132, MAE test loss: 0.3761, train r2: 0.7590, test r2: 0.6845
# Epoch 631, MAE train loss: 0.3117, MAE test loss: 0.3761, train r2: 0.7622, test r2: 0.6823
# Epoch 632, MAE train loss: 0.3112, MAE test loss: 0.3771, train r2: 0.7615, test r2: 0.6845
# Epoch 633, MAE train loss: 0.3127, MAE test loss: 0.3781, train r2: 0.7679, test r2: 0.6853
# Epoch 634, MAE train loss: 0.3127, MAE test loss: 0.3756, train r2: 0.7618, test r2: 0.6857
# Epoch 635, MAE train loss: 0.3099, MAE test loss: 0.3742, train r2: 0.7605, test r2: 0.6839
# Epoch 636, MAE train loss: 0.3093, MAE test loss: 0.3750, train r2: 0.7634, test r2: 0.6847
# Epoch 637, MAE train loss: 0.3147, MAE test loss: 0.3786, train r2: 0.7689, test r2: 0.6852
# Epoch 638, MAE train loss: 0.3102, MAE test loss: 0.3759, train r2: 0.7676, test r2: 0.6864
# Epoch 639, MAE train loss: 0.3146, MAE test loss: 0.3787, train r2: 0.7637, test r2: 0.6871
# Epoch 640, MAE train loss: 0.3078, MAE test loss: 0.3742, train r2: 0.7581, test r2: 0.6851
# Epoch 641, MAE train loss: 0.3107, MAE test loss: 0.3739, train r2: 0.7704, test r2: 0.6856
# Epoch 642, MAE train loss: 0.3116, MAE test loss: 0.3753, train r2: 0.7678, test r2: 0.6864
# Epoch 643, MAE train loss: 0.3134, MAE test loss: 0.3772, train r2: 0.7585, test r2: 0.6864
# Epoch 644, MAE train loss: 0.3161, MAE test loss: 0.3798, train r2: 0.7596, test r2: 0.6847
# Epoch 645, MAE train loss: 0.3105, MAE test loss: 0.3794, train r2: 0.7618, test r2: 0.6854
# Epoch 646, MAE train loss: 0.3126, MAE test loss: 0.3772, train r2: 0.7646, test r2: 0.6843
# Epoch 647, MAE train loss: 0.3135, MAE test loss: 0.3764, train r2: 0.7599, test r2: 0.6853
# Epoch 648, MAE train loss: 0.3130, MAE test loss: 0.3788, train r2: 0.7650, test r2: 0.6860
# Epoch 649, MAE train loss: 0.3071, MAE test loss: 0.3764, train r2: 0.7693, test r2: 0.6840
# Epoch 650, MAE train loss: 0.3081, MAE test loss: 0.3746, train r2: 0.7680, test r2: 0.6855
# Epoch 651, MAE train loss: 0.3110, MAE test loss: 0.3778, train r2: 0.7588, test r2: 0.6860
# Epoch 652, MAE train loss: 0.3106, MAE test loss: 0.3759, train r2: 0.7561, test r2: 0.6849
# Epoch 653, MAE train loss: 0.3089, MAE test loss: 0.3752, train r2: 0.7680, test r2: 0.6841
# Epoch 654, MAE train loss: 0.3083, MAE test loss: 0.3739, train r2: 0.7588, test r2: 0.6833
# Epoch 655, MAE train loss: 0.3114, MAE test loss: 0.3786, train r2: 0.7627, test r2: 0.6845
# Epoch 656, MAE train loss: 0.3131, MAE test loss: 0.3772, train r2: 0.7630, test r2: 0.6868
# Epoch 657, MAE train loss: 0.3188, MAE test loss: 0.3786, train r2: 0.7615, test r2: 0.6864
# Epoch 658, MAE train loss: 0.3164, MAE test loss: 0.3786, train r2: 0.7488, test r2: 0.6862
# Epoch 659, MAE train loss: 0.3195, MAE test loss: 0.3815, train r2: 0.7556, test r2: 0.6853
# Epoch 660, MAE train loss: 0.3116, MAE test loss: 0.3794, train r2: 0.7651, test r2: 0.6857
# Epoch 661, MAE train loss: 0.3136, MAE test loss: 0.3778, train r2: 0.7711, test r2: 0.6868
# Epoch 662, MAE train loss: 0.3119, MAE test loss: 0.3751, train r2: 0.7562, test r2: 0.6866
# Epoch 663, MAE train loss: 0.3174, MAE test loss: 0.3785, train r2: 0.7645, test r2: 0.6868
# Epoch 664, MAE train loss: 0.3126, MAE test loss: 0.3786, train r2: 0.7599, test r2: 0.6878
# Epoch 665, MAE train loss: 0.3129, MAE test loss: 0.3760, train r2: 0.7550, test r2: 0.6866
# Epoch 666, MAE train loss: 0.3095, MAE test loss: 0.3762, train r2: 0.7674, test r2: 0.6851
# Epoch 667, MAE train loss: 0.3081, MAE test loss: 0.3751, train r2: 0.7610, test r2: 0.6855
# Epoch 668, MAE train loss: 0.3124, MAE test loss: 0.3742, train r2: 0.7625, test r2: 0.6847
# Epoch 669, MAE train loss: 0.3070, MAE test loss: 0.3750, train r2: 0.7632, test r2: 0.6849
# Epoch 670, MAE train loss: 0.3137, MAE test loss: 0.3764, train r2: 0.7492, test r2: 0.6840
# Epoch 671, MAE train loss: 0.3132, MAE test loss: 0.3761, train r2: 0.7539, test r2: 0.6821
# Epoch 672, MAE train loss: 0.3093, MAE test loss: 0.3761, train r2: 0.7630, test r2: 0.6827
# Epoch 673, MAE train loss: 0.3079, MAE test loss: 0.3745, train r2: 0.7577, test r2: 0.6819
# Epoch 674, MAE train loss: 0.3108, MAE test loss: 0.3744, train r2: 0.7638, test r2: 0.6853
# Epoch 675, MAE train loss: 0.3087, MAE test loss: 0.3748, train r2: 0.7613, test r2: 0.6850
# Epoch 676, MAE train loss: 0.3080, MAE test loss: 0.3748, train r2: 0.7692, test r2: 0.6838
# Epoch 677, MAE train loss: 0.3143, MAE test loss: 0.3767, train r2: 0.7544, test r2: 0.6844
# Epoch 678, MAE train loss: 0.3092, MAE test loss: 0.3754, train r2: 0.7568, test r2: 0.6853
# Epoch 679, MAE train loss: 0.3108, MAE test loss: 0.3752, train r2: 0.7590, test r2: 0.6848
# Epoch 680, MAE train loss: 0.3083, MAE test loss: 0.3741, train r2: 0.7599, test r2: 0.6838
# Epoch 681, MAE train loss: 0.3195, MAE test loss: 0.3832, train r2: 0.7655, test r2: 0.6839
# Epoch 682, MAE train loss: 0.3083, MAE test loss: 0.3768, train r2: 0.7645, test r2: 0.6863
# Epoch 683, MAE train loss: 0.3079, MAE test loss: 0.3765, train r2: 0.7674, test r2: 0.6859
# Epoch 684, MAE train loss: 0.3185, MAE test loss: 0.3804, train r2: 0.7626, test r2: 0.6857
# Epoch 685, MAE train loss: 0.3151, MAE test loss: 0.3770, train r2: 0.7557, test r2: 0.6855
# Epoch 686, MAE train loss: 0.3104, MAE test loss: 0.3764, train r2: 0.7673, test r2: 0.6841
# Epoch 687, MAE train loss: 0.3115, MAE test loss: 0.3784, train r2: 0.7678, test r2: 0.6817
# Epoch 688, MAE train loss: 0.3138, MAE test loss: 0.3788, train r2: 0.7687, test r2: 0.6853
# Epoch 689, MAE train loss: 0.3095, MAE test loss: 0.3759, train r2: 0.7670, test r2: 0.6841
# Epoch 690, MAE train loss: 0.3125, MAE test loss: 0.3770, train r2: 0.7663, test r2: 0.6853
# Epoch 691, MAE train loss: 0.3177, MAE test loss: 0.3791, train r2: 0.7503, test r2: 0.6850
# Epoch 692, MAE train loss: 0.3145, MAE test loss: 0.3772, train r2: 0.7578, test r2: 0.6849
# Epoch 693, MAE train loss: 0.3083, MAE test loss: 0.3744, train r2: 0.7683, test r2: 0.6844
# Epoch 694, MAE train loss: 0.3077, MAE test loss: 0.3753, train r2: 0.7700, test r2: 0.6866
# Epoch 695, MAE train loss: 0.3161, MAE test loss: 0.3813, train r2: 0.7679, test r2: 0.6857
# Epoch 696, MAE train loss: 0.3197, MAE test loss: 0.3797, train r2: 0.7584, test r2: 0.6862
# Epoch 697, MAE train loss: 0.3128, MAE test loss: 0.3765, train r2: 0.7558, test r2: 0.6835
# Epoch 698, MAE train loss: 0.3084, MAE test loss: 0.3750, train r2: 0.7631, test r2: 0.6861
# Epoch 699, MAE train loss: 0.3110, MAE test loss: 0.3777, train r2: 0.7686, test r2: 0.6876
# Epoch 700, MAE train loss: 0.3129, MAE test loss: 0.3783, train r2: 0.7665, test r2: 0.6860
# Epoch 701, MAE train loss: 0.3106, MAE test loss: 0.3779, train r2: 0.7692, test r2: 0.6867
# Epoch 702, MAE train loss: 0.3106, MAE test loss: 0.3775, train r2: 0.7692, test r2: 0.6865
# Epoch 703, MAE train loss: 0.3096, MAE test loss: 0.3756, train r2: 0.7620, test r2: 0.6861
# Epoch 704, MAE train loss: 0.3110, MAE test loss: 0.3776, train r2: 0.7667, test r2: 0.6872
# Epoch 705, MAE train loss: 0.3187, MAE test loss: 0.3784, train r2: 0.7491, test r2: 0.6858
# Epoch 706, MAE train loss: 0.3163, MAE test loss: 0.3783, train r2: 0.7576, test r2: 0.6870
# Epoch 707, MAE train loss: 0.3146, MAE test loss: 0.3803, train r2: 0.7691, test r2: 0.6861
# Epoch 708, MAE train loss: 0.3112, MAE test loss: 0.3771, train r2: 0.7676, test r2: 0.6865
# Epoch 709, MAE train loss: 0.3135, MAE test loss: 0.3776, train r2: 0.7604, test r2: 0.6856
# Epoch 710, MAE train loss: 0.3106, MAE test loss: 0.3777, train r2: 0.7667, test r2: 0.6856
# Epoch 711, MAE train loss: 0.3132, MAE test loss: 0.3758, train r2: 0.7577, test r2: 0.6862
# Epoch 712, MAE train loss: 0.3108, MAE test loss: 0.3745, train r2: 0.7580, test r2: 0.6862
# Epoch 713, MAE train loss: 0.3176, MAE test loss: 0.3753, train r2: 0.7601, test r2: 0.6856
# Epoch 714, MAE train loss: 0.3061, MAE test loss: 0.3748, train r2: 0.7683, test r2: 0.6860
# Epoch 715, MAE train loss: 0.3125, MAE test loss: 0.3751, train r2: 0.7684, test r2: 0.6855
# Epoch 716, MAE train loss: 0.3135, MAE test loss: 0.3760, train r2: 0.7553, test r2: 0.6864
# Epoch 717, MAE train loss: 0.3110, MAE test loss: 0.3757, train r2: 0.7646, test r2: 0.6875
# Epoch 718, MAE train loss: 0.3096, MAE test loss: 0.3741, train r2: 0.7584, test r2: 0.6849
# Epoch 719, MAE train loss: 0.3064, MAE test loss: 0.3754, train r2: 0.7641, test r2: 0.6854
# Epoch 720, MAE train loss: 0.3124, MAE test loss: 0.3745, train r2: 0.7435, test r2: 0.6855
# Epoch 721, MAE train loss: 0.3071, MAE test loss: 0.3748, train r2: 0.7725, test r2: 0.6855
# Epoch 722, MAE train loss: 0.3065, MAE test loss: 0.3746, train r2: 0.7681, test r2: 0.6833
# Epoch 723, MAE train loss: 0.3117, MAE test loss: 0.3751, train r2: 0.7588, test r2: 0.6849
# Epoch 724, MAE train loss: 0.3093, MAE test loss: 0.3763, train r2: 0.7646, test r2: 0.6860
# Epoch 725, MAE train loss: 0.3084, MAE test loss: 0.3741, train r2: 0.7703, test r2: 0.6855
# Epoch 726, MAE train loss: 0.3108, MAE test loss: 0.3745, train r2: 0.7569, test r2: 0.6850
# Epoch 727, MAE train loss: 0.3070, MAE test loss: 0.3762, train r2: 0.7582, test r2: 0.6839
# Epoch 728, MAE train loss: 0.3118, MAE test loss: 0.3791, train r2: 0.7672, test r2: 0.6862
# Epoch 729, MAE train loss: 0.3157, MAE test loss: 0.3785, train r2: 0.7567, test r2: 0.6867
# Epoch 730, MAE train loss: 0.3198, MAE test loss: 0.3787, train r2: 0.7524, test r2: 0.6863
# Epoch 731, MAE train loss: 0.3155, MAE test loss: 0.3784, train r2: 0.7575, test r2: 0.6836
# Epoch 732, MAE train loss: 0.3117, MAE test loss: 0.3766, train r2: 0.7618, test r2: 0.6855
# Epoch 733, MAE train loss: 0.3079, MAE test loss: 0.3766, train r2: 0.7778, test r2: 0.6858
# Epoch 734, MAE train loss: 0.3103, MAE test loss: 0.3747, train r2: 0.7613, test r2: 0.6858
# Epoch 735, MAE train loss: 0.3071, MAE test loss: 0.3752, train r2: 0.7721, test r2: 0.6844
# Epoch 736, MAE train loss: 0.3117, MAE test loss: 0.3776, train r2: 0.7736, test r2: 0.6857
# Epoch 737, MAE train loss: 0.3142, MAE test loss: 0.3784, train r2: 0.7646, test r2: 0.6847
# Epoch 738, MAE train loss: 0.3069, MAE test loss: 0.3747, train r2: 0.7698, test r2: 0.6843
# Epoch 739, MAE train loss: 0.3114, MAE test loss: 0.3770, train r2: 0.7705, test r2: 0.6849
# Epoch 740, MAE train loss: 0.3166, MAE test loss: 0.3762, train r2: 0.7547, test r2: 0.6862
# Epoch 741, MAE train loss: 0.3135, MAE test loss: 0.3759, train r2: 0.7646, test r2: 0.6874
# Early stopping

# %%
print('r2 on testset', np.average(overall_test_r2[400:]))
print('MAE on testset',np.average(overall_test_loss[400:]))
# Out:
# r2 on testset 0.6821048893306831
# MAE on testset 0.38000295

# %%
x = [i for i in range(1, 742)]
fig = plt.figure(figsize=(16, 8))
plt.plot(x, overall_train_loss, label = 'overall_train_loss')
plt.plot(x, overall_test_loss, label = 'overall_test_loss')
plt.legend()
plt.show()
# fig.savefig('./mae_no_fingerprint_GraphConv.png')

# %%
fig = plt.figure(figsize=(16, 8))
plt.plot(x, overall_train_r2, label = 'overall_train_r2')
plt.plot(x, overall_test_r2, label = 'overall_test_r2')
plt.legend()
plt.show()
# fig.savefig('./r2_no_fingerprint_GraphConv.png')

# %% [markdown]
# # 8. Validation on BindingDB dataset

# %%
CheMBL = pd.read_csv('./data/CheMBL_clean.csv')
CheMBL = CheMBL.sample(frac=1, random_state=seed)
CheMBL = CheMBL.reset_index(drop=True)
CheMBL
# Out:
#                 ID                                             Smiles  \
# 0    CHEMBL3398462  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1    CHEMBL1082079  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2     CHEMBL257165  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3     CHEMBL238970  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4    CHEMBL4632967  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..             ...                                                ...
# 978  CHEMBL1760267  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 979    CHEMBL78529  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 980    CHEMBL92130  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 981   CHEMBL214026  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 982   CHEMBL391479  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      IC50 (nM)                                   canonical_smiles  \
# 0      2120.00  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1        10.00  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2      1250.00  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3      6095.37  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4      1520.00  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..         ...                                                ...
# 978   19952.62  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 979     473.00  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 980    2550.00  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 981    5308.84  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 982     427.56  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      Molecular Weight     LogP  num_H_acceptors  num_H_Donors
# 0             492.572  4.99322                6             1
# 1             503.492  6.62702                3             2
# 2             520.626  5.62932                6             1
# 3             487.518  6.58340                4             1
# 4             573.671  5.61460                6             3
# ..                ...      ...              ...           ...
# 978           530.086  6.77956                4             1
# 979           471.553  6.12642                5             1
# 980           507.608  6.31200                7             1
# 981           454.950  6.69432                4             1
# 982           518.553  6.67352                5             1
#
# [983 rows x 8 columns]

# %%
CheMBL_copy = CheMBL.copy()
pIC50_CheMBL = CheMBL_copy['IC50 (nM)'].apply(lambda x: -np.log10(x * 10 ** (-9) ))
pIC50_CheMBL = pd.Series(pIC50_CheMBL, name='pIC50')
CheMBL_copy['pIC50'] = pIC50_CheMBL

# %%
CheMBL_copy = CheMBL_copy[CheMBL_copy['pIC50'] >= 4.0]
CheMBL_copy = CheMBL_copy.reset_index(drop=True)
CheMBL_copy
# Out:
#                 ID                                             Smiles  \
# 0    CHEMBL3398462  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1    CHEMBL1082079  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2     CHEMBL257165  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3     CHEMBL238970  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4    CHEMBL4632967  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..             ...                                                ...
# 976  CHEMBL1760267  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 977    CHEMBL78529  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 978    CHEMBL92130  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 979   CHEMBL214026  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 980   CHEMBL391479  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      IC50 (nM)                                   canonical_smiles  \
# 0      2120.00  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1        10.00  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2      1250.00  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3      6095.37  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4      1520.00  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..         ...                                                ...
# 976   19952.62  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 977     473.00  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 978    2550.00  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 979    5308.84  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 980     427.56  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      Molecular Weight     LogP  num_H_acceptors  num_H_Donors     pIC50
# 0             492.572  4.99322                6             1  5.673664
# 1             503.492  6.62702                3             2  8.000000
# 2             520.626  5.62932                6             1  5.903090
# 3             487.518  6.58340                4             1  5.215000
# 4             573.671  5.61460                6             3  5.818156
# ..                ...      ...              ...           ...       ...
# 976           530.086  6.77956                4             1  4.700000
# 977           471.553  6.12642                5             1  6.325139
# 978           507.608  6.31200                7             1  5.593460
# 979           454.950  6.69432                4             1  5.275000
# 980           518.553  6.67352                5             1  6.369003
#
# [981 rows x 9 columns]

# %%
graph_list_CheMBL = [smiles_to_graph(smile) for smile in CheMBL_copy['canonical_smiles']]
pIC50_list_CheMBL = CheMBL_copy['pIC50'].to_list()

scaler = StandardScaler()
pIC50_list_CheMBL = scaler.fit_transform(np.array(pIC50_list_CheMBL).reshape(-1, 1)).flatten()

for graph, pIC50 in zip(graph_list_CheMBL, pIC50_list_CheMBL):
    graph.y = torch.tensor([pIC50], dtype=torch.float).view(-1, 1)


drug_graphs_CheMBL = graph_list_CheMBL
drug_graphs_CheMBL[0]
# Out:
# Data(x=[36, 149], edge_index=[2, 78], edge_attr=[78, 10], y=[1, 1])

# %%
CheMBL_loader = DataLoader(drug_graphs_CheMBL, batch_size = 1, shuffle = False)

# %%
def test_DB(protein_graph, loader):
    model.eval()

    loss_list = []
    out_list = []

    with torch.no_grad():
        for data in loader:
            
            protein_graph = protein_graph.to(device)
            data = data.to(device)

            out = model(protein_graph, data)

            out_no_scaled = torch.tensor(scaler.inverse_transform(out.detach().cpu().numpy().reshape(-1, 1)).flatten())
            actual_no_scaled = torch.tensor(scaler.inverse_transform(data.y.detach().cpu().numpy().reshape(-1, 1)).flatten())

            mae_loss = torch.nn.L1Loss(reduction='mean')(out_no_scaled, actual_no_scaled)

            loss_list.append(mae_loss)
            out_list.append(out.detach().cpu().numpy())
            
    return out_list, loss_list

# %%
out_list, loss_list = test_DB(protein_graph, CheMBL_loader)
print(f'the length of out_list: {len(out_list)}')
print(f'the length of out_list: {len(loss_list)}')
# Out:
# the length of out_list: 981
# the length of out_list: 981

# %%
print(f'average MAE loss: {np.average(loss_list):.4f}')
print(out_list[0][0][0])
# Out:
# average MAE loss: 0.4023
# -0.3171787

# %%
out_list_modify = []
for out in out_list:
    out = out[0][0]
    out_list_modify.append(out)
out_list_modify = np.array(out_list_modify)

# %%
y_pred_array = scaler.inverse_transform(out_list_modify.reshape(-1, 1)).flatten()
pIC50_pred = pd.Series(y_pred_array, name='pIC50_pred')

# %%
CheMBL_copy['pIC50_pred'] = pIC50_pred
CheMBL_copy
# Out:
#                 ID                                             Smiles  \
# 0    CHEMBL3398462  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1    CHEMBL1082079  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2     CHEMBL257165  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3     CHEMBL238970  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4    CHEMBL4632967  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..             ...                                                ...
# 976  CHEMBL1760267  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 977    CHEMBL78529  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 978    CHEMBL92130  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 979   CHEMBL214026  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 980   CHEMBL391479  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      IC50 (nM)                                   canonical_smiles  \
# 0      2120.00  CCOC(=O)N1C[C@H](CC(=O)O)[C@@H](Cc2cccc(OCCc3n...
# 1        10.00  CCCCOc1ccc(-c2ccc(C(=O)O)cc2C)cc1CNC(=O)c1ccc(...
# 2      1250.00  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC2CN(C(=O)OCC(C)C...
# 3      6095.37  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 4      1520.00  CC(C)(Oc1ccc(CCOc2ccc(NC(=O)Nc3ccccc3)cc2)cc1)...
# ..         ...                                                ...
# 976   19952.62  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 977     473.00  CCC(Cc1ccc(OCCc2nc(-c3ccccc3)oc2C)cc1)(Oc1cccc...
# 978    2550.00  CCCc1cc(Oc2ccc(OC)cc2)ccc1OCCCOc1cccc(C2SC(=O)...
# 979    5308.84  Cc1cc(OCC[C@@H](C)Oc2ccc(Cl)cc2Oc2ccccc2)ccc1C...
# 980     427.56  Cc1cc(SCc2ccc(OCc3ccc(C(F)(F)F)cc3)cc2)c2c(c1O...
#
#      Molecular Weight     LogP  num_H_acceptors  num_H_Donors     pIC50  \
# 0             492.572  4.99322                6             1  5.673664
# 1             503.492  6.62702                3             2  8.000000
# 2             520.626  5.62932                6             1  5.903090
# 3             487.518  6.58340                4             1  5.215000
# 4             573.671  5.61460                6             3  5.818156
# ..                ...      ...              ...           ...       ...
# 976           530.086  6.77956                4             1  4.700000
# 977           471.553  6.12642                5             1  6.325139
# 978           507.608  6.31200                7             1  5.593460
# 979           454.950  6.69432                4             1  5.275000
# 980           518.553  6.67352                5             1  6.369003
#
#      pIC50_pred
# 0      5.528738
# 1      6.208344
# 2      5.602974
# 3      5.635562
# 4      5.996092
# ..          ...
# 976    4.836874
# 977    6.280029
# 978    6.169114
# 979    5.319751
# 980    6.356553
#
# [981 rows x 10 columns]

# %%
x = CheMBL_copy['pIC50'].to_list()
y = CheMBL_copy['pIC50_pred'].to_list()

# %%
y_baseline = x
fig = plt.figure(figsize=(8,8))
plt.scatter(x, y)
plt.plot(x, y_baseline, label = 'baseline', color = 'r')
plt.legend()
plt.xlabel('actual pIC50')
plt.ylabel('pred_pIC50')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pred_results = pd.DataFrame({"X":x,"Y":y})
pd.plotting.scatter_matrix(pred_results)
plt.show()

r = pearsonr(pred_results['X'],pred_results['Y'])
print("pearson系数:",r[0])
print("P-Value:",r[1])
# Out:
# pearson系数: 0.8132246123543352
# P-Value: 2.0846285949522568e-232

# %%
print(r2_score(x, y))
# Out:
# 0.6602265554769542
