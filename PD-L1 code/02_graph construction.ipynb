# %%
import pandas as pd
import pytorch_geometric
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import pytorch_geometric
#
# ModuleNotFoundError: No module named 'pytorch_geometric'

# %% [markdown]
# # 1. read datasets

# %%
BindingDB = pd.read_csv('./data/BindingDB clean.csv')
BindingDB
# Out:
#            ID                                             Smiles  IC50 (nM)  \
# 0    50228561          CN(CCOc1ccc(Cc2sc(=O)[nH]c2O)cc1)c1ccccn1       5.00
# 1    50939094  Cc1ccc(Cn2nc(CCCc3ccc(OC(C)(C)C(O)=O)cc3)n(C)c...      11.99
# 2    50939108  Cn1c(CCCc2ccc(OC(C)(C)C(O)=O)cc2)nn(Cc2ccc(cc2...      15.00
# 3    50248007  CCCn1c(CCCc2ccc(OC(C)(C)C(O)=O)cc2)nn(Cc2ccc(C...      16.00
# 4    50248027  CCCn1c(CCCc2ccc(OC(C)(C)C(O)=O)cc2)nn(Cc2cccc(...      19.00
# ..        ...                                                ...        ...
# 179  50347985   CCOC(Cc1ccc2n(Cc3nc(oc3C)-c3ccccc3)ccc2c1)C(O)=O     368.00
# 180  50938915  CO[C@@H](Cc1ccc(OCCCOc2ccc(cc2)C(=O)c2ccccc2)c...     469.89
# 181  50303171            CCCc1cc(cc(CCC)c1OC(C)(C)C(O)=O)C(=O)CC     480.00
# 182  50386748         Cc1nc(sc1COc1ccc2n(CC(O)=O)ccc2c1)C(F)(F)F     550.00
# 183  50938877  CO[C@@H](Cc1ccc(OCCCOc2ccc(cc2)-c2ccccc2)cc1)C...     567.54
#
# ...

# %% [markdown]
# # 2. small molecule graphs

# %%
def SmileToGraph(smiles):
