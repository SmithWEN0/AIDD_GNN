# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski
from rdkit.Chem import AllChem
import re
import torch
from torch_geometric.data import Data, Batch

from Bio.PDB import PDBList, PDBParser
from Bio import PDB

import networkx as nx
from torch_geometric.utils import from_networkx
import matplotlib.pyplot as plt

from torch_geometric.loader import DataLoader

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, GATConv, GraphConv, GraphSAGE

import random

# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

from sklearn.preprocessing import StandardScaler

from ydata_profiling import ProfileReport
import os
import math
from scipy.stats import pearsonr

# %%
# 固定随机种子等操作
seed = 12345
print('seed is ' + str(seed))
g = torch.Generator()
g.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = False
torch.use_deterministic_algorithms(True)
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':16:8'
os.environ['PYTHONHASHSEED'] = str(seed)  # 为了禁止hash随机化，使得实验可复现。
# Out:
# seed is 12345

# %% [markdown]
# # 1. read datasets

# %%
raw_data_BindingDB = pd.read_csv('./data/merged_data clean.csv')
raw_data_BindingDB
# Out:
#                  ID                                             Smiles  \
# 0          50952815  COc1ccc(NC(=O)N(CCCCC2CCCCC2)CCc2ccc(SC(C)(C)C...
# 1          50952818  CC(C)(Sc1ccc(CCN(CCCCC2CCCCC2)C(=O)NC2CCCCC2)c...
# 2          50952816  COc1cccc(NC(=O)N(CCCCC2CCCCC2)CCc2ccc(SC(C)(C)...
# 3          50952817  COc1ccccc1NC(=O)N(CCCCC1CCCCC1)CCc1ccc(SC(C)(C...
# 4          50332806  CC[C@@](C)(Cc1ccc(OCCCOc2ccc(cc2Cl)C2CCCCC2)cc...
# ...             ...                                                ...
# 1980  CHEMBL4575562  CCOc1ccc(-c2ccc(CCCc3nn(-c4ccc(S(C)(=O)=O)cc4)...
# 1981  CHEMBL3678128  Cc1c(C)n(Cc2ccc(Cl)c(O[C@@H](C)C(=O)O)c2)c2ccc...
# 1982   CHEMBL510698             O=C(Nc1ccncc1)c1cc([N+](=O)[O-])ccc1Cl
# 1983  CHEMBL5286386  CC(C)(O)c1ccc(NC(=O)c2cc(C(=O)NCc3ccc(F)c(F)c3...
# 1984  CHEMBL5207130  CCc1ccc(-c2nc3cc(NC(=O)c4cc([N+](=O)[O-])ccc4C...
#
#       IC50 (nM)                                   canonical_smiles  \
# 0          0.28  COc1ccc(NC(=O)N(CCCCC2CCCCC2)CCc2ccc(SC(C)(C)C...
# 1          0.46  CC(C)(Sc1ccc(CCN(CCCCC2CCCCC2)C(=O)NC2CCCCC2)c...
# 2          0.59  COc1cccc(NC(=O)N(CCCCC2CCCCC2)CCc2ccc(SC(C)(C)...
# 3          1.90  COc1ccccc1NC(=O)N(CCCCC1CCCCC1)CCc1ccc(SC(C)(C...
# 4          2.00  CC[C@@](C)(Cc1ccc(OCCCOc2ccc(C3CCCCC3)cc2Cl)cc...
# ...         ...                                                ...
# 1980    5040.00  CCOc1ccc(-c2ccc(CCCc3nn(-c4ccc(S(C)(=O)=O)cc4)...
# 1981     935.00  Cc1c(C)n(Cc2ccc(Cl)c(O[C@@H](C)C(=O)O)c2)c2ccc...
# 1982    2950.00             O=C(Nc1ccncc1)c1cc([N+](=O)[O-])ccc1Cl
# 1983   16000.00  CC(C)(O)c1ccc(NC(=O)c2cc(C(=O)NCc3ccc(F)c(F)c3...
# 1984   50000.00  CCc1ccc(-c2nc3cc(NC(=O)c4cc([N+](=O)[O-])ccc4C...
#
#       Molecular Weight     LogP  num_H_acceptors  num_H_Donors
# 0              526.743  7.47770                4             2
# 1              502.765  7.27930                3             2
# 2              526.743  7.47770                4             2
# 3              526.743  7.47770                4             2
# 4              459.026  7.27900                3             1
# ...                ...      ...              ...           ...
# 1980           629.710  5.43390                8             1
# 1981           561.122  7.60024                4             2
# 1982           277.667  2.89550                4             1
# 1983           476.882  5.16700                3             3
# 1984           421.840  5.87110                5             1
#
# [1985 rows x 8 columns]

# %%
raw_data_BindingDB.isna().sum()
# Out:
# ID                  0
# Smiles              0
# IC50 (nM)           0
# canonical_smiles    0
# Molecular Weight    0
# LogP                0
# num_H_acceptors     0
# num_H_Donors        0
# dtype: int64

# %%
raw_data_BindingDB.nunique()
# Out:
# ID                  1985
# Smiles              1952
# IC50 (nM)            639
# canonical_smiles    1086
# Molecular Weight     754
# LogP                 845
# num_H_acceptors        9
# num_H_Donors           5
# dtype: int64

# %%
raw_data_BindingDB.dtypes
# Out:
# ID                   object
# Smiles               object
# IC50 (nM)           float64
# canonical_smiles     object
# Molecular Weight    float64
# LogP                float64
# num_H_acceptors       int64
# num_H_Donors          int64
# dtype: object

# %%
change_type = raw_data_BindingDB['IC50 (nM)'].astype('float32')
raw_data_BindingDB['IC50 (nM)'] = change_type

# %%
raw_data_BindingDB['pIC50'] = raw_data_BindingDB['IC50 (nM)'].apply(lambda x: -np.log10(x * 10 ** (-9)))

# %%
raw_data_molecule_copy = raw_data_BindingDB[raw_data_BindingDB['pIC50'] >= 4.0]

# %%
raw_data_molecule = raw_data_molecule_copy.sample(frac=1, random_state=seed)
raw_data_molecule = raw_data_molecule.reset_index(drop=True)
raw_data_molecule
# Out:
#                  ID                                             Smiles  \
# 0     CHEMBL1760268  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 1      CHEMBL238970  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 2          50077425  CCCCN(c1ccc(F)c(c1)-c1ccc(Cl)cc1)S(=O)(=O)c1cc...
# 3          51241719  Fc1ccccc1-n1c(COc2ccc(cc2)-c2ccc(NS(=O)(=O)c3c...
# 4     CHEMBL1947139  COc1ccc2c(-n3c(=O)n(Cc4ccc([C@@]5(C)OC(=O)NC5=...
# ...             ...                                                ...
# 1976   CHEMBL597349  O=C(NCCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(OC(F...
# 1977       50386699  Cc1nc(sc1COc1cc(Cl)c2c(CC(O)=O)csc2c1)-c1ccc(c...
# 1978   CHEMBL460026           CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCC(=O)O
# 1979   CHEMBL498401  O=C(O)COc1cccc2c1CCN(S(=O)(=O)c1cccc(C(=O)Nc3c...
# 1980       51014438  FC(F)(F)c1ccc(nc1)S(=O)(=O)CCNC(=O)c1ccc(Cl)c(...
#
#          IC50 (nM)                                   canonical_smiles  \
# 0      6309.569824  CCCCN(c1cccc(-c2ccc(Cl)cc2)c1C)S(=O)(=O)c1ccc(...
# 1      6095.370117  CCc1cc(OCC[C@@H](C)Oc2ccc(C(F)(F)F)cc2-c2ccccn...
# 2     19953.000000  CCCCN(c1ccc(F)c(-c2ccc(Cl)cc2)c1)S(=O)(=O)c1cc...
# 3     38140.000000  O=c1n(-c2ccc(C(F)(F)F)cc2)nc(COc2ccc(-c3ccc(NS...
# 4     50000.000000  COc1ccc2c(-n3c(=O)n(Cc4ccc([C@@]5(C)OC(=O)NC5=...
# ...            ...                                                ...
# 1976  10000.000000  O=C(NCCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(OC(F...
# 1977   1040.000000  Cc1nc(-c2ccc(C(F)(F)F)cc2)sc1COc1cc(Cl)c2c(CC(...
# 1978   1100.000000           CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCC(=O)O
# 1979   5011.870117  O=C(O)COc1cccc2c1CCN(S(=O)(=O)c1cccc(C(=O)Nc3c...
# 1980  10000.000000  O=C(NCCS(=O)(=O)c1ccc(C(F)(F)F)cn1)c1ccc(Cl)c(...
#
#       Molecular Weight     LogP  num_H_acceptors  num_H_Donors     pIC50
# 0              516.059  6.39106                4             1  5.200000
# 1              487.518  6.58340                4             1  5.215000
# 2              534.049  6.61024                4             1  4.699992
# 3              661.637  6.62290                8             1  4.418619
# 4              552.465  4.49070                9             1  4.301030
# ...                ...      ...              ...           ...       ...
# 1976           456.364  3.59280                5             1  5.000000
# 1977           497.947  7.21152                5             1  5.982967
# 1978           302.458  5.99270                1             1  5.958607
# 1979           544.969  3.50090                6             3  5.300000
# 1980           471.682  3.72000                4             1  5.000000
#
# [1981 rows x 9 columns]

# %% [markdown]
# # 2. construct graphs for small molecules

# %%
# Define possible values for one-hot encoding
possible_atomic_numbers = list(range(1, 119))
possible_degrees = list(range(0, 10))
possible_hybridizations = [
    Chem.rdchem.HybridizationType.SP,
    Chem.rdchem.HybridizationType.SP2,
    Chem.rdchem.HybridizationType.SP3,
    Chem.rdchem.HybridizationType.SP3D,
    Chem.rdchem.HybridizationType.SP3D2
]
possible_chirality = [
    Chem.rdchem.ChiralType.CHI_UNSPECIFIED,
    Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CW,
    Chem.rdchem.ChiralType.CHI_TETRAHEDRAL_CCW,
    Chem.rdchem.ChiralType.CHI_OTHER
]
possible_bond_types = [Chem.rdchem.BondType.SINGLE, Chem.rdchem.BondType.DOUBLE,
                       Chem.rdchem.BondType.TRIPLE, Chem.rdchem.BondType.AROMATIC]

possible_bond_stereo = [Chem.rdchem.BondStereo.STEREONONE, Chem.rdchem.BondStereo.STEREOZ,
                        Chem.rdchem.BondStereo.STEREOE, Chem.rdchem.BondStereo.STEREOCIS,
                        Chem.rdchem.BondStereo.STEREOTRANS]

# One-hot encoding functions
def one_hot_encode(value, possible_values):
    encoding = [0] * len(possible_values)
    if value in possible_values:
        encoding[possible_values.index(value)] = 1
    return encoding

# Functions for molecular data processing
def get_atomic_info(atom):
    atomic_number_encoding = one_hot_encode(atom.GetAtomicNum(), possible_atomic_numbers)
    degree_encoding = one_hot_encode(atom.GetTotalDegree(), possible_degrees)
    hybridization_encoding = one_hot_encode(atom.GetHybridization(), possible_hybridizations)
    aromatic_encoding = [1 if atom.GetIsAromatic() else 0]
    implicit_valence_encoding = one_hot_encode(atom.GetImplicitValence(), possible_degrees)
    formal_charge_encoding = [atom.GetFormalCharge()]
    chirality_encoding = one_hot_encode(atom.GetChiralTag(), possible_chirality)

    return atomic_number_encoding + degree_encoding + hybridization_encoding + \
           aromatic_encoding + implicit_valence_encoding + formal_charge_encoding + chirality_encoding

def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    atom_features = [get_atomic_info(atom) for atom in mol.GetAtoms()]
    x = torch.tensor(atom_features, dtype=torch.float)

    edges = []
    edge_features = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        edges.append((i, j))
        edges.append((j, i))

        bond_type_encoding = one_hot_encode(bond.GetBondType(), possible_bond_types)
        bond_stereo_encoding = one_hot_encode(bond.GetStereo(), possible_bond_stereo)
        conjugation_encoding = [1 if bond.GetIsConjugated() else 0]
        edge_feature = bond_type_encoding + bond_stereo_encoding + conjugation_encoding

        edge_features.append(edge_feature)
        edge_features.append(edge_feature)

    edge_index = torch.tensor(edges, dtype=torch.int64).t().contiguous()
    edge_attr = torch.tensor(edge_features, dtype=torch.float)

    return Data(x=x, edge_index=edge_index, edge_attr=edge_attr)

# %%
graph_list = [smiles_to_graph(smile) for smile in raw_data_molecule['Smiles']]
pIC50_list = raw_data_molecule['pIC50'].to_list()

scaler = StandardScaler()
pIC50_list = scaler.fit_transform(np.array(pIC50_list).reshape(-1, 1)).flatten()

for graph, pIC50 in zip(graph_list, pIC50_list):
    graph.y = torch.tensor([pIC50], dtype=torch.float).view(-1, 1)


drug_graphs = graph_list
drug_graphs[0]
# Out:
# Data(x=[35, 149], edge_index=[2, 74], edge_attr=[74, 10], y=[1, 1])

# %% [markdown]
# # 3. construct graphs for protein

# %%
# Define a mapping from amino acid names to one-hot encoded vectors
amino_acids = ['ALA', 'ARG', 'ASN', 'ASP', 'CYS', 'GLU', 'GLN', 'GLY', 'HIS', 'ILE', 
               'LEU', 'LYS', 'MET', 'PHE', 'PRO', 'SER', 'THR', 'TRP', 'TYR', 'VAL']
amino_acid_dict = {aa: idx for idx, aa in enumerate(amino_acids)}

# %%
def one_hot_encode_amino_acid(residue_name):
    one_hot = [0] * len(amino_acids)
    if residue_name in amino_acid_dict:
        one_hot[amino_acid_dict[residue_name]] = 1
    return one_hot


def pdb_to_graph(pdb_id):
    pdb_list = PDBList()
    pdb_file_path = pdb_list.retrieve_pdb_file(pdb_id, file_format='pdb', pdir='.')

    parser = PDBParser(QUIET=True)
    structure = parser.get_structure(pdb_id, pdb_file_path)

    # Create a graph
    G = nx.Graph()

    # Traverse through the hierarchy
    for model in structure:
        for chain in model:
            for residue in chain:
                res_id = residue.get_id()
                residue_name = residue.get_resname()
                node_feature = one_hot_encode_amino_acid(residue_name)

                # Additional features: secondary structure and B-factor
                b_factor = residue["CA"].get_bfactor() if 'CA' in residue else 0.0
                
                # Combine all features
                node_feature.append(b_factor)

                G.add_node(res_id, residue_name=residue_name, feature=node_feature)

    # Add edges based on distance threshold
    threshold = 5.0  # Angstroms
    for residue1 in structure.get_residues():
        for residue2 in structure.get_residues():
            if residue1 != residue2:
                try:
                    distance = residue1['CA'] - residue2['CA']  # Using alpha carbon (CA) distance
                    if distance < threshold:
                        G.add_edge(residue1.get_id(), residue2.get_id(), distance=distance)
                except KeyError:
                    continue

    # Convert to PyTorch Geometric Data format
    data = from_networkx(G)

    # Convert node features to tensor and assign to data.x
    node_features = [G.nodes[n]['feature'] for n in G.nodes]
    data.x = torch.tensor(node_features, dtype=torch.float)

    # Optionally add edge attributes if necessary
    edge_attr = [G[u][v]['distance'] for u, v in G.edges]
    data.edge_attr = torch.tensor(edge_attr, dtype=torch.float).view(-1, 1)


    return data

# %%
protein_pdb = '4NKI'
protein_graph = pdb_to_graph(protein_pdb)
protein_graph
# Out:
# Structure exists: '.\pdb4nki.ent'
# Data(edge_index=[2, 694], residue_name=[359], feature=[359, 21], distance=[694], num_nodes=359, x=[359, 21], edge_attr=[347, 1])

# %% [markdown]
# # 4. datasets preparation
#
# shuffling the dataset before it is split can improve the performance. When downloading the dataset from CheMBL, the compound may be sorted and ranked.

# %%
batch_size = 64
torch.manual_seed(seed)
drug_graph_train_loader = DataLoader(drug_graphs[0: int(len(drug_graphs) * 0.8)], batch_size=batch_size, shuffle=True)
drug_graph_test_loader = DataLoader(drug_graphs[int(len(drug_graphs) * 0.2): ], batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 5. model construction

# %%
class GCN_Graph(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN_Graph, self).__init__()
        torch.manual_seed(seed)
        self.conv1 = GraphConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.lin = torch.nn.Linear(hidden_channels, out_channels)

    
    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = F.leaky_relu(x)

        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = F.leaky_relu(x)

        x = global_mean_pool(x, batch)  # Global pooling

        x = F.dropout(x, p=0.5, training=self.training)
        
        x = self.lin(x)

        return x


class AffinityPredictor(torch.nn.Module):
    def __init__(self, protein_gnn, molecule_gnn, hidden_channels):
        super(AffinityPredictor, self).__init__()
        torch.manual_seed(seed)
        self.protein_gnn = protein_gnn
        self.molecule_gnn = molecule_gnn
        self.lin = torch.nn.Linear(hidden_channels * 2, hidden_channels * 2)
        self.batch = torch.nn.BatchNorm1d(hidden_channels * 2)
        self.fc = torch.nn.Linear(hidden_channels * 2, 1)
    
    def forward(self, protein_data, molecule_data):
        # Protein embedding
        protein_embedding = self.protein_gnn(protein_data.x, protein_data.edge_index, protein_data.batch)
        protein_embedding = protein_embedding.unsqueeze(0).expand(molecule_data.batch.max().item() + 1, -1, -1)  # Expand for batch size
        protein_embedding = protein_embedding.reshape(-1, protein_embedding.size(-1))  # Reshape to match molecule_embedding
        # Molecule embedding
        molecule_embedding = self.molecule_gnn(molecule_data.x, molecule_data.edge_index, molecule_data.batch)
        
        # Concatenate embeddings
        x = torch.cat([protein_embedding, molecule_embedding], dim=1)
        x = self.lin(x)
        x = self.batch(x)
        x = F.leaky_relu(x)
        
        x = F.dropout(x, p=0.5, training=self.training)
        
        return self.fc(x)

# %% [markdown]
# # 6. initializing the model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
protein_gnn = GCN_Graph(in_channels=protein_graph.num_node_features, hidden_channels=128, out_channels=128).to(device)
molecule_gnn = GCN_Graph(in_channels=drug_graphs[0].num_node_features, hidden_channels=128, out_channels=128).to(device)
model = AffinityPredictor(protein_gnn, molecule_gnn, hidden_channels=128).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

criterion = torch.nn.L1Loss(reduction='mean').to(device)
# Out:
# Using device: cuda

# %% [markdown]
# # 7. train and test
# rule of thumb: either MAE < 0.6 or R2 > 0.6 is considered as good model
# https://www.nature.com/articles/s41598-020-80113-7

# %%
def train(model, protein_graph, drug_graph_train_loader, optimizer, criterion, epoch):
    model.train()

    for molecule_data in drug_graph_train_loader:
        
        optimizer.zero_grad()
        molecule_data = molecule_data.to(device)
        protein_graph = protein_graph.to(device)
        
        protein_graph_batch = protein_graph.clone()
        protein_graph_batch.batch = torch.zeros(protein_graph.x.size(0), dtype=torch.long).to(device)
        
        output = model(protein_graph, molecule_data)
        loss = criterion(output, molecule_data.y)
        loss.backward()
        optimizer.step()
    

def test(protein_graph, loader):
    model.eval()

    loss_list = []
    r2_list = []

    with torch.no_grad():
        for data in loader:
            
            protein_graph = protein_graph.to(device)
            data = data.to(device)
            out = model(protein_graph, data)
   
            out = torch.tensor(scaler.inverse_transform(out.detach().cpu().numpy().reshape(-1, 1)).flatten())
            actual = torch.tensor(scaler.inverse_transform(data.y.detach().cpu().numpy().reshape(-1, 1)).flatten())

            mae_loss = criterion(out, actual)

            r2 = r2_score(actual, out)
            r2_list.append(r2)

            mae_loss = mae_loss.detach().cpu().numpy()
            loss_list.append(mae_loss)
            
    return loss_list, r2_list
        
overall_train_r2 = []
overall_test_r2 = []
overall_train_loss = []
overall_test_loss = []

best_loss = float('inf')
patience = 100
patience_counter = 0
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
# Training loop
for epoch in range(1, 2001):
    train(model,protein_graph, drug_graph_train_loader, optimizer, criterion, epoch)

    if epoch % 1 == 0:
        train_loss, r2_train_list = test(protein_graph, drug_graph_train_loader)
        test_loss, r2_test_list = test(protein_graph, drug_graph_test_loader)
        print(f'Epoch {epoch}, MAE train loss: {np.average(train_loss):.4f}, MAE test loss: {np.average(test_loss):.4f}, train r2: {np.average(r2_train_list):.4f}, test r2: {np.average(r2_test_list):.4f}')

        overall_train_loss.append(np.average(train_loss))
        overall_test_loss.append(np.average(test_loss))

        overall_train_r2.append(np.average(r2_train_list))
        overall_test_r2.append(np.average(r2_test_list))


        if np.average(test_loss) < best_loss:
            best_loss = np.average(test_loss)
            patience_counter = 0
            # torch.save(model.state_dict(), 'best_model_no_fingerprint_GraphConv_Combined.pth')
        else:
            patience_counter += 1
        
        if patience_counter >= patience:
            print("Early stopping")
            break
    scheduler.step()
# Out:
# Epoch 1, MAE train loss: 0.8257, MAE test loss: 0.8235, train r2: 0.0319, test r2: 0.0117
# Epoch 2, MAE train loss: 0.6759, MAE test loss: 0.6813, train r2: 0.3103, test r2: 0.2781
# Epoch 3, MAE train loss: 0.6403, MAE test loss: 0.6469, train r2: 0.3140, test r2: 0.2903
# Epoch 4, MAE train loss: 0.6293, MAE test loss: 0.6378, train r2: 0.3572, test r2: 0.3247
# Epoch 5, MAE train loss: 0.6173, MAE test loss: 0.6297, train r2: 0.3242, test r2: 0.2856
# Epoch 6, MAE train loss: 0.6151, MAE test loss: 0.6291, train r2: 0.3950, test r2: 0.3461
# Epoch 7, MAE train loss: 0.5984, MAE test loss: 0.6147, train r2: 0.4207, test r2: 0.3802
# Epoch 8, MAE train loss: 0.5845, MAE test loss: 0.5933, train r2: 0.3928, test r2: 0.3744
# Epoch 9, MAE train loss: 0.5838, MAE test loss: 0.5950, train r2: 0.3972, test r2: 0.3651
# Epoch 10, MAE train loss: 0.6817, MAE test loss: 0.6839, train r2: 0.2439, test r2: 0.2233
# Epoch 11, MAE train loss: 0.6080, MAE test loss: 0.6221, train r2: 0.3891, test r2: 0.3529
# Epoch 12, MAE train loss: 0.6514, MAE test loss: 0.6622, train r2: 0.3352, test r2: 0.3013
# Epoch 13, MAE train loss: 0.7297, MAE test loss: 0.7329, train r2: 0.1243, test r2: 0.0863
# Epoch 14, MAE train loss: 0.5669, MAE test loss: 0.5853, train r2: 0.4565, test r2: 0.4152
# Epoch 15, MAE train loss: 0.5926, MAE test loss: 0.6061, train r2: 0.4176, test r2: 0.3814
# Epoch 16, MAE train loss: 0.5942, MAE test loss: 0.6024, train r2: 0.3749, test r2: 0.3440
# Epoch 17, MAE train loss: 0.5133, MAE test loss: 0.5282, train r2: 0.5062, test r2: 0.4826
# Epoch 18, MAE train loss: 0.5084, MAE test loss: 0.5237, train r2: 0.5161, test r2: 0.4853
# Epoch 19, MAE train loss: 0.8270, MAE test loss: 0.8279, train r2: -0.0488, test r2: -0.0859
# Epoch 20, MAE train loss: 0.7031, MAE test loss: 0.7172, train r2: 0.2464, test r2: 0.2204
# Epoch 21, MAE train loss: 0.5417, MAE test loss: 0.5557, train r2: 0.4463, test r2: 0.4109
# Epoch 22, MAE train loss: 0.6159, MAE test loss: 0.6277, train r2: 0.3633, test r2: 0.3585
# Epoch 23, MAE train loss: 0.5452, MAE test loss: 0.5624, train r2: 0.4993, test r2: 0.4656
# Epoch 24, MAE train loss: 0.7343, MAE test loss: 0.7388, train r2: 0.2044, test r2: 0.1591
# Epoch 25, MAE train loss: 0.5153, MAE test loss: 0.5315, train r2: 0.5238, test r2: 0.5027
# Epoch 26, MAE train loss: 0.4966, MAE test loss: 0.5133, train r2: 0.5467, test r2: 0.5196
# Epoch 27, MAE train loss: 0.6134, MAE test loss: 0.6196, train r2: 0.3466, test r2: 0.3084
# Epoch 28, MAE train loss: 0.4955, MAE test loss: 0.5144, train r2: 0.5452, test r2: 0.5192
# Epoch 29, MAE train loss: 0.5416, MAE test loss: 0.5494, train r2: 0.4667, test r2: 0.4349
# Epoch 30, MAE train loss: 0.5345, MAE test loss: 0.5462, train r2: 0.4897, test r2: 0.4639
# Epoch 31, MAE train loss: 0.5408, MAE test loss: 0.5510, train r2: 0.4721, test r2: 0.4348
# Epoch 32, MAE train loss: 0.7811, MAE test loss: 0.7834, train r2: 0.1208, test r2: 0.0838
# Epoch 33, MAE train loss: 0.5806, MAE test loss: 0.5906, train r2: 0.4421, test r2: 0.4101
# Epoch 34, MAE train loss: 0.5951, MAE test loss: 0.6054, train r2: 0.4269, test r2: 0.4033
# Epoch 35, MAE train loss: 0.5226, MAE test loss: 0.5316, train r2: 0.5104, test r2: 0.4777
# Epoch 36, MAE train loss: 0.4737, MAE test loss: 0.4895, train r2: 0.5636, test r2: 0.5346
# Epoch 37, MAE train loss: 0.5771, MAE test loss: 0.5863, train r2: 0.4209, test r2: 0.3872
# Epoch 38, MAE train loss: 0.5048, MAE test loss: 0.5167, train r2: 0.5073, test r2: 0.4818
# Epoch 39, MAE train loss: 0.5567, MAE test loss: 0.5655, train r2: 0.4716, test r2: 0.4503
# Epoch 40, MAE train loss: 0.4946, MAE test loss: 0.5080, train r2: 0.5518, test r2: 0.5204
# Epoch 41, MAE train loss: 0.4806, MAE test loss: 0.4960, train r2: 0.5620, test r2: 0.5334
# Epoch 42, MAE train loss: 0.4718, MAE test loss: 0.4905, train r2: 0.5613, test r2: 0.5224
# Epoch 43, MAE train loss: 0.4890, MAE test loss: 0.5040, train r2: 0.5571, test r2: 0.5323
# Epoch 44, MAE train loss: 0.5804, MAE test loss: 0.5860, train r2: 0.4117, test r2: 0.3803
# Epoch 45, MAE train loss: 0.5054, MAE test loss: 0.5196, train r2: 0.5311, test r2: 0.5128
# Epoch 46, MAE train loss: 0.4520, MAE test loss: 0.4656, train r2: 0.5846, test r2: 0.5631
# Epoch 47, MAE train loss: 0.4631, MAE test loss: 0.4821, train r2: 0.5878, test r2: 0.5535
# Epoch 48, MAE train loss: 0.6040, MAE test loss: 0.6102, train r2: 0.3671, test r2: 0.3351
# Epoch 49, MAE train loss: 0.7404, MAE test loss: 0.7502, train r2: 0.0603, test r2: 0.0175
# Epoch 50, MAE train loss: 0.4783, MAE test loss: 0.4890, train r2: 0.5655, test r2: 0.5362
# Epoch 51, MAE train loss: 0.4672, MAE test loss: 0.4806, train r2: 0.5963, test r2: 0.5737
# Epoch 52, MAE train loss: 0.4539, MAE test loss: 0.4767, train r2: 0.6080, test r2: 0.5728
# Epoch 53, MAE train loss: 0.4553, MAE test loss: 0.4694, train r2: 0.5972, test r2: 0.5802
# Epoch 54, MAE train loss: 0.4562, MAE test loss: 0.4728, train r2: 0.5984, test r2: 0.5783
# Epoch 55, MAE train loss: 0.4758, MAE test loss: 0.4899, train r2: 0.5742, test r2: 0.5411
# Epoch 56, MAE train loss: 0.4479, MAE test loss: 0.4651, train r2: 0.5909, test r2: 0.5662
# Epoch 57, MAE train loss: 0.5457, MAE test loss: 0.5572, train r2: 0.4621, test r2: 0.4275
# Epoch 58, MAE train loss: 0.6913, MAE test loss: 0.6979, train r2: 0.2195, test r2: 0.1650
# Epoch 59, MAE train loss: 0.5054, MAE test loss: 0.5168, train r2: 0.5461, test r2: 0.5258
# Epoch 60, MAE train loss: 0.5232, MAE test loss: 0.5383, train r2: 0.5168, test r2: 0.4714
# Epoch 61, MAE train loss: 0.5633, MAE test loss: 0.5761, train r2: 0.4586, test r2: 0.4282
# Epoch 62, MAE train loss: 0.7801, MAE test loss: 0.7794, train r2: 0.0520, test r2: -0.0019
# Epoch 63, MAE train loss: 0.6492, MAE test loss: 0.6544, train r2: 0.2976, test r2: 0.2535
# Epoch 64, MAE train loss: 0.6713, MAE test loss: 0.6787, train r2: 0.2563, test r2: 0.2016
# Epoch 65, MAE train loss: 0.4388, MAE test loss: 0.4570, train r2: 0.6196, test r2: 0.5881
# Epoch 66, MAE train loss: 0.4696, MAE test loss: 0.4844, train r2: 0.5659, test r2: 0.5328
# Epoch 67, MAE train loss: 0.4750, MAE test loss: 0.4901, train r2: 0.5863, test r2: 0.5590
# Epoch 68, MAE train loss: 0.4713, MAE test loss: 0.4886, train r2: 0.5563, test r2: 0.5216
# Epoch 69, MAE train loss: 0.4479, MAE test loss: 0.4634, train r2: 0.6024, test r2: 0.5741
# Epoch 70, MAE train loss: 0.4352, MAE test loss: 0.4530, train r2: 0.6190, test r2: 0.5833
# Epoch 71, MAE train loss: 0.6551, MAE test loss: 0.6690, train r2: 0.3229, test r2: 0.2962
# Epoch 72, MAE train loss: 0.4432, MAE test loss: 0.4608, train r2: 0.6231, test r2: 0.5900
# Epoch 73, MAE train loss: 0.4688, MAE test loss: 0.4855, train r2: 0.5971, test r2: 0.5689
# Epoch 74, MAE train loss: 0.6044, MAE test loss: 0.6151, train r2: 0.4297, test r2: 0.4013
# Epoch 75, MAE train loss: 0.5241, MAE test loss: 0.5381, train r2: 0.5190, test r2: 0.4846
# Epoch 76, MAE train loss: 0.4357, MAE test loss: 0.4557, train r2: 0.6233, test r2: 0.5986
# Epoch 77, MAE train loss: 0.5288, MAE test loss: 0.5401, train r2: 0.4852, test r2: 0.4482
# Epoch 78, MAE train loss: 0.4825, MAE test loss: 0.5009, train r2: 0.5570, test r2: 0.5241
# Epoch 79, MAE train loss: 0.4327, MAE test loss: 0.4509, train r2: 0.6226, test r2: 0.5991
# Epoch 80, MAE train loss: 0.6257, MAE test loss: 0.6387, train r2: 0.3660, test r2: 0.3395
# Epoch 81, MAE train loss: 0.5814, MAE test loss: 0.5883, train r2: 0.4358, test r2: 0.4179
# Epoch 82, MAE train loss: 0.5859, MAE test loss: 0.5982, train r2: 0.3879, test r2: 0.3497
# Epoch 83, MAE train loss: 0.4413, MAE test loss: 0.4580, train r2: 0.6344, test r2: 0.6080
# Epoch 84, MAE train loss: 0.4552, MAE test loss: 0.4714, train r2: 0.6122, test r2: 0.5826
# Epoch 85, MAE train loss: 0.4158, MAE test loss: 0.4335, train r2: 0.6354, test r2: 0.6124
# Epoch 86, MAE train loss: 0.4732, MAE test loss: 0.4907, train r2: 0.5684, test r2: 0.5237
# Epoch 87, MAE train loss: 0.5227, MAE test loss: 0.5315, train r2: 0.5177, test r2: 0.4896
# Epoch 88, MAE train loss: 0.4393, MAE test loss: 0.4590, train r2: 0.6338, test r2: 0.6027
# Epoch 89, MAE train loss: 0.5259, MAE test loss: 0.5376, train r2: 0.5180, test r2: 0.4955
# Epoch 90, MAE train loss: 0.4686, MAE test loss: 0.4831, train r2: 0.5854, test r2: 0.5592
# Epoch 91, MAE train loss: 0.4188, MAE test loss: 0.4388, train r2: 0.6352, test r2: 0.6109
# Epoch 92, MAE train loss: 0.4229, MAE test loss: 0.4429, train r2: 0.6503, test r2: 0.6137
# Epoch 93, MAE train loss: 0.3989, MAE test loss: 0.4202, train r2: 0.6739, test r2: 0.6400
# Epoch 94, MAE train loss: 0.4847, MAE test loss: 0.5020, train r2: 0.5808, test r2: 0.5538
# Epoch 95, MAE train loss: 0.4183, MAE test loss: 0.4384, train r2: 0.6407, test r2: 0.6161
# Epoch 96, MAE train loss: 0.4528, MAE test loss: 0.4712, train r2: 0.5979, test r2: 0.5658
# Epoch 97, MAE train loss: 0.6600, MAE test loss: 0.6691, train r2: 0.2698, test r2: 0.2263
# Epoch 98, MAE train loss: 0.5174, MAE test loss: 0.5322, train r2: 0.5490, test r2: 0.5256
# Epoch 99, MAE train loss: 0.4462, MAE test loss: 0.4626, train r2: 0.5916, test r2: 0.5612
# Epoch 100, MAE train loss: 0.5452, MAE test loss: 0.5590, train r2: 0.4752, test r2: 0.4236
# Epoch 101, MAE train loss: 0.3972, MAE test loss: 0.4182, train r2: 0.6704, test r2: 0.6396
# Epoch 102, MAE train loss: 0.4568, MAE test loss: 0.4713, train r2: 0.5932, test r2: 0.5622
# Epoch 103, MAE train loss: 0.4389, MAE test loss: 0.4599, train r2: 0.6403, test r2: 0.6130
# Epoch 104, MAE train loss: 0.4155, MAE test loss: 0.4338, train r2: 0.6637, test r2: 0.6341
# Epoch 105, MAE train loss: 0.3825, MAE test loss: 0.4035, train r2: 0.6789, test r2: 0.6509
# Epoch 106, MAE train loss: 0.4180, MAE test loss: 0.4355, train r2: 0.6461, test r2: 0.6130
# Epoch 107, MAE train loss: 0.4418, MAE test loss: 0.4635, train r2: 0.6013, test r2: 0.5600
# Epoch 108, MAE train loss: 0.3810, MAE test loss: 0.4033, train r2: 0.6819, test r2: 0.6504
# Epoch 109, MAE train loss: 0.3933, MAE test loss: 0.4164, train r2: 0.6917, test r2: 0.6559
# Epoch 110, MAE train loss: 0.4127, MAE test loss: 0.4330, train r2: 0.6520, test r2: 0.6107
# Epoch 111, MAE train loss: 0.4099, MAE test loss: 0.4313, train r2: 0.6632, test r2: 0.6284
# Epoch 112, MAE train loss: 0.3877, MAE test loss: 0.4120, train r2: 0.6811, test r2: 0.6416
# Epoch 113, MAE train loss: 0.4361, MAE test loss: 0.4566, train r2: 0.6487, test r2: 0.6192
# Epoch 114, MAE train loss: 0.4085, MAE test loss: 0.4293, train r2: 0.6781, test r2: 0.6467
# Epoch 115, MAE train loss: 0.4093, MAE test loss: 0.4336, train r2: 0.6742, test r2: 0.6414
# Epoch 116, MAE train loss: 0.3894, MAE test loss: 0.4137, train r2: 0.6791, test r2: 0.6480
# Epoch 117, MAE train loss: 0.3897, MAE test loss: 0.4139, train r2: 0.6904, test r2: 0.6557
# Epoch 118, MAE train loss: 0.3794, MAE test loss: 0.3997, train r2: 0.6884, test r2: 0.6631
# Epoch 119, MAE train loss: 0.3836, MAE test loss: 0.4072, train r2: 0.6945, test r2: 0.6555
# Epoch 120, MAE train loss: 0.4799, MAE test loss: 0.4973, train r2: 0.5883, test r2: 0.5695
# Epoch 121, MAE train loss: 0.3801, MAE test loss: 0.4020, train r2: 0.6953, test r2: 0.6577
# Epoch 122, MAE train loss: 0.4544, MAE test loss: 0.4723, train r2: 0.6017, test r2: 0.5649
# Epoch 123, MAE train loss: 0.3827, MAE test loss: 0.4043, train r2: 0.6904, test r2: 0.6650
# Epoch 124, MAE train loss: 0.4061, MAE test loss: 0.4285, train r2: 0.6845, test r2: 0.6470
# Epoch 125, MAE train loss: 0.5899, MAE test loss: 0.6050, train r2: 0.4488, test r2: 0.4165
# Epoch 126, MAE train loss: 0.3914, MAE test loss: 0.4121, train r2: 0.6946, test r2: 0.6586
# Epoch 127, MAE train loss: 0.3881, MAE test loss: 0.4093, train r2: 0.6778, test r2: 0.6464
# Epoch 128, MAE train loss: 0.3860, MAE test loss: 0.4093, train r2: 0.6859, test r2: 0.6607
# Epoch 129, MAE train loss: 0.3825, MAE test loss: 0.4062, train r2: 0.6789, test r2: 0.6443
# Epoch 130, MAE train loss: 0.4152, MAE test loss: 0.4379, train r2: 0.6770, test r2: 0.6476
# Epoch 131, MAE train loss: 0.3886, MAE test loss: 0.4102, train r2: 0.6916, test r2: 0.6627
# Epoch 132, MAE train loss: 0.4284, MAE test loss: 0.4495, train r2: 0.6571, test r2: 0.6298
# Epoch 133, MAE train loss: 0.3726, MAE test loss: 0.3955, train r2: 0.6881, test r2: 0.6660
# Epoch 134, MAE train loss: 0.4137, MAE test loss: 0.4377, train r2: 0.6648, test r2: 0.6328
# Epoch 135, MAE train loss: 0.4628, MAE test loss: 0.4812, train r2: 0.6068, test r2: 0.5845
# Epoch 136, MAE train loss: 0.4009, MAE test loss: 0.4243, train r2: 0.6685, test r2: 0.6310
# Epoch 137, MAE train loss: 0.3670, MAE test loss: 0.3930, train r2: 0.7082, test r2: 0.6771
# Epoch 138, MAE train loss: 0.3808, MAE test loss: 0.4074, train r2: 0.6966, test r2: 0.6617
# Epoch 139, MAE train loss: 0.3657, MAE test loss: 0.3888, train r2: 0.7004, test r2: 0.6693
# Epoch 140, MAE train loss: 0.3771, MAE test loss: 0.4044, train r2: 0.6934, test r2: 0.6526
# Epoch 141, MAE train loss: 0.4242, MAE test loss: 0.4458, train r2: 0.6632, test r2: 0.6366
# Epoch 142, MAE train loss: 0.3895, MAE test loss: 0.4134, train r2: 0.6939, test r2: 0.6610
# Epoch 143, MAE train loss: 0.4317, MAE test loss: 0.4497, train r2: 0.6469, test r2: 0.6193
# Epoch 144, MAE train loss: 0.3987, MAE test loss: 0.4233, train r2: 0.6901, test r2: 0.6589
# Epoch 145, MAE train loss: 0.3770, MAE test loss: 0.4024, train r2: 0.6867, test r2: 0.6532
# Epoch 146, MAE train loss: 0.3618, MAE test loss: 0.3880, train r2: 0.7049, test r2: 0.6747
# Epoch 147, MAE train loss: 0.4539, MAE test loss: 0.4756, train r2: 0.6111, test r2: 0.5645
# Epoch 148, MAE train loss: 0.3744, MAE test loss: 0.3987, train r2: 0.6991, test r2: 0.6691
# Epoch 149, MAE train loss: 0.4370, MAE test loss: 0.4610, train r2: 0.6504, test r2: 0.6194
# Epoch 150, MAE train loss: 0.4335, MAE test loss: 0.4523, train r2: 0.6316, test r2: 0.5912
# Epoch 151, MAE train loss: 0.3960, MAE test loss: 0.4176, train r2: 0.6865, test r2: 0.6529
# Epoch 152, MAE train loss: 0.3746, MAE test loss: 0.4004, train r2: 0.7020, test r2: 0.6675
# Epoch 153, MAE train loss: 0.3865, MAE test loss: 0.4091, train r2: 0.7021, test r2: 0.6734
# Epoch 154, MAE train loss: 0.3683, MAE test loss: 0.3918, train r2: 0.7143, test r2: 0.6855
# Epoch 155, MAE train loss: 0.4482, MAE test loss: 0.4678, train r2: 0.6288, test r2: 0.6033
# Epoch 156, MAE train loss: 0.4554, MAE test loss: 0.4771, train r2: 0.6304, test r2: 0.5971
# Epoch 157, MAE train loss: 0.3691, MAE test loss: 0.3944, train r2: 0.7086, test r2: 0.6807
# Epoch 158, MAE train loss: 0.3990, MAE test loss: 0.4223, train r2: 0.6927, test r2: 0.6633
# Epoch 159, MAE train loss: 0.3618, MAE test loss: 0.3880, train r2: 0.7056, test r2: 0.6718
# Epoch 160, MAE train loss: 0.3795, MAE test loss: 0.4051, train r2: 0.6895, test r2: 0.6497
# Epoch 161, MAE train loss: 0.3829, MAE test loss: 0.4090, train r2: 0.6928, test r2: 0.6606
# Epoch 162, MAE train loss: 0.3863, MAE test loss: 0.4113, train r2: 0.6968, test r2: 0.6657
# Epoch 163, MAE train loss: 0.4523, MAE test loss: 0.4692, train r2: 0.6034, test r2: 0.5682
# Epoch 164, MAE train loss: 0.4005, MAE test loss: 0.4221, train r2: 0.6806, test r2: 0.6430
# Epoch 165, MAE train loss: 0.4878, MAE test loss: 0.5090, train r2: 0.5894, test r2: 0.5647
# Epoch 166, MAE train loss: 0.3662, MAE test loss: 0.3927, train r2: 0.7167, test r2: 0.6822
# Epoch 167, MAE train loss: 0.3742, MAE test loss: 0.4010, train r2: 0.7066, test r2: 0.6702
# Epoch 168, MAE train loss: 0.4199, MAE test loss: 0.4443, train r2: 0.6685, test r2: 0.6383
# Epoch 169, MAE train loss: 0.3672, MAE test loss: 0.3930, train r2: 0.6995, test r2: 0.6753
# Epoch 170, MAE train loss: 0.4046, MAE test loss: 0.4274, train r2: 0.6473, test r2: 0.6169
# Epoch 171, MAE train loss: 0.4055, MAE test loss: 0.4291, train r2: 0.6860, test r2: 0.6545
# Epoch 172, MAE train loss: 0.3988, MAE test loss: 0.4209, train r2: 0.6696, test r2: 0.6301
# Epoch 173, MAE train loss: 0.4070, MAE test loss: 0.4302, train r2: 0.6685, test r2: 0.6428
# Epoch 174, MAE train loss: 0.4810, MAE test loss: 0.4998, train r2: 0.5604, test r2: 0.5160
# Epoch 175, MAE train loss: 0.3884, MAE test loss: 0.4112, train r2: 0.6975, test r2: 0.6598
# Epoch 176, MAE train loss: 0.3779, MAE test loss: 0.4026, train r2: 0.6993, test r2: 0.6653
# Epoch 177, MAE train loss: 0.3695, MAE test loss: 0.3946, train r2: 0.7206, test r2: 0.6856
# Epoch 178, MAE train loss: 0.3590, MAE test loss: 0.3851, train r2: 0.7252, test r2: 0.6914
# Epoch 179, MAE train loss: 0.3532, MAE test loss: 0.3790, train r2: 0.7229, test r2: 0.6929
# Epoch 180, MAE train loss: 0.3618, MAE test loss: 0.3887, train r2: 0.6928, test r2: 0.6572
# Epoch 181, MAE train loss: 0.3782, MAE test loss: 0.4036, train r2: 0.7069, test r2: 0.6738
# Epoch 182, MAE train loss: 0.3677, MAE test loss: 0.3923, train r2: 0.7131, test r2: 0.6836
# Epoch 183, MAE train loss: 0.3580, MAE test loss: 0.3857, train r2: 0.7069, test r2: 0.6684
# Epoch 184, MAE train loss: 0.3745, MAE test loss: 0.3956, train r2: 0.6985, test r2: 0.6711
# Epoch 185, MAE train loss: 0.3862, MAE test loss: 0.4134, train r2: 0.6729, test r2: 0.6327
# Epoch 186, MAE train loss: 0.4838, MAE test loss: 0.5061, train r2: 0.5907, test r2: 0.5536
# Epoch 187, MAE train loss: 0.3582, MAE test loss: 0.3808, train r2: 0.7020, test r2: 0.6804
# Epoch 188, MAE train loss: 0.3773, MAE test loss: 0.4021, train r2: 0.7041, test r2: 0.6733
# Epoch 189, MAE train loss: 0.3700, MAE test loss: 0.3969, train r2: 0.6928, test r2: 0.6571
# Epoch 190, MAE train loss: 0.4248, MAE test loss: 0.4464, train r2: 0.6547, test r2: 0.6234
# Epoch 191, MAE train loss: 0.3684, MAE test loss: 0.3926, train r2: 0.6850, test r2: 0.6582
# Epoch 192, MAE train loss: 0.3699, MAE test loss: 0.3948, train r2: 0.7103, test r2: 0.6821
# Epoch 193, MAE train loss: 0.3959, MAE test loss: 0.4153, train r2: 0.6836, test r2: 0.6533
# Epoch 194, MAE train loss: 0.3873, MAE test loss: 0.4082, train r2: 0.6824, test r2: 0.6560
# Epoch 195, MAE train loss: 0.4252, MAE test loss: 0.4457, train r2: 0.6479, test r2: 0.6075
# Epoch 196, MAE train loss: 0.3652, MAE test loss: 0.3895, train r2: 0.7188, test r2: 0.6885
# Epoch 197, MAE train loss: 0.3600, MAE test loss: 0.3878, train r2: 0.7176, test r2: 0.6834
# Epoch 198, MAE train loss: 0.3629, MAE test loss: 0.3910, train r2: 0.7293, test r2: 0.6930
# Epoch 199, MAE train loss: 0.3813, MAE test loss: 0.4080, train r2: 0.7096, test r2: 0.6749
# Epoch 200, MAE train loss: 0.3773, MAE test loss: 0.4014, train r2: 0.6739, test r2: 0.6487
# Epoch 201, MAE train loss: 0.3463, MAE test loss: 0.3744, train r2: 0.7294, test r2: 0.7008
# Epoch 202, MAE train loss: 0.3475, MAE test loss: 0.3742, train r2: 0.7296, test r2: 0.7011
# Epoch 203, MAE train loss: 0.3519, MAE test loss: 0.3818, train r2: 0.7376, test r2: 0.6984
# Epoch 204, MAE train loss: 0.3498, MAE test loss: 0.3772, train r2: 0.7337, test r2: 0.7017
# Epoch 205, MAE train loss: 0.3424, MAE test loss: 0.3705, train r2: 0.7306, test r2: 0.7012
# Epoch 206, MAE train loss: 0.3466, MAE test loss: 0.3750, train r2: 0.7246, test r2: 0.6882
# Epoch 207, MAE train loss: 0.3585, MAE test loss: 0.3865, train r2: 0.7266, test r2: 0.6950
# Epoch 208, MAE train loss: 0.3822, MAE test loss: 0.4094, train r2: 0.6809, test r2: 0.6359
# Epoch 209, MAE train loss: 0.3468, MAE test loss: 0.3754, train r2: 0.7375, test r2: 0.7047
# Epoch 210, MAE train loss: 0.3521, MAE test loss: 0.3805, train r2: 0.7182, test r2: 0.6776
# Epoch 211, MAE train loss: 0.3747, MAE test loss: 0.4025, train r2: 0.7146, test r2: 0.6871
# Epoch 212, MAE train loss: 0.3617, MAE test loss: 0.3889, train r2: 0.7240, test r2: 0.6943
# Epoch 213, MAE train loss: 0.4050, MAE test loss: 0.4278, train r2: 0.6628, test r2: 0.6187
# Epoch 214, MAE train loss: 0.3465, MAE test loss: 0.3746, train r2: 0.7314, test r2: 0.7007
# Epoch 215, MAE train loss: 0.3541, MAE test loss: 0.3819, train r2: 0.7389, test r2: 0.7065
# Epoch 216, MAE train loss: 0.3381, MAE test loss: 0.3668, train r2: 0.7368, test r2: 0.7047
# Epoch 217, MAE train loss: 0.3357, MAE test loss: 0.3628, train r2: 0.7371, test r2: 0.7070
# Epoch 218, MAE train loss: 0.3366, MAE test loss: 0.3655, train r2: 0.7434, test r2: 0.7083
# Epoch 219, MAE train loss: 0.3372, MAE test loss: 0.3668, train r2: 0.7419, test r2: 0.7099
# Epoch 220, MAE train loss: 0.3386, MAE test loss: 0.3672, train r2: 0.7386, test r2: 0.7103
# Epoch 221, MAE train loss: 0.3342, MAE test loss: 0.3631, train r2: 0.7418, test r2: 0.7094
# Epoch 222, MAE train loss: 0.3493, MAE test loss: 0.3773, train r2: 0.7118, test r2: 0.6799
# Epoch 223, MAE train loss: 0.3325, MAE test loss: 0.3606, train r2: 0.7384, test r2: 0.7126
# Epoch 224, MAE train loss: 0.3318, MAE test loss: 0.3628, train r2: 0.7443, test r2: 0.7090
# Epoch 225, MAE train loss: 0.3411, MAE test loss: 0.3672, train r2: 0.7389, test r2: 0.7088
# Epoch 226, MAE train loss: 0.3505, MAE test loss: 0.3775, train r2: 0.7392, test r2: 0.7060
# Epoch 227, MAE train loss: 0.3866, MAE test loss: 0.4119, train r2: 0.6822, test r2: 0.6414
# Epoch 228, MAE train loss: 0.3349, MAE test loss: 0.3638, train r2: 0.7412, test r2: 0.7147
# Epoch 229, MAE train loss: 0.3436, MAE test loss: 0.3704, train r2: 0.7466, test r2: 0.7156
# Epoch 230, MAE train loss: 0.3513, MAE test loss: 0.3788, train r2: 0.7275, test r2: 0.6990
# Epoch 231, MAE train loss: 0.3308, MAE test loss: 0.3587, train r2: 0.7428, test r2: 0.7095
# Epoch 232, MAE train loss: 0.3551, MAE test loss: 0.3830, train r2: 0.7360, test r2: 0.7074
# Epoch 233, MAE train loss: 0.3282, MAE test loss: 0.3569, train r2: 0.7432, test r2: 0.7139
# Epoch 234, MAE train loss: 0.3408, MAE test loss: 0.3692, train r2: 0.7496, test r2: 0.7117
# Epoch 235, MAE train loss: 0.3330, MAE test loss: 0.3617, train r2: 0.7464, test r2: 0.7140
# Epoch 236, MAE train loss: 0.3442, MAE test loss: 0.3722, train r2: 0.7325, test r2: 0.7045
# Epoch 237, MAE train loss: 0.3626, MAE test loss: 0.3907, train r2: 0.7233, test r2: 0.6896
# Epoch 238, MAE train loss: 0.3396, MAE test loss: 0.3668, train r2: 0.7493, test r2: 0.7095
# Epoch 239, MAE train loss: 0.3304, MAE test loss: 0.3593, train r2: 0.7387, test r2: 0.7141
# Epoch 240, MAE train loss: 0.3307, MAE test loss: 0.3587, train r2: 0.7406, test r2: 0.7075
# Epoch 241, MAE train loss: 0.3414, MAE test loss: 0.3701, train r2: 0.7313, test r2: 0.6991
# Epoch 242, MAE train loss: 0.3381, MAE test loss: 0.3670, train r2: 0.7435, test r2: 0.7122
# Epoch 243, MAE train loss: 0.3371, MAE test loss: 0.3654, train r2: 0.7333, test r2: 0.7017
# Epoch 244, MAE train loss: 0.3427, MAE test loss: 0.3706, train r2: 0.7366, test r2: 0.7012
# Epoch 245, MAE train loss: 0.3404, MAE test loss: 0.3668, train r2: 0.7303, test r2: 0.6991
# Epoch 246, MAE train loss: 0.3307, MAE test loss: 0.3607, train r2: 0.7339, test r2: 0.6999
# Epoch 247, MAE train loss: 0.3338, MAE test loss: 0.3635, train r2: 0.7440, test r2: 0.7102
# Epoch 248, MAE train loss: 0.3355, MAE test loss: 0.3658, train r2: 0.7528, test r2: 0.7135
# Epoch 249, MAE train loss: 0.3395, MAE test loss: 0.3689, train r2: 0.7300, test r2: 0.6961
# Epoch 250, MAE train loss: 0.3552, MAE test loss: 0.3845, train r2: 0.7354, test r2: 0.7036
# Epoch 251, MAE train loss: 0.3228, MAE test loss: 0.3535, train r2: 0.7478, test r2: 0.7175
# Epoch 252, MAE train loss: 0.3318, MAE test loss: 0.3597, train r2: 0.7450, test r2: 0.7123
# Epoch 253, MAE train loss: 0.3746, MAE test loss: 0.3994, train r2: 0.7139, test r2: 0.6839
# Epoch 254, MAE train loss: 0.3280, MAE test loss: 0.3569, train r2: 0.7482, test r2: 0.7134
# Epoch 255, MAE train loss: 0.3283, MAE test loss: 0.3572, train r2: 0.7570, test r2: 0.7208
# Epoch 256, MAE train loss: 0.4153, MAE test loss: 0.4397, train r2: 0.6477, test r2: 0.5995
# Epoch 257, MAE train loss: 0.3309, MAE test loss: 0.3608, train r2: 0.7596, test r2: 0.7205
# Epoch 258, MAE train loss: 0.3288, MAE test loss: 0.3591, train r2: 0.7424, test r2: 0.7039
# Epoch 259, MAE train loss: 0.3611, MAE test loss: 0.3877, train r2: 0.7244, test r2: 0.7019
# Epoch 260, MAE train loss: 0.3523, MAE test loss: 0.3787, train r2: 0.7394, test r2: 0.7044
# Epoch 261, MAE train loss: 0.3247, MAE test loss: 0.3534, train r2: 0.7398, test r2: 0.7093
# Epoch 262, MAE train loss: 0.3262, MAE test loss: 0.3556, train r2: 0.7501, test r2: 0.7165
# Epoch 263, MAE train loss: 0.3761, MAE test loss: 0.4024, train r2: 0.7185, test r2: 0.6922
# Epoch 264, MAE train loss: 0.3234, MAE test loss: 0.3562, train r2: 0.7489, test r2: 0.7142
# Epoch 265, MAE train loss: 0.3678, MAE test loss: 0.3926, train r2: 0.7186, test r2: 0.6908
# Epoch 266, MAE train loss: 0.3654, MAE test loss: 0.3915, train r2: 0.7054, test r2: 0.6645
# Epoch 267, MAE train loss: 0.3594, MAE test loss: 0.3878, train r2: 0.7104, test r2: 0.6725
# Epoch 268, MAE train loss: 0.3301, MAE test loss: 0.3606, train r2: 0.7547, test r2: 0.7217
# Epoch 269, MAE train loss: 0.3282, MAE test loss: 0.3581, train r2: 0.7525, test r2: 0.7191
# Epoch 270, MAE train loss: 0.3245, MAE test loss: 0.3551, train r2: 0.7515, test r2: 0.7179
# Epoch 271, MAE train loss: 0.3346, MAE test loss: 0.3625, train r2: 0.7508, test r2: 0.7204
# Epoch 272, MAE train loss: 0.3607, MAE test loss: 0.3892, train r2: 0.7383, test r2: 0.7042
# Epoch 273, MAE train loss: 0.3259, MAE test loss: 0.3550, train r2: 0.7495, test r2: 0.7182
# Epoch 274, MAE train loss: 0.3558, MAE test loss: 0.3820, train r2: 0.7354, test r2: 0.7032
# Epoch 275, MAE train loss: 0.3516, MAE test loss: 0.3787, train r2: 0.7258, test r2: 0.6915
# Epoch 276, MAE train loss: 0.3696, MAE test loss: 0.3973, train r2: 0.6980, test r2: 0.6576
# Epoch 277, MAE train loss: 0.3297, MAE test loss: 0.3581, train r2: 0.7411, test r2: 0.7183
# Epoch 278, MAE train loss: 0.3246, MAE test loss: 0.3545, train r2: 0.7523, test r2: 0.7187
# Epoch 279, MAE train loss: 0.3249, MAE test loss: 0.3551, train r2: 0.7392, test r2: 0.7066
# Epoch 280, MAE train loss: 0.3256, MAE test loss: 0.3551, train r2: 0.7474, test r2: 0.7173
# Epoch 281, MAE train loss: 0.3315, MAE test loss: 0.3611, train r2: 0.7501, test r2: 0.7210
# Epoch 282, MAE train loss: 0.3551, MAE test loss: 0.3806, train r2: 0.7308, test r2: 0.7030
# Epoch 283, MAE train loss: 0.3808, MAE test loss: 0.4036, train r2: 0.7119, test r2: 0.6850
# Epoch 284, MAE train loss: 0.3191, MAE test loss: 0.3488, train r2: 0.7576, test r2: 0.7194
# Epoch 285, MAE train loss: 0.4147, MAE test loss: 0.4379, train r2: 0.6461, test r2: 0.6033
# Epoch 286, MAE train loss: 0.3309, MAE test loss: 0.3578, train r2: 0.7437, test r2: 0.7169
# Epoch 287, MAE train loss: 0.3679, MAE test loss: 0.3943, train r2: 0.7249, test r2: 0.6967
# Epoch 288, MAE train loss: 0.3347, MAE test loss: 0.3629, train r2: 0.7411, test r2: 0.7024
# Epoch 289, MAE train loss: 0.3425, MAE test loss: 0.3727, train r2: 0.7498, test r2: 0.7113
# Epoch 290, MAE train loss: 0.3354, MAE test loss: 0.3651, train r2: 0.7554, test r2: 0.7181
# Epoch 291, MAE train loss: 0.3281, MAE test loss: 0.3594, train r2: 0.7613, test r2: 0.7227
# Epoch 292, MAE train loss: 0.3249, MAE test loss: 0.3531, train r2: 0.7424, test r2: 0.7075
# Epoch 293, MAE train loss: 0.3739, MAE test loss: 0.4004, train r2: 0.7040, test r2: 0.6585
# Epoch 294, MAE train loss: 0.3243, MAE test loss: 0.3546, train r2: 0.7558, test r2: 0.7198
# Epoch 295, MAE train loss: 0.3188, MAE test loss: 0.3501, train r2: 0.7600, test r2: 0.7233
# Epoch 296, MAE train loss: 0.3771, MAE test loss: 0.4019, train r2: 0.7134, test r2: 0.6812
# Epoch 297, MAE train loss: 0.3253, MAE test loss: 0.3571, train r2: 0.7485, test r2: 0.7192
# Epoch 298, MAE train loss: 0.3374, MAE test loss: 0.3648, train r2: 0.7474, test r2: 0.7064
# Epoch 299, MAE train loss: 0.3247, MAE test loss: 0.3546, train r2: 0.7511, test r2: 0.7217
# Epoch 300, MAE train loss: 0.3219, MAE test loss: 0.3514, train r2: 0.7658, test r2: 0.7261
# Epoch 301, MAE train loss: 0.3184, MAE test loss: 0.3477, train r2: 0.7571, test r2: 0.7292
# Epoch 302, MAE train loss: 0.3154, MAE test loss: 0.3472, train r2: 0.7595, test r2: 0.7247
# Epoch 303, MAE train loss: 0.3138, MAE test loss: 0.3440, train r2: 0.7640, test r2: 0.7305
# Epoch 304, MAE train loss: 0.3171, MAE test loss: 0.3473, train r2: 0.7620, test r2: 0.7271
# Epoch 305, MAE train loss: 0.3165, MAE test loss: 0.3473, train r2: 0.7592, test r2: 0.7271
# Epoch 306, MAE train loss: 0.3121, MAE test loss: 0.3443, train r2: 0.7608, test r2: 0.7301
# Epoch 307, MAE train loss: 0.3125, MAE test loss: 0.3443, train r2: 0.7604, test r2: 0.7261
# Epoch 308, MAE train loss: 0.3249, MAE test loss: 0.3533, train r2: 0.7526, test r2: 0.7162
# Epoch 309, MAE train loss: 0.3313, MAE test loss: 0.3609, train r2: 0.7543, test r2: 0.7213
# Epoch 310, MAE train loss: 0.3154, MAE test loss: 0.3457, train r2: 0.7557, test r2: 0.7278
# Epoch 311, MAE train loss: 0.3107, MAE test loss: 0.3417, train r2: 0.7638, test r2: 0.7296
# Epoch 312, MAE train loss: 0.3181, MAE test loss: 0.3477, train r2: 0.7572, test r2: 0.7312
# Epoch 313, MAE train loss: 0.3123, MAE test loss: 0.3442, train r2: 0.7685, test r2: 0.7321
# Epoch 314, MAE train loss: 0.3143, MAE test loss: 0.3449, train r2: 0.7642, test r2: 0.7307
# Epoch 315, MAE train loss: 0.3182, MAE test loss: 0.3503, train r2: 0.7568, test r2: 0.7293
# Epoch 316, MAE train loss: 0.3169, MAE test loss: 0.3494, train r2: 0.7640, test r2: 0.7291
# Epoch 317, MAE train loss: 0.3172, MAE test loss: 0.3473, train r2: 0.7513, test r2: 0.7259
# Epoch 318, MAE train loss: 0.3119, MAE test loss: 0.3427, train r2: 0.7646, test r2: 0.7315
# Epoch 319, MAE train loss: 0.3164, MAE test loss: 0.3471, train r2: 0.7617, test r2: 0.7323
# Epoch 320, MAE train loss: 0.3179, MAE test loss: 0.3478, train r2: 0.7628, test r2: 0.7311
# Epoch 321, MAE train loss: 0.3165, MAE test loss: 0.3467, train r2: 0.7614, test r2: 0.7299
# Epoch 322, MAE train loss: 0.3158, MAE test loss: 0.3459, train r2: 0.7671, test r2: 0.7325
# Epoch 323, MAE train loss: 0.3132, MAE test loss: 0.3435, train r2: 0.7630, test r2: 0.7265
# Epoch 324, MAE train loss: 0.3185, MAE test loss: 0.3480, train r2: 0.7631, test r2: 0.7306
# Epoch 325, MAE train loss: 0.3118, MAE test loss: 0.3424, train r2: 0.7646, test r2: 0.7327
# Epoch 326, MAE train loss: 0.3302, MAE test loss: 0.3583, train r2: 0.7437, test r2: 0.7072
# Epoch 327, MAE train loss: 0.3252, MAE test loss: 0.3560, train r2: 0.7591, test r2: 0.7263
# Epoch 328, MAE train loss: 0.3120, MAE test loss: 0.3434, train r2: 0.7657, test r2: 0.7342
# Epoch 329, MAE train loss: 0.3312, MAE test loss: 0.3613, train r2: 0.7558, test r2: 0.7216
# Epoch 330, MAE train loss: 0.3241, MAE test loss: 0.3530, train r2: 0.7443, test r2: 0.7117
# Epoch 331, MAE train loss: 0.3187, MAE test loss: 0.3481, train r2: 0.7572, test r2: 0.7326
# Epoch 332, MAE train loss: 0.3236, MAE test loss: 0.3551, train r2: 0.7601, test r2: 0.7292
# Epoch 333, MAE train loss: 0.3078, MAE test loss: 0.3397, train r2: 0.7637, test r2: 0.7286
# Epoch 334, MAE train loss: 0.3220, MAE test loss: 0.3507, train r2: 0.7655, test r2: 0.7312
# Epoch 335, MAE train loss: 0.3176, MAE test loss: 0.3483, train r2: 0.7583, test r2: 0.7288
# Epoch 336, MAE train loss: 0.3303, MAE test loss: 0.3593, train r2: 0.7664, test r2: 0.7262
# Epoch 337, MAE train loss: 0.3143, MAE test loss: 0.3454, train r2: 0.7607, test r2: 0.7332
# Epoch 338, MAE train loss: 0.3111, MAE test loss: 0.3429, train r2: 0.7670, test r2: 0.7307
# Epoch 339, MAE train loss: 0.3100, MAE test loss: 0.3394, train r2: 0.7588, test r2: 0.7291
# Epoch 340, MAE train loss: 0.3115, MAE test loss: 0.3419, train r2: 0.7689, test r2: 0.7334
# Epoch 341, MAE train loss: 0.3197, MAE test loss: 0.3496, train r2: 0.7529, test r2: 0.7161
# Epoch 342, MAE train loss: 0.3104, MAE test loss: 0.3404, train r2: 0.7659, test r2: 0.7334
# Epoch 343, MAE train loss: 0.3176, MAE test loss: 0.3462, train r2: 0.7678, test r2: 0.7322
# Epoch 344, MAE train loss: 0.3145, MAE test loss: 0.3463, train r2: 0.7548, test r2: 0.7190
# Epoch 345, MAE train loss: 0.3140, MAE test loss: 0.3427, train r2: 0.7650, test r2: 0.7327
# Epoch 346, MAE train loss: 0.3096, MAE test loss: 0.3406, train r2: 0.7639, test r2: 0.7339
# Epoch 347, MAE train loss: 0.3177, MAE test loss: 0.3468, train r2: 0.7652, test r2: 0.7324
# Epoch 348, MAE train loss: 0.3140, MAE test loss: 0.3459, train r2: 0.7600, test r2: 0.7344
# Epoch 349, MAE train loss: 0.3102, MAE test loss: 0.3402, train r2: 0.7650, test r2: 0.7319
# Epoch 350, MAE train loss: 0.3225, MAE test loss: 0.3532, train r2: 0.7606, test r2: 0.7277
# Epoch 351, MAE train loss: 0.3126, MAE test loss: 0.3436, train r2: 0.7681, test r2: 0.7327
# Epoch 352, MAE train loss: 0.3062, MAE test loss: 0.3385, train r2: 0.7699, test r2: 0.7368
# Epoch 353, MAE train loss: 0.3176, MAE test loss: 0.3473, train r2: 0.7642, test r2: 0.7312
# Epoch 354, MAE train loss: 0.3120, MAE test loss: 0.3421, train r2: 0.7561, test r2: 0.7270
# Epoch 355, MAE train loss: 0.3156, MAE test loss: 0.3464, train r2: 0.7639, test r2: 0.7347
# Epoch 356, MAE train loss: 0.3117, MAE test loss: 0.3426, train r2: 0.7731, test r2: 0.7361
# Epoch 357, MAE train loss: 0.3111, MAE test loss: 0.3415, train r2: 0.7673, test r2: 0.7299
# Epoch 358, MAE train loss: 0.3249, MAE test loss: 0.3555, train r2: 0.7617, test r2: 0.7297
# Epoch 359, MAE train loss: 0.3170, MAE test loss: 0.3468, train r2: 0.7605, test r2: 0.7293
# Epoch 360, MAE train loss: 0.3108, MAE test loss: 0.3415, train r2: 0.7629, test r2: 0.7296
# Epoch 361, MAE train loss: 0.3146, MAE test loss: 0.3445, train r2: 0.7693, test r2: 0.7331
# Epoch 362, MAE train loss: 0.3188, MAE test loss: 0.3471, train r2: 0.7593, test r2: 0.7339
# Epoch 363, MAE train loss: 0.3154, MAE test loss: 0.3458, train r2: 0.7675, test r2: 0.7356
# Epoch 364, MAE train loss: 0.3094, MAE test loss: 0.3402, train r2: 0.7708, test r2: 0.7362
# Epoch 365, MAE train loss: 0.3118, MAE test loss: 0.3418, train r2: 0.7694, test r2: 0.7331
# Epoch 366, MAE train loss: 0.3119, MAE test loss: 0.3437, train r2: 0.7665, test r2: 0.7344
# Epoch 367, MAE train loss: 0.3174, MAE test loss: 0.3470, train r2: 0.7591, test r2: 0.7300
# Epoch 368, MAE train loss: 0.3156, MAE test loss: 0.3473, train r2: 0.7556, test r2: 0.7177
# Epoch 369, MAE train loss: 0.3165, MAE test loss: 0.3456, train r2: 0.7610, test r2: 0.7297
# Epoch 370, MAE train loss: 0.3076, MAE test loss: 0.3395, train r2: 0.7675, test r2: 0.7355
# Epoch 371, MAE train loss: 0.3114, MAE test loss: 0.3430, train r2: 0.7623, test r2: 0.7297
# Epoch 372, MAE train loss: 0.3151, MAE test loss: 0.3465, train r2: 0.7699, test r2: 0.7343
# Epoch 373, MAE train loss: 0.3075, MAE test loss: 0.3381, train r2: 0.7655, test r2: 0.7345
# Epoch 374, MAE train loss: 0.3016, MAE test loss: 0.3337, train r2: 0.7685, test r2: 0.7354
# Epoch 375, MAE train loss: 0.3038, MAE test loss: 0.3363, train r2: 0.7764, test r2: 0.7369
# Epoch 376, MAE train loss: 0.3103, MAE test loss: 0.3422, train r2: 0.7697, test r2: 0.7344
# Epoch 377, MAE train loss: 0.3116, MAE test loss: 0.3424, train r2: 0.7586, test r2: 0.7277
# Epoch 378, MAE train loss: 0.3167, MAE test loss: 0.3467, train r2: 0.7628, test r2: 0.7319
# Epoch 379, MAE train loss: 0.3280, MAE test loss: 0.3568, train r2: 0.7542, test r2: 0.7241
# Epoch 380, MAE train loss: 0.3054, MAE test loss: 0.3376, train r2: 0.7674, test r2: 0.7370
# Epoch 381, MAE train loss: 0.3063, MAE test loss: 0.3376, train r2: 0.7654, test r2: 0.7356
# Epoch 382, MAE train loss: 0.3067, MAE test loss: 0.3375, train r2: 0.7675, test r2: 0.7361
# Epoch 383, MAE train loss: 0.3074, MAE test loss: 0.3392, train r2: 0.7715, test r2: 0.7335
# Epoch 384, MAE train loss: 0.3115, MAE test loss: 0.3404, train r2: 0.7605, test r2: 0.7282
# Epoch 385, MAE train loss: 0.3133, MAE test loss: 0.3447, train r2: 0.7698, test r2: 0.7332
# Epoch 386, MAE train loss: 0.3426, MAE test loss: 0.3724, train r2: 0.7502, test r2: 0.7151
# Epoch 387, MAE train loss: 0.3151, MAE test loss: 0.3458, train r2: 0.7531, test r2: 0.7191
# Epoch 388, MAE train loss: 0.3107, MAE test loss: 0.3415, train r2: 0.7733, test r2: 0.7367
# Epoch 389, MAE train loss: 0.3225, MAE test loss: 0.3510, train r2: 0.7632, test r2: 0.7313
# Epoch 390, MAE train loss: 0.3097, MAE test loss: 0.3411, train r2: 0.7745, test r2: 0.7381
# Epoch 391, MAE train loss: 0.3091, MAE test loss: 0.3404, train r2: 0.7675, test r2: 0.7288
# Epoch 392, MAE train loss: 0.3354, MAE test loss: 0.3639, train r2: 0.7413, test r2: 0.7023
# Epoch 393, MAE train loss: 0.3555, MAE test loss: 0.3826, train r2: 0.7415, test r2: 0.7087
# Epoch 394, MAE train loss: 0.3090, MAE test loss: 0.3395, train r2: 0.7675, test r2: 0.7367
# Epoch 395, MAE train loss: 0.3033, MAE test loss: 0.3348, train r2: 0.7706, test r2: 0.7358
# Epoch 396, MAE train loss: 0.3104, MAE test loss: 0.3401, train r2: 0.7702, test r2: 0.7370
# Epoch 397, MAE train loss: 0.3120, MAE test loss: 0.3433, train r2: 0.7649, test r2: 0.7340
# Epoch 398, MAE train loss: 0.3277, MAE test loss: 0.3586, train r2: 0.7539, test r2: 0.7203
# Epoch 399, MAE train loss: 0.3163, MAE test loss: 0.3472, train r2: 0.7579, test r2: 0.7192
# Epoch 400, MAE train loss: 0.3552, MAE test loss: 0.3828, train r2: 0.7329, test r2: 0.7045
# Epoch 401, MAE train loss: 0.3052, MAE test loss: 0.3364, train r2: 0.7674, test r2: 0.7335
# Epoch 402, MAE train loss: 0.3071, MAE test loss: 0.3383, train r2: 0.7621, test r2: 0.7315
# Epoch 403, MAE train loss: 0.3207, MAE test loss: 0.3507, train r2: 0.7670, test r2: 0.7334
# Epoch 404, MAE train loss: 0.3024, MAE test loss: 0.3347, train r2: 0.7737, test r2: 0.7405
# Epoch 405, MAE train loss: 0.3090, MAE test loss: 0.3412, train r2: 0.7701, test r2: 0.7385
# Epoch 406, MAE train loss: 0.3065, MAE test loss: 0.3382, train r2: 0.7682, test r2: 0.7385
# Epoch 407, MAE train loss: 0.3085, MAE test loss: 0.3404, train r2: 0.7725, test r2: 0.7377
# Epoch 408, MAE train loss: 0.3032, MAE test loss: 0.3358, train r2: 0.7761, test r2: 0.7399
# Epoch 409, MAE train loss: 0.3070, MAE test loss: 0.3380, train r2: 0.7804, test r2: 0.7408
# Epoch 410, MAE train loss: 0.3098, MAE test loss: 0.3421, train r2: 0.7722, test r2: 0.7387
# Epoch 411, MAE train loss: 0.3027, MAE test loss: 0.3338, train r2: 0.7737, test r2: 0.7347
# Epoch 412, MAE train loss: 0.3039, MAE test loss: 0.3354, train r2: 0.7710, test r2: 0.7414
# Epoch 413, MAE train loss: 0.3015, MAE test loss: 0.3321, train r2: 0.7678, test r2: 0.7398
# Epoch 414, MAE train loss: 0.3071, MAE test loss: 0.3371, train r2: 0.7681, test r2: 0.7400
# Epoch 415, MAE train loss: 0.3099, MAE test loss: 0.3411, train r2: 0.7769, test r2: 0.7383
# Epoch 416, MAE train loss: 0.3159, MAE test loss: 0.3464, train r2: 0.7672, test r2: 0.7357
# Epoch 417, MAE train loss: 0.3046, MAE test loss: 0.3361, train r2: 0.7669, test r2: 0.7396
# Epoch 418, MAE train loss: 0.3017, MAE test loss: 0.3347, train r2: 0.7726, test r2: 0.7356
# Epoch 419, MAE train loss: 0.3104, MAE test loss: 0.3408, train r2: 0.7657, test r2: 0.7317
# Epoch 420, MAE train loss: 0.3119, MAE test loss: 0.3439, train r2: 0.7714, test r2: 0.7384
# Epoch 421, MAE train loss: 0.3037, MAE test loss: 0.3358, train r2: 0.7709, test r2: 0.7413
# Epoch 422, MAE train loss: 0.3013, MAE test loss: 0.3334, train r2: 0.7709, test r2: 0.7402
# Epoch 423, MAE train loss: 0.3061, MAE test loss: 0.3379, train r2: 0.7750, test r2: 0.7394
# Epoch 424, MAE train loss: 0.3032, MAE test loss: 0.3363, train r2: 0.7684, test r2: 0.7387
# Epoch 425, MAE train loss: 0.3024, MAE test loss: 0.3331, train r2: 0.7807, test r2: 0.7415
# Epoch 426, MAE train loss: 0.3036, MAE test loss: 0.3341, train r2: 0.7683, test r2: 0.7333
# Epoch 427, MAE train loss: 0.3241, MAE test loss: 0.3535, train r2: 0.7651, test r2: 0.7316
# Epoch 428, MAE train loss: 0.3052, MAE test loss: 0.3378, train r2: 0.7736, test r2: 0.7386
# Epoch 429, MAE train loss: 0.3056, MAE test loss: 0.3358, train r2: 0.7719, test r2: 0.7388
# Epoch 430, MAE train loss: 0.3037, MAE test loss: 0.3343, train r2: 0.7784, test r2: 0.7414
# Epoch 431, MAE train loss: 0.3082, MAE test loss: 0.3396, train r2: 0.7691, test r2: 0.7392
# Epoch 432, MAE train loss: 0.3011, MAE test loss: 0.3334, train r2: 0.7670, test r2: 0.7331
# Epoch 433, MAE train loss: 0.2974, MAE test loss: 0.3301, train r2: 0.7710, test r2: 0.7389
# Epoch 434, MAE train loss: 0.3053, MAE test loss: 0.3378, train r2: 0.7710, test r2: 0.7365
# Epoch 435, MAE train loss: 0.3162, MAE test loss: 0.3471, train r2: 0.7681, test r2: 0.7352
# Epoch 436, MAE train loss: 0.3021, MAE test loss: 0.3344, train r2: 0.7794, test r2: 0.7409
# Epoch 437, MAE train loss: 0.3002, MAE test loss: 0.3321, train r2: 0.7780, test r2: 0.7426
# Epoch 438, MAE train loss: 0.3071, MAE test loss: 0.3385, train r2: 0.7755, test r2: 0.7397
# Epoch 439, MAE train loss: 0.2992, MAE test loss: 0.3329, train r2: 0.7711, test r2: 0.7390
# Epoch 440, MAE train loss: 0.2984, MAE test loss: 0.3312, train r2: 0.7750, test r2: 0.7402
# Epoch 441, MAE train loss: 0.3055, MAE test loss: 0.3353, train r2: 0.7696, test r2: 0.7367
# Epoch 442, MAE train loss: 0.3336, MAE test loss: 0.3621, train r2: 0.7609, test r2: 0.7258
# Epoch 443, MAE train loss: 0.3013, MAE test loss: 0.3325, train r2: 0.7745, test r2: 0.7398
# Epoch 444, MAE train loss: 0.3033, MAE test loss: 0.3355, train r2: 0.7797, test r2: 0.7418
# Epoch 445, MAE train loss: 0.2988, MAE test loss: 0.3304, train r2: 0.7768, test r2: 0.7405
# Epoch 446, MAE train loss: 0.3030, MAE test loss: 0.3342, train r2: 0.7766, test r2: 0.7406
# Epoch 447, MAE train loss: 0.3002, MAE test loss: 0.3302, train r2: 0.7737, test r2: 0.7402
# Epoch 448, MAE train loss: 0.3081, MAE test loss: 0.3370, train r2: 0.7754, test r2: 0.7411
# Epoch 449, MAE train loss: 0.3008, MAE test loss: 0.3323, train r2: 0.7820, test r2: 0.7433
# Epoch 450, MAE train loss: 0.3096, MAE test loss: 0.3404, train r2: 0.7721, test r2: 0.7385
# Epoch 451, MAE train loss: 0.2987, MAE test loss: 0.3309, train r2: 0.7788, test r2: 0.7403
# Epoch 452, MAE train loss: 0.3017, MAE test loss: 0.3338, train r2: 0.7742, test r2: 0.7414
# Epoch 453, MAE train loss: 0.3010, MAE test loss: 0.3320, train r2: 0.7742, test r2: 0.7386
# Epoch 454, MAE train loss: 0.2973, MAE test loss: 0.3298, train r2: 0.7700, test r2: 0.7423
# Epoch 455, MAE train loss: 0.2980, MAE test loss: 0.3301, train r2: 0.7783, test r2: 0.7423
# Epoch 456, MAE train loss: 0.2972, MAE test loss: 0.3296, train r2: 0.7712, test r2: 0.7379
# Epoch 457, MAE train loss: 0.3049, MAE test loss: 0.3359, train r2: 0.7774, test r2: 0.7424
# Epoch 458, MAE train loss: 0.3065, MAE test loss: 0.3372, train r2: 0.7753, test r2: 0.7429
# Epoch 459, MAE train loss: 0.3219, MAE test loss: 0.3506, train r2: 0.7698, test r2: 0.7351
# Epoch 460, MAE train loss: 0.3057, MAE test loss: 0.3377, train r2: 0.7759, test r2: 0.7418
# Epoch 461, MAE train loss: 0.3087, MAE test loss: 0.3380, train r2: 0.7734, test r2: 0.7400
# Epoch 462, MAE train loss: 0.2983, MAE test loss: 0.3307, train r2: 0.7797, test r2: 0.7403
# Epoch 463, MAE train loss: 0.2987, MAE test loss: 0.3311, train r2: 0.7791, test r2: 0.7441
# Epoch 464, MAE train loss: 0.2994, MAE test loss: 0.3316, train r2: 0.7795, test r2: 0.7420
# Epoch 465, MAE train loss: 0.3112, MAE test loss: 0.3421, train r2: 0.7742, test r2: 0.7387
# Epoch 466, MAE train loss: 0.3020, MAE test loss: 0.3332, train r2: 0.7740, test r2: 0.7427
# Epoch 467, MAE train loss: 0.3017, MAE test loss: 0.3341, train r2: 0.7758, test r2: 0.7424
# Epoch 468, MAE train loss: 0.3064, MAE test loss: 0.3387, train r2: 0.7758, test r2: 0.7411
# Epoch 469, MAE train loss: 0.3000, MAE test loss: 0.3332, train r2: 0.7857, test r2: 0.7425
# Epoch 470, MAE train loss: 0.2974, MAE test loss: 0.3297, train r2: 0.7716, test r2: 0.7412
# Epoch 471, MAE train loss: 0.2995, MAE test loss: 0.3323, train r2: 0.7750, test r2: 0.7412
# Epoch 472, MAE train loss: 0.3056, MAE test loss: 0.3376, train r2: 0.7767, test r2: 0.7409
# Epoch 473, MAE train loss: 0.3011, MAE test loss: 0.3344, train r2: 0.7779, test r2: 0.7403
# Epoch 474, MAE train loss: 0.3068, MAE test loss: 0.3382, train r2: 0.7748, test r2: 0.7415
# Epoch 475, MAE train loss: 0.3004, MAE test loss: 0.3311, train r2: 0.7739, test r2: 0.7395
# Epoch 476, MAE train loss: 0.3158, MAE test loss: 0.3456, train r2: 0.7683, test r2: 0.7377
# Epoch 477, MAE train loss: 0.2994, MAE test loss: 0.3319, train r2: 0.7768, test r2: 0.7429
# Epoch 478, MAE train loss: 0.3036, MAE test loss: 0.3350, train r2: 0.7773, test r2: 0.7439
# Epoch 479, MAE train loss: 0.2999, MAE test loss: 0.3310, train r2: 0.7813, test r2: 0.7435
# Epoch 480, MAE train loss: 0.3025, MAE test loss: 0.3345, train r2: 0.7758, test r2: 0.7422
# Epoch 481, MAE train loss: 0.2984, MAE test loss: 0.3299, train r2: 0.7765, test r2: 0.7411
# Epoch 482, MAE train loss: 0.3038, MAE test loss: 0.3337, train r2: 0.7754, test r2: 0.7408
# Epoch 483, MAE train loss: 0.3150, MAE test loss: 0.3458, train r2: 0.7719, test r2: 0.7366
# Epoch 484, MAE train loss: 0.3000, MAE test loss: 0.3313, train r2: 0.7766, test r2: 0.7427
# Epoch 485, MAE train loss: 0.2962, MAE test loss: 0.3278, train r2: 0.7778, test r2: 0.7459
# Epoch 486, MAE train loss: 0.3011, MAE test loss: 0.3325, train r2: 0.7825, test r2: 0.7427
# Epoch 487, MAE train loss: 0.3021, MAE test loss: 0.3335, train r2: 0.7763, test r2: 0.7439
# Epoch 488, MAE train loss: 0.3020, MAE test loss: 0.3337, train r2: 0.7789, test r2: 0.7424
# Epoch 489, MAE train loss: 0.3077, MAE test loss: 0.3374, train r2: 0.7763, test r2: 0.7422
# Epoch 490, MAE train loss: 0.3108, MAE test loss: 0.3422, train r2: 0.7729, test r2: 0.7386
# Epoch 491, MAE train loss: 0.3032, MAE test loss: 0.3356, train r2: 0.7741, test r2: 0.7403
# Epoch 492, MAE train loss: 0.3002, MAE test loss: 0.3332, train r2: 0.7787, test r2: 0.7428
# Epoch 493, MAE train loss: 0.3048, MAE test loss: 0.3353, train r2: 0.7801, test r2: 0.7422
# Epoch 494, MAE train loss: 0.3013, MAE test loss: 0.3345, train r2: 0.7730, test r2: 0.7379
# Epoch 495, MAE train loss: 0.3048, MAE test loss: 0.3360, train r2: 0.7789, test r2: 0.7429
# Epoch 496, MAE train loss: 0.2975, MAE test loss: 0.3296, train r2: 0.7809, test r2: 0.7444
# Epoch 497, MAE train loss: 0.3007, MAE test loss: 0.3328, train r2: 0.7786, test r2: 0.7448
# Epoch 498, MAE train loss: 0.2995, MAE test loss: 0.3299, train r2: 0.7786, test r2: 0.7440
# Epoch 499, MAE train loss: 0.3079, MAE test loss: 0.3391, train r2: 0.7802, test r2: 0.7419
# Epoch 500, MAE train loss: 0.3005, MAE test loss: 0.3336, train r2: 0.7772, test r2: 0.7429
# Epoch 501, MAE train loss: 0.3017, MAE test loss: 0.3340, train r2: 0.7812, test r2: 0.7433
# Epoch 502, MAE train loss: 0.3043, MAE test loss: 0.3365, train r2: 0.7735, test r2: 0.7438
# Epoch 503, MAE train loss: 0.3059, MAE test loss: 0.3374, train r2: 0.7719, test r2: 0.7429
# Epoch 504, MAE train loss: 0.2949, MAE test loss: 0.3276, train r2: 0.7849, test r2: 0.7445
# Epoch 505, MAE train loss: 0.2979, MAE test loss: 0.3300, train r2: 0.7843, test r2: 0.7452
# Epoch 506, MAE train loss: 0.2994, MAE test loss: 0.3327, train r2: 0.7786, test r2: 0.7453
# Epoch 507, MAE train loss: 0.2977, MAE test loss: 0.3298, train r2: 0.7803, test r2: 0.7448
# Epoch 508, MAE train loss: 0.3058, MAE test loss: 0.3358, train r2: 0.7744, test r2: 0.7444
# Epoch 509, MAE train loss: 0.2998, MAE test loss: 0.3323, train r2: 0.7757, test r2: 0.7454
# Epoch 510, MAE train loss: 0.2996, MAE test loss: 0.3312, train r2: 0.7846, test r2: 0.7459
# Epoch 511, MAE train loss: 0.3059, MAE test loss: 0.3372, train r2: 0.7743, test r2: 0.7423
# Epoch 512, MAE train loss: 0.2975, MAE test loss: 0.3300, train r2: 0.7811, test r2: 0.7451
# Epoch 513, MAE train loss: 0.2940, MAE test loss: 0.3262, train r2: 0.7792, test r2: 0.7444
# Epoch 514, MAE train loss: 0.2958, MAE test loss: 0.3269, train r2: 0.7793, test r2: 0.7456
# Epoch 515, MAE train loss: 0.3067, MAE test loss: 0.3370, train r2: 0.7754, test r2: 0.7429
# Epoch 516, MAE train loss: 0.3001, MAE test loss: 0.3319, train r2: 0.7783, test r2: 0.7448
# Epoch 517, MAE train loss: 0.2991, MAE test loss: 0.3310, train r2: 0.7778, test r2: 0.7445
# Epoch 518, MAE train loss: 0.3066, MAE test loss: 0.3381, train r2: 0.7727, test r2: 0.7423
# Epoch 519, MAE train loss: 0.3001, MAE test loss: 0.3318, train r2: 0.7747, test r2: 0.7445
# Epoch 520, MAE train loss: 0.3074, MAE test loss: 0.3380, train r2: 0.7776, test r2: 0.7436
# Epoch 521, MAE train loss: 0.2951, MAE test loss: 0.3273, train r2: 0.7811, test r2: 0.7461
# Epoch 522, MAE train loss: 0.2981, MAE test loss: 0.3304, train r2: 0.7803, test r2: 0.7455
# ...
# Epoch 689, MAE train loss: 0.2942, MAE test loss: 0.3270, train r2: 0.7834, test r2: 0.7494
# Epoch 690, MAE train loss: 0.2922, MAE test loss: 0.3245, train r2: 0.7799, test r2: 0.7492
# Epoch 691, MAE train loss: 0.2947, MAE test loss: 0.3272, train r2: 0.7858, test r2: 0.7490
# Epoch 692, MAE train loss: 0.2926, MAE test loss: 0.3251, train r2: 0.7830, test r2: 0.7497
# Epoch 693, MAE train loss: 0.2934, MAE test loss: 0.3256, train r2: 0.7891, test r2: 0.7493
# Epoch 694, MAE train loss: 0.2927, MAE test loss: 0.3248, train r2: 0.7854, test r2: 0.7495
# Epoch 695, MAE train loss: 0.2909, MAE test loss: 0.3236, train r2: 0.7855, test r2: 0.7491
# Epoch 696, MAE train loss: 0.3052, MAE test loss: 0.3361, train r2: 0.7752, test r2: 0.7439
# Epoch 697, MAE train loss: 0.2948, MAE test loss: 0.3269, train r2: 0.7807, test r2: 0.7497
# Epoch 698, MAE train loss: 0.2933, MAE test loss: 0.3262, train r2: 0.7852, test r2: 0.7493
# Epoch 699, MAE train loss: 0.2897, MAE test loss: 0.3215, train r2: 0.7844, test r2: 0.7485
# Epoch 700, MAE train loss: 0.2927, MAE test loss: 0.3249, train r2: 0.7835, test r2: 0.7501
# Epoch 701, MAE train loss: 0.2948, MAE test loss: 0.3270, train r2: 0.7841, test r2: 0.7460
# Epoch 702, MAE train loss: 0.2939, MAE test loss: 0.3269, train r2: 0.7879, test r2: 0.7494
# Epoch 703, MAE train loss: 0.3000, MAE test loss: 0.3324, train r2: 0.7793, test r2: 0.7479
# Epoch 704, MAE train loss: 0.2980, MAE test loss: 0.3304, train r2: 0.7868, test r2: 0.7490
# Epoch 705, MAE train loss: 0.2962, MAE test loss: 0.3281, train r2: 0.7837, test r2: 0.7494
# Epoch 706, MAE train loss: 0.2901, MAE test loss: 0.3231, train r2: 0.7817, test r2: 0.7493
# Epoch 707, MAE train loss: 0.2914, MAE test loss: 0.3243, train r2: 0.7860, test r2: 0.7499
# Epoch 708, MAE train loss: 0.2942, MAE test loss: 0.3268, train r2: 0.7855, test r2: 0.7500
# Epoch 709, MAE train loss: 0.2913, MAE test loss: 0.3240, train r2: 0.7858, test r2: 0.7501
# Epoch 710, MAE train loss: 0.2987, MAE test loss: 0.3311, train r2: 0.7851, test r2: 0.7482
# Epoch 711, MAE train loss: 0.2953, MAE test loss: 0.3281, train r2: 0.7824, test r2: 0.7493
# Epoch 712, MAE train loss: 0.2921, MAE test loss: 0.3248, train r2: 0.7853, test r2: 0.7502
# Epoch 713, MAE train loss: 0.2975, MAE test loss: 0.3297, train r2: 0.7842, test r2: 0.7492
# Epoch 714, MAE train loss: 0.2889, MAE test loss: 0.3224, train r2: 0.7855, test r2: 0.7497
# Epoch 715, MAE train loss: 0.2929, MAE test loss: 0.3252, train r2: 0.7847, test r2: 0.7499
# Epoch 716, MAE train loss: 0.2939, MAE test loss: 0.3269, train r2: 0.7808, test r2: 0.7497
# Epoch 717, MAE train loss: 0.2961, MAE test loss: 0.3284, train r2: 0.7796, test r2: 0.7493
# Epoch 718, MAE train loss: 0.2928, MAE test loss: 0.3252, train r2: 0.7863, test r2: 0.7503
# Epoch 719, MAE train loss: 0.2931, MAE test loss: 0.3255, train r2: 0.7889, test r2: 0.7488
# Epoch 720, MAE train loss: 0.2970, MAE test loss: 0.3287, train r2: 0.7775, test r2: 0.7483
# Epoch 721, MAE train loss: 0.2933, MAE test loss: 0.3261, train r2: 0.7807, test r2: 0.7494
# Epoch 722, MAE train loss: 0.2899, MAE test loss: 0.3232, train r2: 0.7854, test r2: 0.7500
# Epoch 723, MAE train loss: 0.2912, MAE test loss: 0.3246, train r2: 0.7798, test r2: 0.7497
# Epoch 724, MAE train loss: 0.2985, MAE test loss: 0.3312, train r2: 0.7809, test r2: 0.7482
# Epoch 725, MAE train loss: 0.2951, MAE test loss: 0.3282, train r2: 0.7838, test r2: 0.7482
# Epoch 726, MAE train loss: 0.2969, MAE test loss: 0.3292, train r2: 0.7837, test r2: 0.7485
# Epoch 727, MAE train loss: 0.2915, MAE test loss: 0.3245, train r2: 0.7884, test r2: 0.7496
# Epoch 728, MAE train loss: 0.2963, MAE test loss: 0.3288, train r2: 0.7837, test r2: 0.7491
# Epoch 729, MAE train loss: 0.2947, MAE test loss: 0.3279, train r2: 0.7825, test r2: 0.7491
# Epoch 730, MAE train loss: 0.2921, MAE test loss: 0.3243, train r2: 0.7804, test r2: 0.7494
# Epoch 731, MAE train loss: 0.2973, MAE test loss: 0.3293, train r2: 0.7855, test r2: 0.7481
# Epoch 732, MAE train loss: 0.2954, MAE test loss: 0.3277, train r2: 0.7798, test r2: 0.7493
# Epoch 733, MAE train loss: 0.2927, MAE test loss: 0.3255, train r2: 0.7831, test r2: 0.7497
# Epoch 734, MAE train loss: 0.2954, MAE test loss: 0.3281, train r2: 0.7850, test r2: 0.7491
# Epoch 735, MAE train loss: 0.2933, MAE test loss: 0.3260, train r2: 0.7907, test r2: 0.7491
# Epoch 736, MAE train loss: 0.2905, MAE test loss: 0.3243, train r2: 0.7889, test r2: 0.7488
# Epoch 737, MAE train loss: 0.2919, MAE test loss: 0.3245, train r2: 0.7818, test r2: 0.7497
# Epoch 738, MAE train loss: 0.2937, MAE test loss: 0.3274, train r2: 0.7852, test r2: 0.7493
# Epoch 739, MAE train loss: 0.3007, MAE test loss: 0.3324, train r2: 0.7833, test r2: 0.7474
# Epoch 740, MAE train loss: 0.2965, MAE test loss: 0.3287, train r2: 0.7815, test r2: 0.7475
# Epoch 741, MAE train loss: 0.2889, MAE test loss: 0.3223, train r2: 0.7852, test r2: 0.7491
# Epoch 742, MAE train loss: 0.2893, MAE test loss: 0.3221, train r2: 0.7865, test r2: 0.7497
# Epoch 743, MAE train loss: 0.2934, MAE test loss: 0.3259, train r2: 0.7836, test r2: 0.7489
# Epoch 744, MAE train loss: 0.2938, MAE test loss: 0.3262, train r2: 0.7861, test r2: 0.7491
# Epoch 745, MAE train loss: 0.2893, MAE test loss: 0.3223, train r2: 0.7801, test r2: 0.7490
# Epoch 746, MAE train loss: 0.2889, MAE test loss: 0.3220, train r2: 0.7885, test r2: 0.7498
# Epoch 747, MAE train loss: 0.2912, MAE test loss: 0.3238, train r2: 0.7887, test r2: 0.7500
# Epoch 748, MAE train loss: 0.2943, MAE test loss: 0.3264, train r2: 0.7847, test r2: 0.7497
# Epoch 749, MAE train loss: 0.2920, MAE test loss: 0.3252, train r2: 0.7876, test r2: 0.7497
# Epoch 750, MAE train loss: 0.2901, MAE test loss: 0.3229, train r2: 0.7847, test r2: 0.7505
# Epoch 751, MAE train loss: 0.2925, MAE test loss: 0.3250, train r2: 0.7839, test r2: 0.7504
# Epoch 752, MAE train loss: 0.2889, MAE test loss: 0.3220, train r2: 0.7827, test r2: 0.7504
# Epoch 753, MAE train loss: 0.2994, MAE test loss: 0.3307, train r2: 0.7837, test r2: 0.7486
# Epoch 754, MAE train loss: 0.2952, MAE test loss: 0.3270, train r2: 0.7833, test r2: 0.7501
# Epoch 755, MAE train loss: 0.2983, MAE test loss: 0.3291, train r2: 0.7765, test r2: 0.7483
# Epoch 756, MAE train loss: 0.2907, MAE test loss: 0.3221, train r2: 0.7820, test r2: 0.7497
# Epoch 757, MAE train loss: 0.2942, MAE test loss: 0.3266, train r2: 0.7884, test r2: 0.7495
# Epoch 758, MAE train loss: 0.2933, MAE test loss: 0.3256, train r2: 0.7783, test r2: 0.7502
# Epoch 759, MAE train loss: 0.2950, MAE test loss: 0.3271, train r2: 0.7817, test r2: 0.7497
# Epoch 760, MAE train loss: 0.2915, MAE test loss: 0.3238, train r2: 0.7864, test r2: 0.7502
# Epoch 761, MAE train loss: 0.2879, MAE test loss: 0.3210, train r2: 0.7836, test r2: 0.7496
# Epoch 762, MAE train loss: 0.2911, MAE test loss: 0.3235, train r2: 0.7877, test r2: 0.7489
# Epoch 763, MAE train loss: 0.2957, MAE test loss: 0.3281, train r2: 0.7879, test r2: 0.7495
# Epoch 764, MAE train loss: 0.3037, MAE test loss: 0.3342, train r2: 0.7825, test r2: 0.7468
# Epoch 765, MAE train loss: 0.3016, MAE test loss: 0.3327, train r2: 0.7835, test r2: 0.7485
# Epoch 766, MAE train loss: 0.2957, MAE test loss: 0.3273, train r2: 0.7884, test r2: 0.7496
# Epoch 767, MAE train loss: 0.2926, MAE test loss: 0.3253, train r2: 0.7892, test r2: 0.7503
# Epoch 768, MAE train loss: 0.2952, MAE test loss: 0.3268, train r2: 0.7866, test r2: 0.7497
# Epoch 769, MAE train loss: 0.2933, MAE test loss: 0.3252, train r2: 0.7886, test r2: 0.7494
# Epoch 770, MAE train loss: 0.2910, MAE test loss: 0.3243, train r2: 0.7880, test r2: 0.7492
# Epoch 771, MAE train loss: 0.2915, MAE test loss: 0.3243, train r2: 0.7816, test r2: 0.7500
# Epoch 772, MAE train loss: 0.2914, MAE test loss: 0.3243, train r2: 0.7859, test r2: 0.7500
# Epoch 773, MAE train loss: 0.2928, MAE test loss: 0.3256, train r2: 0.7861, test r2: 0.7499
# Epoch 774, MAE train loss: 0.2953, MAE test loss: 0.3281, train r2: 0.7857, test r2: 0.7488
# Epoch 775, MAE train loss: 0.2993, MAE test loss: 0.3317, train r2: 0.7837, test r2: 0.7478
# Epoch 776, MAE train loss: 0.2941, MAE test loss: 0.3268, train r2: 0.7799, test r2: 0.7491
# Epoch 777, MAE train loss: 0.2916, MAE test loss: 0.3244, train r2: 0.7868, test r2: 0.7497
# Epoch 778, MAE train loss: 0.2953, MAE test loss: 0.3269, train r2: 0.7818, test r2: 0.7491
# Epoch 779, MAE train loss: 0.2984, MAE test loss: 0.3297, train r2: 0.7822, test r2: 0.7485
# Epoch 780, MAE train loss: 0.2915, MAE test loss: 0.3246, train r2: 0.7883, test r2: 0.7504
# Epoch 781, MAE train loss: 0.2908, MAE test loss: 0.3220, train r2: 0.7859, test r2: 0.7505
# Epoch 782, MAE train loss: 0.2920, MAE test loss: 0.3244, train r2: 0.7844, test r2: 0.7499
# Epoch 783, MAE train loss: 0.2919, MAE test loss: 0.3244, train r2: 0.7884, test r2: 0.7503
# Epoch 784, MAE train loss: 0.2921, MAE test loss: 0.3253, train r2: 0.7848, test r2: 0.7499
# Epoch 785, MAE train loss: 0.3008, MAE test loss: 0.3325, train r2: 0.7854, test r2: 0.7471
# Epoch 786, MAE train loss: 0.2933, MAE test loss: 0.3265, train r2: 0.7856, test r2: 0.7496
# Epoch 787, MAE train loss: 0.2900, MAE test loss: 0.3222, train r2: 0.7880, test r2: 0.7498
# Epoch 788, MAE train loss: 0.2926, MAE test loss: 0.3246, train r2: 0.7881, test r2: 0.7503
# Epoch 789, MAE train loss: 0.3008, MAE test loss: 0.3323, train r2: 0.7783, test r2: 0.7476
# Epoch 790, MAE train loss: 0.2899, MAE test loss: 0.3221, train r2: 0.7854, test r2: 0.7508
# Epoch 791, MAE train loss: 0.2921, MAE test loss: 0.3261, train r2: 0.7870, test r2: 0.7499
# Epoch 792, MAE train loss: 0.2940, MAE test loss: 0.3274, train r2: 0.7838, test r2: 0.7495
# Epoch 793, MAE train loss: 0.3002, MAE test loss: 0.3319, train r2: 0.7817, test r2: 0.7477
# Epoch 794, MAE train loss: 0.2944, MAE test loss: 0.3263, train r2: 0.7829, test r2: 0.7497
# Epoch 795, MAE train loss: 0.3057, MAE test loss: 0.3369, train r2: 0.7806, test r2: 0.7462
# Epoch 796, MAE train loss: 0.2927, MAE test loss: 0.3258, train r2: 0.7875, test r2: 0.7495
# Epoch 797, MAE train loss: 0.2931, MAE test loss: 0.3256, train r2: 0.7864, test r2: 0.7501
# Epoch 798, MAE train loss: 0.2959, MAE test loss: 0.3279, train r2: 0.7839, test r2: 0.7488
# Epoch 799, MAE train loss: 0.2977, MAE test loss: 0.3292, train r2: 0.7836, test r2: 0.7471
# Epoch 800, MAE train loss: 0.2909, MAE test loss: 0.3238, train r2: 0.7865, test r2: 0.7501
# Epoch 801, MAE train loss: 0.2897, MAE test loss: 0.3225, train r2: 0.7859, test r2: 0.7500
# Epoch 802, MAE train loss: 0.2959, MAE test loss: 0.3283, train r2: 0.7847, test r2: 0.7492
# Epoch 803, MAE train loss: 0.2921, MAE test loss: 0.3249, train r2: 0.7826, test r2: 0.7500
# Epoch 804, MAE train loss: 0.2908, MAE test loss: 0.3234, train r2: 0.7843, test r2: 0.7501
# Epoch 805, MAE train loss: 0.2969, MAE test loss: 0.3293, train r2: 0.7849, test r2: 0.7488
# Epoch 806, MAE train loss: 0.2952, MAE test loss: 0.3283, train r2: 0.7877, test r2: 0.7492
# Epoch 807, MAE train loss: 0.2907, MAE test loss: 0.3240, train r2: 0.7881, test r2: 0.7500
# Epoch 808, MAE train loss: 0.2971, MAE test loss: 0.3300, train r2: 0.7853, test r2: 0.7488
# Epoch 809, MAE train loss: 0.2998, MAE test loss: 0.3317, train r2: 0.7812, test r2: 0.7482
# Epoch 810, MAE train loss: 0.2958, MAE test loss: 0.3282, train r2: 0.7821, test r2: 0.7493
# Epoch 811, MAE train loss: 0.2907, MAE test loss: 0.3230, train r2: 0.7824, test r2: 0.7501
# Epoch 812, MAE train loss: 0.2942, MAE test loss: 0.3263, train r2: 0.7849, test r2: 0.7492
# Epoch 813, MAE train loss: 0.2962, MAE test loss: 0.3288, train r2: 0.7861, test r2: 0.7485
# Epoch 814, MAE train loss: 0.2905, MAE test loss: 0.3233, train r2: 0.7871, test r2: 0.7501
# Epoch 815, MAE train loss: 0.2966, MAE test loss: 0.3289, train r2: 0.7831, test r2: 0.7491
# Epoch 816, MAE train loss: 0.2893, MAE test loss: 0.3229, train r2: 0.7837, test r2: 0.7493
# Epoch 817, MAE train loss: 0.2928, MAE test loss: 0.3251, train r2: 0.7825, test r2: 0.7498
# Epoch 818, MAE train loss: 0.2894, MAE test loss: 0.3220, train r2: 0.7757, test r2: 0.7502
# Epoch 819, MAE train loss: 0.2914, MAE test loss: 0.3236, train r2: 0.7890, test r2: 0.7504
# Epoch 820, MAE train loss: 0.2959, MAE test loss: 0.3283, train r2: 0.7833, test r2: 0.7498
# Epoch 821, MAE train loss: 0.2961, MAE test loss: 0.3278, train r2: 0.7872, test r2: 0.7491
# Epoch 822, MAE train loss: 0.2908, MAE test loss: 0.3241, train r2: 0.7871, test r2: 0.7505
# Epoch 823, MAE train loss: 0.2901, MAE test loss: 0.3234, train r2: 0.7850, test r2: 0.7507
# Epoch 824, MAE train loss: 0.2924, MAE test loss: 0.3251, train r2: 0.7869, test r2: 0.7502
# Epoch 825, MAE train loss: 0.2923, MAE test loss: 0.3251, train r2: 0.7844, test r2: 0.7502
# Epoch 826, MAE train loss: 0.2905, MAE test loss: 0.3241, train r2: 0.7858, test r2: 0.7496
# Epoch 827, MAE train loss: 0.2950, MAE test loss: 0.3272, train r2: 0.7863, test r2: 0.7499
# Epoch 828, MAE train loss: 0.2906, MAE test loss: 0.3235, train r2: 0.7843, test r2: 0.7494
# Epoch 829, MAE train loss: 0.2942, MAE test loss: 0.3274, train r2: 0.7836, test r2: 0.7501
# Epoch 830, MAE train loss: 0.2953, MAE test loss: 0.3276, train r2: 0.7806, test r2: 0.7500
# Epoch 831, MAE train loss: 0.2912, MAE test loss: 0.3242, train r2: 0.7861, test r2: 0.7503
# Epoch 832, MAE train loss: 0.2933, MAE test loss: 0.3258, train r2: 0.7824, test r2: 0.7499
# Epoch 833, MAE train loss: 0.2926, MAE test loss: 0.3251, train r2: 0.7859, test r2: 0.7507
# Epoch 834, MAE train loss: 0.2899, MAE test loss: 0.3231, train r2: 0.7849, test r2: 0.7506
# Epoch 835, MAE train loss: 0.2900, MAE test loss: 0.3235, train r2: 0.7893, test r2: 0.7505
# Epoch 836, MAE train loss: 0.2932, MAE test loss: 0.3244, train r2: 0.7826, test r2: 0.7506
# Epoch 837, MAE train loss: 0.2939, MAE test loss: 0.3259, train r2: 0.7831, test r2: 0.7505
# Epoch 838, MAE train loss: 0.2974, MAE test loss: 0.3292, train r2: 0.7787, test r2: 0.7498
# Epoch 839, MAE train loss: 0.2885, MAE test loss: 0.3216, train r2: 0.7882, test r2: 0.7492
# Epoch 840, MAE train loss: 0.2906, MAE test loss: 0.3235, train r2: 0.7880, test r2: 0.7505
# Epoch 841, MAE train loss: 0.2904, MAE test loss: 0.3224, train r2: 0.7803, test r2: 0.7498
# Epoch 842, MAE train loss: 0.2910, MAE test loss: 0.3241, train r2: 0.7853, test r2: 0.7505
# Epoch 843, MAE train loss: 0.2934, MAE test loss: 0.3258, train r2: 0.7841, test r2: 0.7491
# Epoch 844, MAE train loss: 0.2901, MAE test loss: 0.3230, train r2: 0.7829, test r2: 0.7489
# Epoch 845, MAE train loss: 0.2912, MAE test loss: 0.3240, train r2: 0.7862, test r2: 0.7508
# Epoch 846, MAE train loss: 0.2929, MAE test loss: 0.3249, train r2: 0.7848, test r2: 0.7503
# Epoch 847, MAE train loss: 0.2898, MAE test loss: 0.3222, train r2: 0.7828, test r2: 0.7503
# Epoch 848, MAE train loss: 0.2966, MAE test loss: 0.3290, train r2: 0.7844, test r2: 0.7498
# Epoch 849, MAE train loss: 0.2944, MAE test loss: 0.3257, train r2: 0.7854, test r2: 0.7507
# Epoch 850, MAE train loss: 0.2975, MAE test loss: 0.3294, train r2: 0.7861, test r2: 0.7493
# Epoch 851, MAE train loss: 0.2907, MAE test loss: 0.3239, train r2: 0.7839, test r2: 0.7489
# Epoch 852, MAE train loss: 0.2926, MAE test loss: 0.3253, train r2: 0.7876, test r2: 0.7504
# Epoch 853, MAE train loss: 0.2895, MAE test loss: 0.3217, train r2: 0.7817, test r2: 0.7501
# Epoch 854, MAE train loss: 0.2904, MAE test loss: 0.3228, train r2: 0.7831, test r2: 0.7509
# Epoch 855, MAE train loss: 0.2907, MAE test loss: 0.3221, train r2: 0.7863, test r2: 0.7513
# Epoch 856, MAE train loss: 0.2944, MAE test loss: 0.3272, train r2: 0.7896, test r2: 0.7506
# Epoch 857, MAE train loss: 0.2904, MAE test loss: 0.3232, train r2: 0.7887, test r2: 0.7506
# Epoch 858, MAE train loss: 0.2908, MAE test loss: 0.3232, train r2: 0.7855, test r2: 0.7499
# Epoch 859, MAE train loss: 0.2878, MAE test loss: 0.3211, train r2: 0.7883, test r2: 0.7510
# Epoch 860, MAE train loss: 0.2916, MAE test loss: 0.3237, train r2: 0.7836, test r2: 0.7509
# Epoch 861, MAE train loss: 0.2922, MAE test loss: 0.3255, train r2: 0.7861, test r2: 0.7509
# Early stopping

# %%
print('r2 on testset', np.average(overall_test_r2[400:]))
print('MAE on testset',np.average(overall_test_loss[400:]))
# Out:
# r2 on testset 0.7463659301363504
# MAE on testset 0.3293158

# %%
x = [i for i in range(1, 862)]
fig = plt.figure(figsize=(16, 8))
plt.plot(x, overall_train_loss, label = 'overall_train_loss')
plt.plot(x, overall_test_loss, label = 'overall_test_loss')
plt.legend()
plt.show() 
# fig.savefig('./mae_no_fingerprint_GraphConv_Combined.png')

# %%
fig = plt.figure(figsize=(16, 8))
plt.plot(x, overall_train_r2, label = 'overall_train_r2')
plt.plot(x, overall_test_r2, label = 'overall_test_r2')
plt.legend()
plt.show()
# fig.savefig('./r2_no_fingerprint_GraphConv_Combined.png')
